# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Value of encoding may differ for linux machine**

# %%
df = pd.read_csv('OTC.csv',encoding="cp1252")

# %%
columns = list(df.columns)

# %%
columns
# Out:
# ['ESN',
#  'ORDER_NUMBER',
#  'ACCOUNT_SEGMENT',
#  'CUSTOMER_CATEGORY',
#  'CUSTOMER_TYPE',
#  'BILL_TO_ACCNT_ID',
#  'BILL_TO_ACCNT_CUST_NAME',
#  'ORDER_TYPE',
#  'INVC_NUM',
#  'INVC_LINE_NUM',
#  'INVC_DATE',
#  'INVC_STATUS',
#  'ITEM_NAME',
#  'PRODUCT_DESCRIPTION',
#  'INVC_QTY',
#  'UNIT_OF_MEASURE',
#  'ITEM_BASE_PRICE',
#  'ITEM_SELLING_PRICE',
#  'INVC_AMT',
#  'ITEM_CATEGORY',
#  'SHIP_TO_STATE']

# %%
df2 = df[['INVC_NUM','ITEM_NAME']]

# %%
df2.head()
# Out:
#           INVC_NUM ITEM_NAME
# 0  OSVKK2122000283   5285612
# 1  OSVKK2122000283   3978040
# 2  OSVKK2122000283   3954904
# 3  OSVKK2122000283    505441
# 4  OSVKK2122000284   3401544

# %%
df2.shape
# Out:
# (513894, 2)

# %%
grouped = df2.groupby('INVC_NUM')['ITEM_NAME'].apply(','.join).reset_index()

# %%
grouped.head()
# Out:
#         INVC_NUM                                          ITEM_NAME
# 0  1-14159855793                                 SR-SC-PV-Maint-Gen
# 1  1-14167579557                            5285612,5319245,5349496
# 2  1-14291359880    3978040,3954904,3329289,3889311,3889310,3879488
# 3  1-14301892747  KIT3238535,4371769,4352578,4376512,3023079,495...
# 4  1-14327191570                                            4926654

# %%
grouped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 123329 entries, 0 to 123328
# Data columns (total 2 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   INVC_NUM   123329 non-null  object
#  1   ITEM_NAME  123329 non-null  object
# dtypes: object(2)
# memory usage: 1.9+ MB

# %%
#deleting original dataframe to free memory
del df

# %%
# Create a list of transaction
grouped['ITEM_NAME']= grouped['ITEM_NAME'].apply(lambda x: x.split(','))

# %%
grouped.head()
# Out:
#         INVC_NUM                                          ITEM_NAME
# 0  1-14159855793                               [SR-SC-PV-Maint-Gen]
# 1  1-14167579557                        [5285612, 5319245, 5349496]
# 2  1-14291359880  [3978040, 3954904, 3329289, 3889311, 3889310, ...
# 3  1-14301892747  [KIT3238535, 4371769, 4352578, 4376512, 302307...
# 4  1-14327191570                                          [4926654]

# %%
grouped.shape
# Out:
# (123329, 2)

# %%
grouped = grouped.iloc[0:3000]
#grouped = grouped.iloc[0:2000]

# %% [markdown]
# ### Now for JC data

# %%
df = pd.read_csv('JC_2022.csv',encoding="cp1252")
df2 = df[['Invoice Number','ITEM_NUMBER']]

# %%
df2 = df2.astype({"Invoice Number": str})
df2 = df2.astype({"ITEM_NUMBER": str})

# %%
grouped2 = df2.groupby('Invoice Number')['ITEM_NUMBER'].apply(','.join).reset_index()

# %%
grouped2.head()
# Out:
#   Invoice Number          ITEM_NUMBER
# 0  1-13849074703  AX1001912,AX1008223
# 1  1-13849074714            AX1001907
# 2  1-13855034946            AX1001912
# 3  1-13855034953            AX1001907
# 4  1-13861233910  AX1008626,AX1008224

# %%
#deleting original dataframe to free memory
del df

# %%
grouped2['ITEM_NUMBER']= grouped2['ITEM_NUMBER'].apply(lambda x: x.split(','))

# %%
grouped2.head()
# Out:
#   Invoice Number             ITEM_NUMBER
# 0  1-13849074703  [AX1001912, AX1008223]
# 1  1-13849074714             [AX1001907]
# 2  1-13855034946             [AX1001912]
# 3  1-13855034953             [AX1001907]
# 4  1-13861233910  [AX1008626, AX1008224]

# %%
grouped2.shape
# Out:
# (90893, 2)

# %%
grouped2 = grouped2.iloc[0:3000]

# %%
grouped2 = grouped2.rename(columns={'Invoice Number':'INVC_NUM','ITEM_NUMBER':'ITEM_NAME'})

# %%
grouped2.head()
# Out:
#         INVC_NUM               ITEM_NAME
# 0  1-13849074703  [AX1001912, AX1008223]
# 1  1-13849074714             [AX1001907]
# 2  1-13855034946             [AX1001912]
# 3  1-13855034953             [AX1001907]
# 4  1-13861233910  [AX1008626, AX1008224]

# %% [markdown]
# ### Cobining both transactions

# %%
grouped = pd.concat([grouped,grouped2])

# %%
grouped.shape
# Out:
# (6000, 2)

# %%
# Convert the transaction list from a DataFrame column into a list of strings
transactions = list(grouped['ITEM_NAME'])

# %%
transactions
# Out:
# [['SR-SC-PV-Maint-Gen'],
#  ['5285612', '5319245', '5349496'],
#  ['3978040', '3954904', '3329289', '3889311', '3889310', '3879488'],
#  ['KIT3238535',
#   '4371769',
#   '4352578',
#   '4376512',
#   '3023079',
#   '4952020',
#   '3880282',
#   '130083',
#   '3018889',
#   '3167836',
#   'AK16022  6MC',
#   'AK16027   NF',
#   '217302',
#   '3818271',
#   '132770',
#   '3235591',
#   '3002834',
#   '203131',
#   '165006',
#   '3006696',
#   '207233',
#   '207378',
#   '135675',
#   '186780',
#   '206224',
#   '168306'],
#  ['4926654'],
#  ['A053N752', 'A044X404'],
#  ['3238666', '0149-2967', '0122-0962', '3816986', '506924'],
#  ['AX1014429'],
#  ['AX1014429'],
#  ['3931063', '4093731', '5285612', '4315238', '4315239', '3816986', '505441'],
#  ['4093731', '3931063', '4315238', '4315239'],
#  ['AX1014236'],
#  ['505441', '4926654', '4093731', '3931063'],
#  ['0149-2967', '4982627', '3238666', '3816986', '506924'],
#  ['AX1014429'],
#  ['3238667', '4104821', '4962810', '3401544'],
#  ['0122-0922', '4093731', '0140-4088', '506924', '3816986'],
#  ['506924', '0122-0922', '4093731', '0140-4088', '3816986'],
#  ['0149-2967', '0122-0962', '3238666'],
#  ['3401544',
#   '4104821',
#   '4962810',
#   'AX1013359',
#   '0149-2967',
#   '0122-0962',
#   '3238666',
#   'A054G527',
#   '506655'],
#  ['3238668'],
#  ['4093731',
#   '3931063',
#   '5285612',
#   '4926654',
#   '4315238',
#   '4315239',
#   '506655',
#   'AX1013359'],
#  ['0149-2967', '4982627', '3238666', '3816986'],
#  ['3915489',
#   '4080720',
#   '3936583',
#   'AX1005068',
#   'A044F796',
#   '4093731',
#   '5285612',
#   '3931063',
#   '3238666',
#   '505441'],
#  ['3329289', '3889310', '3889311', '3827423', '3238665', '506655'],
#  ['0300-6014'],
#  ['4093731', '5285612', '3931063', '3238666', '3816986', '505441'],
#  ['0122-0961', '0149-2952', '0140-4088', '3816986', '506923'],
#  ['3936594', '3936583', '4080720', '3915489', '3935319', 'AX1005068'],
#  ['3329289', '3889310', '3889311', '4072352', '3238665', '4926654', '506655'],
#  ['4093731',
#   '505441',
#   '5285612',
#   '3931063',
#   '3814312',
#   '3814313',
#   '4926654',
#   'AX1013359'],
#  ['4093731',
#   '5285612',
#   '3931063',
#   '3814312',
#   '3814313',
#   'AX1013359',
#   '4926654',
#   '505441'],
#  ['4093731',
#   '5285612',
#   '3931063',
#   '3814312',
#   'AX1013359',
#   '4926654',
#   '505441'],
#  ['5285612', '4093731', '3931063', '3814312', '505441'],
#  ['5285612', '3931063', '4093731', '3814312', '4926654', '505441'],
#  ['5285612', '4093731', '3931063', '3238666', '4926654', '505441'],
#  ['5285612', '3931063', '4093731', '3238666', '4926654', '505441'],
#  ['0122-0962', '3238666', 'AX1013358', '3816986', '506924'],
#  ['RSK2001', '051-01049'],
#  ['A042L017', 'A042L016', 'A042L021', 'A042L022'],
#  ['4926654'],
#  ['3814313', 'AX1013359'],
#  ['3814313', 'AX1013359'],
#  ['AX1013359'],
#  ['AX1013359', '4926654'],
#  ['AX1001368', '4926654'],
#  ['3814313'],
#  ['5285612'],
#  ['5621847',
#   '5263529',
#   '4954905',
#   '4383933',
#   '3883284',
#   '179901',
#   '3936583',
#   '3921231',
#   '179903',
#   'AK 8080   MS',
#   '5313861',
#   '5594276'],
#  ['0122-0922', '4093731', '0140-4088', '506924', '3816986'],
#  ['0149-2967', '3238666', '0122-0962', '3816986', '506924'],
#  ['0149-2967', '0122-0962'],
#  ['AX1014429'],
#  ['3889310',
#   '3889311',
#   '3329289',
#   '3827423',
#   '3238665',
#   '4926654',
#   'AX1013359',
#   '506655'],
#  ['3238666', '3816986', '4982627', '0149-2967', '506924', 'A044F796'],
#  ['0149-2967', '506924', '0122-0962'],
#  ['AX1014236'],
#  ['4982627'],
#  ['0205-0390'],
#  ['5469225', '0193-0430-01', 'A044F796', '4982627', '0149-2967'],
#  ['4025270', '3941786', '3938160'],
#  ['3816986'],
#  ['3238493', '3238204', '3879488'],
#  ['0122-0961',
#   '0149-2952',
#   '3816986',
#   '0140-4088',
#   '506923',
#   '0110-4165',
#   'A044X404'],
#  ['0122-0922', '4093731', '0140-4088', '506924', '3816986'],
#  ['3238493', '3238204', '3879488', '3238665', '504626', '3167224'],
#  ['3931063', '4093731', '5285612', '4315238', '4315239', '505441'],
#  ['AX1014236'],
#  ['AX1001368', '0122-0962', '4926654', 'AX1013359', '506924', '3238666'],
#  ['4093731', '505441', '3931063', '5285612'],
#  ['0122-0922', '4093731', '506924', '3816986'],
#  ['4093731', '3931063', '5285612', '3816986', '505441'],
#  ['3973232',
#   '3973233',
#   '3401544',
#   'A041R273',
#   'A041R279',
#   '3816986',
#   '505441'],
#  ['0122-0922', '4093731', '0140-4088', '3816986', '506924'],
#  ['4982627', '0149-2967', '3238666', '506924'],
#  ['3238493',
#   '3238204',
#   '3238665',
#   '3879488',
#   'AX1006288',
#   '3167224',
#   'AX1013359'],
#  ['AX1014429'],
#  ['505441', '5285612', '4926654', '4093731', '3931063', '3238666'],
#  ['A044F796', '4080741'],
#  ['0327-1617-01'],
#  ['3401544', '3973232', '3973233', '3827423', '505441'],
#  ['AX1014429'],
#  ['3238204', '3879488', '3238493'],
#  ['4093731', '3931063', '5285612', '505441'],
#  ['4897898',
#   '3978040',
#   '3954904',
#   'A042M071',
#   'A042M070',
#   '3816986',
#   '505441'],
#  ['AX1002172', '0132-0528', '3816986', 'A057Y933'],
#  ['3401544', '4104821', '4962810', '505441', '506924', '3238667'],
#  ['3816986', 'AX1013359'],
#  ['3238493', '3879488', '3238204', '3238665', '3167224'],
#  ['AX1014236'],
#  ['4962810', '4104821', '3401544', '3167222', '505441', '506924'],
#  ['3240743'],
#  ['3973232', '3973233', '3401544', '3816986', '505441', '506924'],
#  ['3973233', '3973232', '3401544', '3827423', '505441'],
#  ['4926654'],
#  ['3329289'],
#  ['4962810', '3401544'],
#  ['AX1014236'],
#  ['0155-4659',
#   'A044F796',
#   '0140-4213',
#   '0155-4807',
#   'A048M259',
#   'AX1014429',
#   '3401544',
#   '3973232',
#   '3973233',
#   'A041R273',
#   'A041R279',
#   '4926654',
#   '3403800',
#   '505441'],
#  ['0122-0922', '0149-2967', '0140-4088', '3816986', '506924'],
#  ['AX1014236'],
#  ['AX1014429'],
#  ['3931063', '4093731', '5285612', '505441', '3816986'],
#  ['4982627', '0149-2967', '3238666', '3816986', '506924'],
#  ['4093731', '3931063', '5285612', '3816986', '505441', '4315238', '4315239'],
#  ['3973232', '3973233', 'A041R273', 'A041R279', '3401544', '506655'],
#  ['4315238', '4315239', '4093731', '3931063', '5285612', '3816986', '505441'],
#  ['506924', '4093731', '0122-0922', 'A034P660', 'A034P656', '3816986'],
#  ['3973232',
#   '3973233',
#   'A041R279',
#   'A041R273',
#   '3401544',
#   '3816986',
#   '505441'],
#  ['AX1014429'],
#  ['3938160', '5405392'],
#  ['4093731', '0122-0922', '3816986', '0140-4088', '506924'],
#  ['4093731', '0122-0922', '0140-4088', '3816986', '506924'],
#  ['506924',
#   '505441',
#   '4093731',
#   '3931063',
#   '5285612',
#   '0149-2967',
#   '4982627',
#   '3816986'],
#  ['5285612', '4093731', '3931063'],
#  ['4897898'],
#  ['3329289', '3889310', '3889311', '3827423', '3238665'],
#  ['4926654'],
#  ['0149-2967', '0122-0962', '3816986', '3238666', '506924'],
#  ['CSEL00155'],
#  ['0122-0922', '4093731', '3816986', '0140-4088', '506924'],
#  ['4315238', '4315239', '4093731', '3931063', '5285612', '3816986', '505441'],
#  ['3283570', '3930906'],
#  ['A034P660',
#   'A034P656',
#   '0122-0949',
#   '3827423',
#   '0503-3163-03',
#   'A051P670',
#   '3054609'],
#  ['CSEL0043'],
#  ['0132-0528', '4926654'],
#  ['4078701'],
#  ['4897898',
#   '3978040',
#   '3954904',
#   'A042M070',
#   'A042M071',
#   '3816986',
#   '506924',
#   'AX1013359'],
#  ['4962810', '3401544', '3827423'],
#  ['0122-0922', '4093731', '0140-4088', '506924', '3816986'],
#  ['506924', '0149-2967', '4982627', '3816986', '3238666'],
#  ['5285612', '4093731', '3931063', '3238666', '505441', '3816986'],
#  ['0122-0922', '4093731', '506924'],
#  ['0149-2967', '0122-0922', '0140-4088', '3816986', '506924', 'AX1014429'],
#  ['4926654'],
#  ['4982627', '0149-2967', '3238666', '3816986', '506924'],
#  ['4926654'],
#  ['3238667', '4962810'],
#  ['3238666', '4093731', '3931063', '5285612', '505441', '3816986', '3403800'],
#  ['A054G527', '0193-0430-01'],
#  ['A054G527', 'A044F794'],
#  ['AX1006288'],
#  ['506924', '4982627', '3238666', '0149-2967'],
#  ['4093731', '0122-0922', '3816986', '506924'],
#  ['4315238', '4315239', '4093731', '3931063', '5285612', '3816986', '505441'],
#  ['5285612',
#   '4093731',
#   '3931063',
#   '3816986',
#   '4315238',
#   '4315239',
#   '505441',
#   '5469225'],
#  ['4093731', '3931063', '5285612', '3238666', '3816986', '505441'],
#  ['4093731',
#   '5285612',
#   '3931063',
#   '3238666',
#   '505441',
#   '3816986',
#   'AX1005068'],
#  ['A054G527'],
#  ['4926654'],
#  ['4962810', '3401544', '4104821', '3238668', '3167222', '505441'],
#  ['5311736', '4926654'],
#  ['0149-2967', '0122-0962', '3238666', '506924', '3816986'],
#  ['3816986'],
#  ['4897898',
#   '3978040',
#   '3954904',
#   'A042M070',
#   'A042M071',
#   '4926654',
#   '505441'],
#  ['505441', '5285612', '4093731', '3931063', '3238666', '4926654'],
#  ['4093731',
#   '3931063',
#   '5285612',
#   '3238666',
#   '3936594',
#   '4080720',
#   'A044F796'],
#  ['3167218'],
#  ['4926654'],
#  ['3329289', '3889310', '3889311', '3827423', '506655'],
#  ['0193-0430-01',
#   'A034P660',
#   'A034P656',
#   '3816986',
#   '0122-0922',
#   '506924',
#   '4093731'],
#  ['4926654'],
#  ['3238493', '3879488', '3238204', '3238358', '3167222'],
#  ['0300-6014'],
#  ['3973232',
#   '3973233',
#   '3401544',
#   '3816986',
#   'A041R273',
#   'A041R279',
#   '505441'],
#  ['3816986'],
#  ['3238666'],
#  ['4926654'],
#  ['4093731', '0122-0922', '3816986', '506924', 'A034P656', 'A034P660'],
#  ['5285612', '4093731', '3931063', '3238666', '505441'],
#  ['AX1012844'],
#  ['3329289', '3889310', '3889311', '3827423', '3238665', '3816986', '506655'],
#  ['AX1014236', '4926654'],
#  ['3238666', '0149-2967', '4982627', '3816986', '506924'],
#  ['3978040', '3816986', '3954904', '4897898', '505441'],
#  ['506924', '4093731', '0140-4088', '0122-0922'],
#  ['3238493',
#   '3238358',
#   '3238204',
#   '4345001',
#   '4344509',
#   '3401544',
#   '3827423',
#   '4957708',
#   '4957709',
#   '4093731',
#   '3931063',
#   '5285612',
#   '3238666'],
#  ['A054G527'],
#  ['0122-0922',
#   '4093731',
#   'A034P660',
#   'A034P656',
#   '3816986',
#   '506924',
#   '5285612',
#   '3238666',
#   '3931063',
#   '505441'],
#  ['4093731',
#   '3931063',
#   '5285612',
#   '4315238',
#   '4315239',
#   '4926654',
#   '505441',
#   '0122-0922',
#   '506924',
#   '3816986',
#   '0140-4088'],
#  ['4926654'],
#  ['4982627', '0149-2967', '3238666', '3816986', '506924'],
#  ['0149-2952', '0122-0961', '0140-4088'],
#  ['AX1014429'],
#  ['3973232',
#   '3973233',
#   '3401544',
#   '3827423',
#   'A041R273',
#   'A041R279',
#   '505441',
#   '4926654'],
#  ['0122-0922', '4093731', '0140-4088', '506923'],
#  ['A041N614'],
#  ['3973232', '3973233', '3401544', '505441'],
#  ['3329289', '3889310', '3889311', '3238665', '4926654', '3827423'],
#  ['KIT3238075'],
#  ['A055G562'],
#  ['4093731', '0122-0922', '0140-4088', '3816986', '506924'],
#  ['4093731', '0122-0922', '0140-4088', '506924'],
#  ['4897898',
#   '3978040',
#   '3954904',
#   '4926654',
#   '3238666',
#   '4093731',
#   '3931063',
#   '5285612',
#   'A042M070',
#   'A042M071'],
#  ['4926654'],
#  ['AX1014429'],
#  ['3401544',
#   '3973232',
#   '3973233',
#   'A041R273',
#   'A041R279',
#   '4926654',
#   '505441'],
#  ['5285612',
#   '3978040',
#   '3954904',
#   '3403800',
#   '4315238',
#   '4315239',
#   '4926654',
#   '505441'],
#  ['4093731', '0122-0922', '0140-4088', '3816986', '506924'],
#  ['505441', '506924', '4897898', '3978040', '3954904', 'A042M070', 'A042M071'],
#  ['0149-2967', '0122-0962', '0140-4088', '3816986', '506924'],
#  ['506924', '3238666', '0149-2967', '3816986', '4982627'],
#  ['AX1012843'],
#  ['3401544',
#   '3973232',
#   '3973233',
#   'A041R273',
#   'A041R279',
#   '3403800',
#   '4926654',
#   '505441'],
#  ['A054G527'],
#  ['505441', '4897898', '3978040', '3954904', '3816986'],
#  ['A042M070', 'A042M071'],
#  ['4897898',
#   '3978040',
#   '3954904',
#   '4926654',
#   'A042M070',
#   '505441',
#   'AX1013359'],
#  ['A042M071'],
#  ['4926654'],
#  ['5285612', '4093731', '3931063', '4315238', '4315239'],
#  ['4982627', '0149-2967', '3403800', '3238666', '4926654', '506924'],
#  ['RSK2001',
#   '506924',
#   '0149-2967',
#   '0122-0922',
#   '3238666',
#   'AX1013359',
#   '4926654',
#   'A054G527'],
#  ['506924', '0122-0949', 'AX1001368', '3816986'],
#  ['4982627', '0149-2967', '3816986', '3238666', '506924'],
#  ['A054K669'],
#  ['4093731', '3931063', '5285612', '505441'],
#  ['0193-0430-01'],
#  ['3401544', '4962810'],
#  ['4093731', '3931063', '505441'],
#  ['4093731', '5285612', '3931063', '4315238', '4315239', '4926654', '505441'],
#  ['504626'],
#  ['A044F796', '5469225'],
#  ['A044F796'],
#  ['3238666', '0149-2967', '4982627', '3816986', '506924'],
#  ['AX1012845'],
#  ['4093731', '0122-0922', 'A034P660', 'A034P656', '3816986', '506924'],
#  ['A054G527'],
#  ['0149-2967', '0122-0962', '3238666', '3816986', '506924'],
#  ['4093731',
#   '5285612',
#   '3931063',
#   '3238666',
#   '3915489',
#   '3816986',
#   '506924',
#   '4080720'],
#  ['KIT3238075'],
#  ['3329289', '3889310', '3889311', '3827423', '3238665', '4926654', '506655'],
#  ['A040W113', '4327015', '4926654'],
#  ['3238204', '3238493', '3879488'],
#  ['4330737'],
#  ['4093731',
#   '5285612',
#   '3931063',
#   '4315238',
#   '4315239',
#   '0122-0922',
#   '0140-4088',
#   '3816986',
#   '505441',
#   '506924'],
#  ['506924'],
#  ['0149-2967', '0122-0962', '3238666', '3816986', '506924'],
#  ['3930906'],
#  ['4093731', '5285612', '3931063', '3238666', '3816986', '505441'],
#  ['0193-0610',
#   '0149-2828',
#   '0149-2967',
#   '0149-2827',
#   '0140-4088',
#   '3978040',
#   '4897898',
#   'A048M259',
#   '3238204',
#   '0122-0922',
#   '4982627'],
#  ['0193-0430-01', '4926654'],
#  ['3816986', '4093731', '0122-0922', '0140-4088', '506924'],
#  ['3238665'],
#  ['3329289', '3889310', '3889311', '3827423', '3238665', '506655'],
#  ['0122-0961', '0149-2952', '0140-4088', '3816986', '506924'],
#  ['4982627', '0149-2967', '3816986', '3238666', '506924'],
#  ['5469225', '3922900', '67185', '4926654'],
#  ['AX1012843'],
#  ['3329289', '3889311', '3889310', '3827423', '3238665', '4926654', '506655'],
#  ['3286503', '5285612', '4926654', '3238666', '505441'],
#  ['4093731', '5285612', '3931063', '4926654', '4315238', '4315239', '505441'],
#  ['0122-0922', '0149-2967', '3816986', '506924'],
#  ['AX1012845'],
#  ['AX1012845'],
#  ['3238204', '3238493', '3879488', '3167217', '3238358', 'CSFREIGHT1'],
#  ['504626'],
#  ['3889310', '3889311', '3329289', '3238665', '4926654', '3872813', '3403800'],
#  ['0122-0922',
#   '4093731',
#   '0140-4088',
#   'A048M259',
#   '506924',
#   '3816986',
#   '3403800',
#   'CSFREIGHT1'],
#  ['0149-2967',
#   '4982627',
#   '3238666',
#   '506924',
#   '3403800',
#   'A048M259',
#   '0140-4323-02',
#   'CSFREIGHT1'],
#  ['0149-2967', '4982627', 'A048M259', '3238666', '506924', '3816986'],
#  ['504626', 'AX1013508', '3167224'],
#  ['4020551',
#   '4020552',
#   '506655',
#   '3238204',
#   '3879488',
#   '3167226',
#   '3872813',
#   '3167218',
#   'CSFREIGHT1',
#   '3238493'],
#  ['0122-0922',
#   '0149-2967',
#   'A048M259',
#   '3403800',
#   '506924',
#   '3816986',
#   'CSFREIGHT1'],
#  ['A031B113'],
#  ['0149-2828', '0149-2827', '0122-0922', '506924'],
#  ['4982627',
#   '0149-2967',
#   '3238666',
#   '3816986',
#   '506924',
#   'A048M259',
#   '0140-4323-02',
#   'CSFREIGHT1'],
#  ['4368800', '5259022', '3289124', '3282433'],
#  ['AX1012843', 'CSFREIGHT'],
#  ['AX1014236', '3816986', 'CSFREIGHT1'],
#  ['AX1012845', 'CSFREIGHT'],
#  ['4104821', '3401544', '3329289', '3238358', '506655'],
#  ['5285612',
#   '4093731',
#   '3931063',
#   '4315238',
#   '4315239',
#   '4080720',
#   '4926654',
#   '3872813',
#   'CSFREIGHT1',
#   '3403800'],
#  ['504626', 'CSFREIGHT1'],
#  ['0149-2967',
#   '4982627',
#   '3238666',
#   '3403800',
#   '3872813',
#   '3816986',
#   'CSFREIGHT1'],
#  ['5285612',
#   '4926654',
#   '3872813',
#   'CSFREIGHT1',
#   '5319245',
#   '5349496',
#   '3403800',
#   '3238666'],
#  ['5345253',
#   '4982846',
#   '4982847',
#   '4982908',
#   '4982899',
#   '4982907',
#   '4982909',
#   '4926654',
#   '3816986',
#   'A044V616',
#   '3800884',
#   '4982115',
#   '4982218',
#   '4982198',
#   '4944155',
#   'C6204111840',
#   '4982951',
#   '4982960',
#   '4944175',
#   '0155-4778',
#   '3931904',
#   '4982627',
#   '0149-2967',
#   '3238666',
#   '506924',
#   'CSFREIGHT1'],
#  ['3200977', 'A028X493', 'CSFREIGHT1'],
#  ['3931063',
#   '4093731',
#   '4315238',
#   '4315239',
#   '4926654',
#   '505441',
#   '5285612',
#   '0140-4323-02',
#   '4080720',
#   'CSFREIGHT1'],
#  ['0115-0590',
#   '0860-2142',
#   '0115-0583',
#   'A046X053',
#   '0110-4164',
#   'AX1001368',
#   '0122-0961',
#   '0140-4088',
#   '506924',
#   '3816986',
#   'CSFREIGHT1',
#   '0541-1751'],
#  ['4926654'],
#  ['0541-1731', 'CSFREIGHT1'],
#  ['0193-0529-02', '3289124', 'CSFREIGHT1'],
#  ['AX1012843', 'CSFREIGHT'],
#  ['5370391'],
#  ['A044F796', 'CSFREIGHT'],
#  ['3889310',
#   '3238665',
#   '3889311',
#   '3329289',
#   '4058965',
#   '3403800',
#   '178517',
#   '4926654'],
#  ['3978040',
#   '4343955',
#   '4897898',
#   'A042M070',
#   'A042M071',
#   '3403800',
#   '4926654',
#   '0140-4323-02',
#   'CSFREIGHT1',
#   '3979344',
#   '504626'],
#  ['0503-3155-01', '0503-3170', '0503-3214', '0140-4088'],
#  ['0503-3178', '0503-3179'],
#  ['4093731',
#   '5285612',
#   '5319245',
#   '4926654',
#   '4080720',
#   '505441',
#   '3403800',
#   'CSFREIGHT1'],
#  ['CSFREIGHT', 'AX1012843'],
#  ['4093731',
#   '0122-0922',
#   '0140-4088',
#   'A048M259',
#   '3403800',
#   '0140-4323-02',
#   '506924'],
#  ['3238204', '3238493', '3879488', '3167218'],
#  ['A054G527',
#   '0193-0666',
#   '0193-0610',
#   '0193-0529-02',
#   '0338-5325',
#   '0338-5350',
#   'A051L764',
#   'A030Y174',
#   '0307-3190',
#   'CSFREIGHT1'],
#  ['0149-2828', '0149-2827', '0122-0922', '3816986', '506923', 'CSFREIGHT1'],
#  ['4950317', 'CSFREIGHT1'],
#  ['4926654', 'CSFREIGHT1'],
#  ['0140-4088',
#   '0149-2967',
#   '0122-0962',
#   '506924',
#   '3403800',
#   '0140-4323-02',
#   '3816986',
#   'CSFREIGHT1'],
#  ['0338-5325', 'CSFREIGHT1'],
#  ['4093731',
#   '0122-0922',
#   '3403800',
#   'A048M259',
#   '506924',
#   'CSFREIGHT1',
#   '0140-4088'],
#  ['4093731',
#   '3931063',
#   '5285612',
#   '4315238',
#   '4315239',
#   '4926654',
#   '505441',
#   '3403800',
#   '0140-4323-02',
#   'CSFREIGHT1',
#   '4080741',
#   'A056C664'],
#  ['3889310',
#   '3889311',
#   '3329289',
#   '4058965',
#   '4926654',
#   '506655',
#   '3872813',
#   '3238665',
#   '3403800',
#   'CSFREIGHT1'],
#  ['4080743'],
#  ['A053N752'],
#  ['4093731', '0122-0922', '0140-4088', '506924', 'A048M259', 'CSFREIGHT1'],
#  ['3238204', '3238493', '3879488', '3238358', 'CSFREIGHT1'],
#  ['AX1001368',
#   '0122-0949',
#   '4926654',
#   'AX1013358',
#   '506924',
#   '0140-4088',
#   'CSFREIGHT1',
#   '0140-4323-02'],
#  ['3238666', '0149-2967', '0122-0962', '3872813', 'A048M259', 'CSFREIGHT1'],
#  ['A047C312', 'A047D772', 'A044F796', 'CSFREIGHT1'],
#  ['0122-0922', '0149-2828', '0149-2827'],
#  ['4093731', '0122-0922', '506924', 'CSFREIGHT1', '3403800'],
#  ['506924'],
#  ['0149-2967',
#   '0122-0962',
#   '3238666',
#   '3816986',
#   '506924',
#   '3403800',
#   '0140-4323-02',
#   'CSFREIGHT1'],
#  ['3915489',
#   '3918192',
#   '3936583',
#   '3938152',
#   '3906697',
#   '5469225',
#   '4980085',
#   '3900955',
#   '4080672',
#   '3905443',
#   '3931904',
#   '3901448',
#   '3918188',
#   '43828    A',
#   '3282113',
#   '0503-3164',
#   '0503-3165',
#   '0503-2923',
#   '0503-3094',
#   'CSFREIGHT1'],
#  ['4328043', 'CS-P&F2', 'CS-F&D2'],
#  ['0122-0922',
#   '4093731',
#   '3816986',
#   'A048M259',
#   '0140-4088',
#   '506924',
#   '3872813',
#   'CSFREIGHT1'],
#  ['0121-0258', 'CSFREIGHT'],
#  ['0503-3165', '0503-3164', 'CSFREIGHT1'],
#  ['CS4993834'],
#  ['3238204', '3238493', '3879488', '4072352', '3167217'],
#  ['4093731',
#   '3931063',
#   '3937743',
#   '5285612',
#   '4080720',
#   '3403800',
#   '4315238',
#   '4315239',
#   '3238666',
#   'CSFREIGHT1',
#   '0140-4323-02'],
#  ['5319245',
#   '5349496',
#   '5285612',
#   '4080720',
#   '3238666',
#   '3403800',
#   '0140-4323-02',
#   'CSFREIGHT1'],
#  ['3408326'],
#  ['3238204', '3238493', '3879488'],
#  ['0193-0610', 'CSFREIGHT'],
#  ['3238203',
#   '3238358',
#   '4055584',
#   '4020551',
#   '4020552',
#   '3238493',
#   '3238204',
#   '3238452',
#   '504395',
#   '504975',
#   '3001600',
#   'AK 5033   SS',
#   '0309-0714'],
#  ['4093731', '3931063', '3937743', '4080720', '505441', '4926654', '3238666'],
#  ['3010937', '3392445', '3020183'],
#  ['0122-0922', '4093731', '506924', '3403800'],
#  ['3816986', 'CSFREIGHT1'],
#  ['3067459',
#   '3017750',
#   '3014778',
#   '3166307',
#   '145504',
#   '3067613',
#   '3036666',
#   '3037537',
#   '3076203',
#   '215705',
#   '4058949',
#   '3020185'],
#  ['3931063',
#   '3937743',
#   '4093731',
#   '3403800',
#   '3872813',
#   '505441',
#   '4080720',
#   '3238666',
#   'CSFREIGHT1'],
#  ['3238204', '3238493', '3879488', 'CSFREIGHT1'],
#  ['4982227'],
#  ['AX1014429', 'CSFREIGHT'],
#  ['CSF002A10732', 'CS26241170', 'CS4H15030', 'CS5469717', 'CS26241440'],
#  ['3978040',
#   '4343955',
#   '4897898',
#   'A042M070',
#   'A042M071',
#   '4926654',
#   'CSFREIGHT1',
#   '505441',
#   '506923'],
#  ['AX1001368', '0122-0949', '3816986', '506924', '3238666', 'CSFREIGHT1'],
#  ['5285612', '3978040', '3329289', '3238667', '505441'],
#  ['AX1012844', 'CSFREIGHT'],
#  ['KIT3238180', '3167218', 'CSFREIGHT1'],
#  ['3973232', '3973233'],
#  ['504626', 'CSFREIGHT1'],
#  ['3017993', '4958277', 'CSFREIGHT1'],
#  ['4093731',
#   '0122-0922',
#   'A034P660',
#   'A034P656',
#   'A048M259',
#   '506924',
#   '3816986',
#   '0193-0430-01',
#   'CSFREIGHT1',
#   '3403800'],
#  ['0140-4088'],
#  ['3167224', 'AX1013508', 'CSFREIGHT1'],
#  ['A028X493'],
#  ['3238204', '3238493', '3879488'],
#  ['0149-2952',
#   '0122-0961',
#   '3816986',
#   '506924',
#   '0140-4088',
#   'CSFREIGHT1',
#   '3403800'],
#  ['AX1012843', 'CSFREIGHT'],
#  ['3329289', '4096196', '4072352', '4020551', '4020552', 'CSFREIGHT1'],
#  ['4083935', 'CSFREIGHT1'],
#  ['AX1014429', 'CSFREIGHT'],
#  ['0122-0922',
#   '4093731',
#   '0140-4088',
#   '3816986',
#   '3403800',
#   '506924',
#   'CSFREIGHT1'],
#  ['AX1012845', 'CSFREIGHT'],
#  ['AX1012900', 'CSFREIGHT'],
#  ['3238204', '3238493', '3238358'],
#  ['0122-0922', '0149-2828', '0149-2827', '0140-4088', 'CSFREIGHT1'],
#  ['4926654', '3816986'],
#  ['4344509',
#   '4345001',
#   '3401544',
#   '4058965',
#   '506655',
#   '4957708',
#   '4957709',
#   '4926654',
#   'CSFREIGHT1'],
#  ['506655', 'CSFREIGHT1'],
#  ['0509-0563', 'A050X709', 'A046V060'],
#  ['0149-2828',
#   '0122-0922',
#   '0149-2827',
#   '0140-4088',
#   '3816986',
#   '3403800',
#   'CSFREIGHT1'],
#  ['4093731',
#   '3931063',
#   '3937743',
#   '4080720',
#   '3238666',
#   '505441',
#   'CSFREIGHT1'],
#  ['3238204',
#   '3238493',
#   '3879488',
#   '3167218',
#   '3872813',
#   '3167226',
#   'CSFREIGHT1',
#   'CSSER82.5TO250'],
#  ['3238204',
#   '3879488',
#   '3238493',
#   '3167218',
#   '3872813',
#   'CSSER82.5TO250',
#   'CSFREIGHT1',
#   '3167226'],
#  ['3329289',
#   '3889310',
#   '3889311',
#   '4058965',
#   '3238665',
#   '3403800',
#   '3872813',
#   '4926654',
#   'CSFREIGHT1'],
#  ['3931063',
#   '3937743',
#   '4080720',
#   '3403800',
#   '3872813',
#   '3238666',
#   '4926654',
#   'CSFREIGHT1',
#   '4093731'],
#  ['4345001', '4344509', '4926654', 'CSFREIGHT1'],
#  ['3238203', 'CSFREIGHT1'],
#  ['3931904', '4926654'],
#  ['0193-0610', 'CSFREIGHT'],
#  ['4982627',
#   '0149-2967',
#   'A048M259',
#   '4926654',
#   '506924',
#   '3238666',
#   '3403800',
#   'CSFREIGHT1'],
#  ['3238204', '3238493', '504626'],
#  ['AX1013235'],
#  ['3889310', '3889311', '3329289', '4072352', '3403800', '4926654', '505441'],
#  ['0327-1617-01', 'CSFREIGHT1'],
#  ['3238543', '3238667', 'KIT3238217', '0300-6014', 'CSFREIGHT1'],
#  ['506655', '3167218', 'AX1013359', 'CSFREIGHT1'],
#  ['3238543', '0300-6014', '67185    H', '3238668', '43828    D', 'CSFREIGHT1'],
#  ['0110-4152',
#   '0110-4167',
#   '0110-4183',
#   '0110-4169',
#   '0110-4174',
#   '0110-4175',
#   '0541-1729',
#   '0406-1245',
#   '0509-0573',
#   '0502-1737',
#   '0112-0351',
#   '0112-0350',
#   '3931904',
#   '0110-4013',
#   'AX1002172',
#   'A057Y933',
#   'A040G639',
#   '0130-8415',
#   '4027490',
#   '0509-0561',
#   '3924147',
#   '0105-0791',
#   '0503-3207',
#   '0503-3155-01',
#   '0503-3178',
#   '0503-3179',
#   '43828    B',
#   '43828    A',
#   '0110-4015',
#   '0503-3203',
#   '0503-3153',
#   '0503-2926',
#   '0503-3151',
#   '0193-0666',
#   '506924',
#   '0501-1092',
#   '0541-1763',
#   '0114-0461',
#   '0130-7998',
#   '0149-2946',
#   '0149-2947',
#   '0193-0659',
#   '0502-1624',
#   '0502-1625',
#   '0502-1629',
#   '0502-1734',
#   '0509-0505',
#   '0132-0528',
#   '3901249',
#   '3914868',
#   '3916069',
#   '3916361',
#   'A051L764',
#   'CSSPSOSSLEEV',
#   'CS02B10545',
#   'CS60042-97',
#   'CSEL000055',
#   'CS1411015097',
#   'CSEL001212',
#   'CS03044196',
#   'CSF002A50013',
#   'CS9441037000',
#   'CSFREIGHT1',
#   'CSPSSGASKET'],
#  ['4897898', '4343955', '3978040', '505441'],
#  ['3973232',
#   '3973233',
#   '4058965',
#   '3401544',
#   'A041R273',
#   'A041R279',
#   '505441',
#   '4926654',
#   'CSFREIGHT1'],
#  ['3167218'],
#  ['0300-6086', 'CSFREIGHT'],
#  ['4093731',
#   '0122-0922',
#   '0140-4088',
#   '3403800',
#   '0140-4323-02',
#   '3816986',
#   '506924',
#   'CSFREIGHT1'],
#  ['3167218', '3238204', '3238493', '3238358', '4105951', 'CSFREIGHT1'],
#  ['4093731', '0140-4088', '0122-0922'],
#  ['0503-3193',
#   '0503-3164',
#   '0503-3165',
#   '43828    C',
#   '43828    D',
#   '5469225',
#   '3978022',
#   '0327-1617-01',
#   'CSFREIGHT1'],
#  ['5417137', 'CS-P&F2', 'CS-F&D2'],
#  ['504395'],
#  ['504626', 'CSFREIGHT1'],
#  ['0122-0922', '0149-2967', '0122-0962'],
#  ['3691279', 'CS-P&F2', 'CS-F&D2'],
#  ['4056442', '4056441'],
#  ['3238493', '3238204', '3879488'],
#  ['A034W009'],
#  ['3238543', '505441', '506923', '3816986', 'CSFREIGHT1', '3403800'],
#  ['0503-3158'],
#  ['3875360'],
#  ['AX1002172'],
#  ['3179035'],
#  ['206416',
#   '206193',
#   '206457',
#   '206455',
#   '3007512',
#   '207515',
#   '206460',
#   '3629140',
#   '3040721',
#   '193736',
#   '3010510',
#   '207244',
#   '3001340',
#   '206277',
#   '3014304',
#   '3630742',
#   '3171368',
#   'RO3016676',
#   'RO3635807',
#   'RO2879737E488'],
#  ['3026395', '3014449', '3003016', '3175545', '3023066', '207244'],
#  ['3238204'],
#  ['A054G527'],
#  ['4072352'],
#  ['0193-0610'],
#  ['0149-2967',
#   '4982627',
#   '506924',
#   '3816986',
#   '3403800',
#   'A048M259',
#   '3238666'],
#  ['4093731',
#   '3931063',
#   '5285612',
#   '4080720',
#   '4315238',
#   '4315239',
#   '505441',
#   '4926654',
#   '3403800',
#   '0140-4323-02',
#   'CSFREIGHT1'],
#  ['3238204',
#   '3238493',
#   '3879488',
#   '4096196',
#   '3329289',
#   '4072352',
#   '3403800',
#   '3872813',
#   '504626',
#   '4095189',
#   '3889310',
#   '3889311',
#   '3167218',
#   '4926654',
#   'CSFREIGHT1'],
#  ['4926654', 'CSFREIGHT1'],
#  ['3978040',
#   '4343955',
#   '5285612',
#   '4315239',
#   '4315238',
#   '505441',
#   '4926654',
#   '3403800',
#   '3872813',
#   'CSFREIGHT1'],
#  ['5469225'],
#  ['3935319', 'CSFREIGHT'],
#  ['0193-0430-01', 'CSFREIGHT1'],
#  ['4093731', '3937743', '3931063', '3238667', '505441'],
#  ['3329289', '3889310', '3889311', '4072352', '3167218', '506655', '3238665'],
#  ['3238358'],
#  ['505441', '3238666'],
#  ['3238666'],
#  ['4093731', '5285612', '3931063', '4080720', '505441'],
#  ['A054G527', '0338-5322', 'CSFREIGHT1'],
#  ['3643839', 'CS-P&F2', 'CS-F&D2'],
#  ['0122-0922',
#   '0149-2967',
#   'A048M259',
#   '3403800',
#   '506924',
#   '3816986',
#   'CSFREIGHT1'],
#  ['4093731',
#   '5285612',
#   '3931063',
#   '4080720',
#   '4315238',
#   '4315239',
#   '3403800',
#   '3872813',
#   '4926654',
#   '505441',
#   'CSFREIGHT1'],
#  ['4383933', '3928832', 'CSFREIGHT1', '0300-6014'],
#  ['3238543', '506924', '505441', 'CSFREIGHT1'],
#  ['0149-2967', '4982627', '3238666'],
#  ['5285612', '4093731', '3931063', '4315238', '4315239'],
#  ['5285612', '5319245', '5349496', '3238666', 'A044F796'],
#  ['0193-0610'],
#  ['3403800',
#   '4982627',
#   '0149-2967',
#   '506924',
#   'A048M259',
#   '3816986',
#   'CSFREIGHT1'],
#  ['0149-2967', '4982627', 'A048M259', '506924', 'CSFREIGHT1'],
#  ['A062F623', 'CS-P&F2', 'CS-F&D2'],
#  ['3329289',
#   '4058965',
#   '3401544',
#   '3238358',
#   'AX1013358',
#   'AX1013508',
#   '3167218',
#   '3872813',
#   'CSFREIGHT1'],
#  ['3329289',
#   '3889310',
#   '3889311',
#   '4058965',
#   '4104832',
#   '43828    E',
#   '4104834',
#   '4104829',
#   'AK 5060   SS',
#   '4104828',
#   'CSFREIGHT1'],
#  ['4926654'],
#  ['5469225', '0503-3164', '0503-3165', '43828    D', '43828    C', '3816986'],
#  ['4982627',
#   '0149-2967',
#   '506924',
#   'A048M259',
#   '3403800',
#   '3816986',
#   'CSFREIGHT1'],
#  ['3084539'],
#  ['505441'],
#  ['4104829'],
#  ['4093731', '0122-0922', '0140-4088', '4926654', '505441'],
#  ['0122-0922',
#   '0149-2967',
#   'A048M259',
#   '3403800',
#   '506924',
#   'A034P656',
#   'A034P660',
#   'CSFREIGHT1'],
#  ['A063J172'],
#  ['A030X912', 'A030X917', 'CSFREIGHT1'],
#  ['4093731',
#   '3931063',
#   '5285612',
#   '4315238',
#   '4315239',
#   '3403800',
#   '4926654',
#   '505441',
#   'CSFREIGHT1'],
#  ['4093731',
#   '3931063',
#   '5285612',
#   '4080720',
#   '505441',
#   '3403800',
#   '3872813',
#   'CSFREIGHT1'],
#  ['5319245',
#   '5349496',
#   '5285612',
#   '4080720',
#   '505441',
#   '3238666',
#   'CSFREIGHT1'],
#  ['0149-2967',
#   '4982627',
#   '3816986',
#   '506924',
#   '3403800',
#   '3238666',
#   'CSFREIGHT1'],
#  ['3931063', '3937743', '4093731', '4080720', '505441', '4926654'],
#  ['0149-2967', '4982627'],
#  ['3047390',
#   '3175856',
#   '193736',
#   '207244',
#   '3069103',
#   '3046852',
#   '3010937',
#   '3001340',
#   '3084539',
#   '70295',
#   '216187',
#   '3879479',
#   'S   169    A',
#   '3167224',
#   '504626',
#   '3238204',
#   '3238493',
#   '3879488',
#   '3238665',
#   '206193',
#   '206455',
#   '3007512',
#   '3179035',
#   '206460',
#   '207515',
#   '3006089',
#   '3238277',
#   '4352580',
#   '4072352',
#   'CSFREIGHT1'],
#  ['70295'],
#  ['3879488', '3238493', '3238358', '3238204', 'CSFREIGHT1'],
#  ['3238358',
#   '3238204',
#   '3238493',
#   '3879488',
#   '3872813',
#   '3403800',
#   '3167217',
#   '180405'],
#  ['3401544', '3973232', '3973233', '4926654', 'CSFREIGHT1'],
#  ['3099083',
#   '4105874',
#   '194106',
#   '108692',
#   '504867',
#   'BM57272',
#   '178617',
#   '3166497',
#   '3037156',
#   '4105150',
#   'BM50745'],
#  ['504626', 'CSFREIGHT1'],
#  ['AX1001368', '0122-0949', '3238666', '3816986', '506924', 'CSFREIGHT1'],
#  ['3816986', 'CSFREIGHT1'],
#  ['BM98224', 'BM62431'],
#  ['3973232',
#   '3973233',
#   '3401544',
#   '3403800',
#   '3872813',
#   'A041R273',
#   'A041R279',
#   '4926654',
#   '505441',
#   'CSFREIGHT1'],
#  ['0503-3178',
#   '0503-3153',
#   '0503-3155-01',
#   '0503-3179',
#   '0511-0260',
#   '0193-0610',
#   'CSFREIGHT1'],
#  ['4926654', 'CSFREIGHT1'],
#  ['3889310', '3889311', '3329289', '4058965', '3238665'],
#  ['3179035'],
#  ['3889310',
#   '3889311',
#   '3329289',
#   '4058965',
#   '4926654',
#   '506655',
#   'CSFREIGHT1'],
#  ['A054G527', '0338-5322', 'CSFREIGHT1'],
#  ['3018888'],
#  ['3401544',
#   '3973232',
#   '3973233',
#   'A041R273',
#   'A041R279',
#   '4926654',
#   '3403800',
#   'CSFREIGHT1'],
#  ['3020183', '4058949', '3076203', '3020185', '215705', '3931904', '3055069'],
#  ['4021131', 'CSFREIGHT1'],
#  ['0193-0430-01', 'AX1012843', 'CSFREIGHT1'],
#  ['3238204', '3879488', '3238493', '3238358', 'CSFREIGHT1'],
#  ['0149-2967',
#   '0122-0962',
#   '0140-4088',
#   '506924',
#   '3816986',
#   '3403800',
#   'CSFREIGHT1'],
#  ['AX1001368', '0122-0949', '506924', '3816986', 'CSFREIGHT1', '3403800'],
#  ['A044F796'],
#  ['4093731',
#   '3931063',
#   '3937743',
#   '3238666',
#   '3403800',
#   '4926654',
#   '4080720',
#   '505441',
#   'CSFREIGHT1'],
#  ['3973232', '3973233', '3401544', '4058965'],
#  ['0149-2967', '4982627', 'A048M259', '506924', '3403800', 'CSFREIGHT1'],
#  ['0149-2828', '0149-2827', '0122-0922', '506924', 'CSFREIGHT1'],
#  ['4093731',
#   '3931063',
#   '3937743',
#   '4080720',
#   '3403800',
#   '3872813',
#   '505441',
#   'CSFREIGHT1'],
#  ['4093731', '3931063', '3937743', '4080720', '4315238', '4315239', '505441'],
#  ['5285612', '5319245', '5349496', 'CSFREIGHT1'],
#  ['0149-2967', '0122-0962', '3238666', '3816986', 'CSFREIGHT1'],
#  ['3239601', '154087', 'AK10078   MS', 'CSFREIGHT1'],
#  ['3238204', '3879488', '3238493'],
#  ['AX1013235'],
#  ['3167224', '4072352', '3238204', 'CSFREIGHT1'],
#  ['4926654',
#   '0149-2967',
#   '0122-0922',
#   'A034P656',
#   'A034P660',
#   '506924',
#   'AX1013358',
#   'CSFREIGHT1',
#   '3403800',
#   '0193-0430-01'],
#  ['AX1014429', 'AX1013235'],
#  ['504626', 'CSFREIGHT1', 'AX1012844', '3238204', '3238493', '3879488'],
#  ['4315238',
#   '4315239',
#   '4093731',
#   '3937743',
#   '3931063',
#   '4080720',
#   '3403800',
#   '505441',
#   '4926654',
#   '3872813',
#   'CSFREIGHT1'],
#  ['3238666', '4093731', '3931063', '3937743'],
#  ['3329289', '3889311', '3403800'],
#  ['4093731', '3931063', '5285612', '505441', 'CSFREIGHT1', '3403800'],
#  ['A048L463'],
#  ['3978040', '5285612', '3329289'],
#  ['4093731',
#   '3931063',
#   '5285612',
#   '4080720',
#   '505441',
#   '4926654',
#   '3403800',
#   '3872813',
#   '4315238',
#   '4315239',
#   'CSFREIGHT1'],
#  ['3062894'],
#  ['0115-0572', 'CSFREIGHT', '0132-0528'],
#  ['0307-3190'],
#  ['0149-2967',
#   '0122-0962',
#   '3238666',
#   'A048M259',
#   '3403800',
#   '3816986',
#   '506924',
#   'CSFREIGHT1'],
#  ['3978040',
#   '4343955',
#   '5285612',
#   '4926654',
#   '4315238',
#   '4315239',
#   '505441',
#   '3403800',
#   'CSFREIGHT1'],
#  ['A031B113', 'CSFREIGHT1'],
#  ['4093731',
#   '5285612',
#   '3931063',
#   '4080720',
#   '4926654',
#   '505441',
#   'CSFREIGHT1',
#   '4315238',
#   '4315239'],
#  ['0149-2828', '0149-2827', '0122-0922'],
#  ['3973232',
#   '3973233',
#   '3401544',
#   '4058965',
#   '3403800',
#   '505441',
#   '506924',
#   'A041R273',
#   'A041R279',
#   '3816986',
#   'CSFREIGHT1'],
#  ['E000-24403', 'CSFREIGHT1'],
#  ['0122-0961', '0149-2952'],
#  ['3401544',
#   '4072352',
#   '4957708',
#   '4957709',
#   '4345001',
#   '5317717',
#   '4104832',
#   '43828    E',
#   '4926654',
#   '506655',
#   'AX1013359',
#   '3403800'],
#  ['3403800',
#   '3238543',
#   '3167218',
#   '505441',
#   '506924',
#   '3238667',
#   'CSFREIGHT1'],
#  ['0122-0962',
#   '0149-2967',
#   '3816986',
#   '506924',
#   '3403800',
#   'CSFREIGHT1',
#   '4080720'],
#  ['0300-6014', 'CSFREIGHT1'],
#  ['3238543',
#   '3238668',
#   '505441',
#   '506924',
#   '3167218',
#   '0300-6014',
#   'CSFREIGHT1'],
#  ['3238666',
#   '4093731',
#   '3931063',
#   '3937743',
#   '4926654',
#   '505441',
#   'CSFREIGHT1',
#   '4080720'],
#  ['0149-2952', '0122-0961', 'CSFREIGHT1'],
#  ['4396431', 'CS-P&F2', 'CS-F&D2'],
#  ['0503-3165',
#   'A044A823',
#   'CSFREIGHT1',
#   '43828    D',
#   '43828    C',
#   '67185    H'],
#  ['3238668', 'CSFREIGHT1', '3401544', '4104821', '4962810'],
#  ['4093731', '3931063', '3937743', '4080720', '3238666', 'CSFREIGHT1'],
#  ['3238204', '3238493', '3879488', '3238543'],
#  ['506655', 'CSFREIGHT1'],
#  ['506655', 'CSFREIGHT1'],
#  ['4926654', 'CSFREIGHT1'],
#  ['3889310',
#   '3889311',
#   '3329289',
#   '4072352',
#   '4926654',
#   '506655',
#   '3238665',
#   'CSFREIGHT1',
#   '3403800'],
#  ['0132-0528',
#   '0503-3214',
#   '0503-3179',
#   '0503-3155-01',
#   '0503-3178',
#   '43828    B',
#   '43828    A',
#   '43828    C',
#   'A040G639',
#   '0193-0430-01',
#   'A044F794',
#   'A031B113',
#   '0130-8415',
#   '4926654',
#   '3816986'],
#  ['3238666', '5285612', '4080720', '5319245', '5349496'],
#  ['3238204', '3238493', '3879488', '3238358', '3167218'],
#  ['3238665', 'CSFREIGHT1'],
#  ['A054G527'],
#  ['3889310',
#   '3889311',
#   '3329289',
#   '4058965',
#   '4926654',
#   '506655',
#   'AX1013508',
#   '3238665',
#   'CSFREIGHT1'],
#  ['4926975',
#   '0503-2993',
#   '0503-2940',
#   '0503-2924',
#   '0503-2985',
#   '0130-7779',
#   'A040W113',
#   '0309-0714',
#   '4327015',
#   '0511-0248'],
#  ['5285612', '3403800', '4093731', '3931063', '505441'],
#  ['0149-2952', '0122-0961', '0140-4088', '3816986', '506924'],
#  ['3954904', '4897898', '3978040'],
#  ['3238493'],
#  ['0122-0949',
#   'AX1001368',
#   '3238666',
#   '3937743',
#   '3931063',
#   '4093731',
#   '506655',
#   '4926654',
#   '3815068',
#   '3815069'],
#  ['0503-3180'],
#  ['4093731', '0122-0922', '0140-4088', '506924', 'A048M259', 'CSFREIGHT1'],
#  ['0149-2828', '0149-2827', '0122-0922', '0140-4088'],
#  ['AX1013236', 'CSFREIGHT'],
#  ['3238204', '3879488'],
#  ['3651200', 'CS-P&F3', 'CS-F&D3'],
#  ['5285612',
#   '3931063',
#   '4093731',
#   '3403800',
#   '505441',
#   '4926654',
#   'CSFREIGHT1'],
#  ['0122-0922',
#   '0149-2967',
#   'A048M259',
#   '3403800',
#   '506924',
#   '3816986',
#   'CSFREIGHT1'],
#  ['5285612',
#   '4093731',
#   '3931063',
#   '3403800',
#   '4315238',
#   '4315239',
#   '505441',
#   'CSFREIGHT1',
#   '4926654',
#   '4080720'],
#  ['506924', '3238666', 'AX1001368', '0507-0047'],
#  ['3931904', '0509-0493', 'A044S204', '4093731', '0122-0922', 'CSFREIGHT1'],
#  ['AX1009300'],
#  ['0149-2967', '0122-0962', '3816986', '506924', 'CSFREIGHT1'],
#  ['4093731', '3931063', '4080720', '3238666', '3937743', 'CSFREIGHT1'],
#  ['0503-3099-03'],
#  ['CSFREIGHT'],
#  ['AX1013235'],
#  ['0402-0972'],
#  ['178456', 'CSFREIGHT1'],
#  ['3889310',
#   '3889311',
#   '4020551',
#   '4926654',
#   '3329289',
#   '4020552',
#   '506655',
#   '505441',
#   'CSFREIGHT1'],
#  ['3238204', '3879488'],
#  ['5319245', '5349496', '5285612', '3816986'],
#  ['4926654',
#   'AX1013508',
#   '3329289',
#   '3889310',
#   '3889311',
#   '4072352',
#   '3238665',
#   'CSFREIGHT1'],
#  ['506655'],
#  ['0511-0246'],
#  ['3931063',
#   '4093731',
#   '3937743',
#   '3238666',
#   '505441',
#   '4926654',
#   'CSFREIGHT1',
#   '3403800',
#   '4080720'],
#  ['0149-2967', '4982627', '3403800', '3816986', '506924', 'CSFREIGHT1'],
#  ['4072352', '3329289', '4096196', '4926654', 'CSFREIGHT1'],
#  ['3973232',
#   '3973233',
#   '3401544',
#   '3403800',
#   'A041R279',
#   'A041R273',
#   '4926654',
#   '505441',
#   'CSFREIGHT1'],
#  ['0149-2967',
#   '4982627',
#   '3238666',
#   '3403800',
#   '506924',
#   '3816986',
#   'CSFREIGHT1'],
#  ['4372405', 'CS-P&F3', 'CS-F&D3'],
#  ['A048M259'],
#  ['4093731', '3931063', '3937743'],
#  ['3238666'],
#  ['0149-2967',
#   '4982627',
#   '506924',
#   '3816986',
#   'A048M259',
#   '3403800',
#   '3238666',
#   'CSFREIGHT1'],
#  ['3889310',
#   '3889311',
#   '3329289',
#   '4072352',
#   '3238665',
#   '3238204',
#   '3238493',
#   '3879488',
#   '3238358',
#   '3816981'],
#  ['0140-4088', '0122-0961', '0149-2952', 'A046V962', 'CSFREIGHT1'],
#  ['0193-0610', 'AX1002172'],
#  ['0503-2924'],
#  ['0338-5014', 'AX1014236', 'CSFREIGHT1'],
#  ['3973232',
#   '3973233',
#   '4058965',
#   '3401544',
#   '4926654',
#   '3403800',
#   'A041R273',
#   'A041R279',
#   '3978040',
#   '4343955',
#   '5285612',
#   'CSFREIGHT1',
#   '4315238',
#   '4315239'],
#  ['0149-2967', '0122-0962', '506924', '3816986'],
#  ['AX1006288'],
#  ['3978040',
#   '4343955',
#   '4897898',
#   '3403800',
#   '3872813',
#   'A042M070',
#   'A042M071',
#   '505441',
#   '506924',
#   '4926654',
#   'CSFREIGHT1'],
#  ['505441'],
#  ['3403800',
#   'A044F796',
#   '3936594',
#   '5469225',
#   '3872813',
#   '4926654',
#   '5285612',
#   '4093731',
#   '3937743',
#   '4315239',
#   '4315238',
#   'CSFREIGHT1'],
#  ['4093731',
#   '3931063',
#   '3937743',
#   '4080720',
#   '3403800',
#   '505441',
#   '4926654',
#   'CSFREIGHT1',
#   '3872813',
#   '3238666'],
#  ['A044F794', '4926975'],
#  ['0149-2967',
#   '0122-0962',
#   '506924',
#   'A053N752',
#   '3816986',
#   '3403800',
#   'CSFREIGHT1'],
#  ['3403800', '0149-2967', '0122-0962', '0140-4088', '506924', 'CSFREIGHT1'],
#  ['0193-0529-01'],
#  ['0503-3099-03', 'CSFREIGHT1'],
#  ['0130-8415', 'CSFREIGHT1'],
#  ['0149-2967', '4982627', '3403800', '506924', 'CSFREIGHT1'],
#  ['3329289',
#   '5589060',
#   'C6003112110',
#   '506924',
#   '4926654',
#   '2890655',
#   '2890656',
#   '3403800',
#   '3872813',
#   'CSFREIGHT1'],
#  ['3238667', '3403800', '3238543', 'CSFREIGHT1'],
#  ['KIT3238180', '3238204', '3238493', '3238358', '3879488', 'AX1013508'],
#  ['0122-0922', '4093731', '3403800', '0140-4088', 'CSFREIGHT1'],
#  ['A048M259'],
#  ['3937743', '4093731', '3931063'],
#  ['A041N836'],
#  ['0123-2440'],
#  ['AX1012845', 'CSFREIGHT'],
#  ['A054G527'],
#  ['A044L753', '3936594', 'AX1014236', 'CSFREIGHT1'],
#  ['0122-0922',
#   '4093731',
#   'A034P656',
#   'A034P660',
#   'A048M259',
#   '3403800',
#   '0140-4323-02',
#   '506924',
#   'CSFREIGHT1'],
#  ['3403800',
#   '3238666',
#   '4926654',
#   '506924',
#   '0503-3214',
#   '0501-1097',
#   'AX1001368',
#   '0122-0949',
#   'CSFREIGHT1'],
#  ['A044F796'],
#  ['5319245',
#   '5349496',
#   '5285612',
#   '3816986',
#   '505441',
#   '3403800',
#   'CSFREIGHT1'],
#  ['3238358', '3238452', '3238204', '3238493', '3879488'],
#  ['4093731',
#   '0122-0922',
#   'A048M259',
#   '3816986',
#   '506924',
#   '3403800',
#   'CSFREIGHT1'],
#  ['3167224', 'CSFREIGHT1'],
#  ['CS0102-1555', 'CSFREIGHT1', '0102-1537', '3931904'],
#  ['4982627',
#   '0149-2967',
#   '3403800',
#   '3816986',
#   'A048M259',
#   '3238666',
#   '0140-4323-02',
#   'CSFREIGHT1'],
#  ['506924'],
#  ['3238543',
#   '3238668',
#   '506924',
#   '505441',
#   '3403800',
#   '4926654',
#   'CSFREIGHT1'],
#  ['3238204', '3238493', '3879488', '4096196', '3329289', '4072352'],
#  ['4093731', '0122-0922', '3403800', 'A048M259', '506924'],
#  ['3973232', '3973233'],
#  ['3403800',
#   '4897898',
#   '4343955',
#   '3978040',
#   '505441',
#   '4926654',
#   'A042M070',
#   'A042M071',
#   'CSFREIGHT1',
#   '3872813'],
#  ['3403800', '4345001', '4344509', '3401544'],
#  ['4072352', '506655', 'CSFREIGHT1'],
#  ['4926654'],
#  ['AX1012844'],
#  ['CSFREIGHT1',
#   '3816986',
#   'A048M259',
#   '0149-2967',
#   '4982627',
#   '506924',
#   '3403800',
#   '3238666'],
#  ['3910739', 'CSFREIGHT1'],
#  ['3238204', '3238493', '3879488', '3238358'],
#  ['4055076', 'CSFREIGHT1'],
#  ['0140-4088'],
#  ['AX1014429', 'CSFREIGHT'],
#  ['3289124'],
#  ['3403800',
#   '0149-2828',
#   '0149-2827',
#   '0140-4088',
#   '506924',
#   'CSFREIGHT1',
#   '0122-0922'],
#  ['3329289', '3401544'],
#  ['3936594', 'CSFREIGHT1', '0121-0258', 'A031B113'],
#  ['4093731',
#   '3937743',
#   '3931063',
#   '505441',
#   '4926654',
#   '4315238',
#   '4315239',
#   'CSFREIGHT1'],
#  ['3403800',
#   '0149-2828',
#   '0149-2827',
#   '0140-4088',
#   '0122-0922',
#   '506924',
#   'CSFREIGHT1'],
#  ['0149-2967', '0122-0962', '506924', 'CSFREIGHT1'],
#  ['3978040',
#   '4343955',
#   '4897898',
#   'A042M070',
#   'A042M071',
#   '4926654',
#   '505441',
#   'CSFREIGHT1',
#   '3403800'],
#  ['3403800',
#   '5469225',
#   '4093731',
#   '3931063',
#   '3937743',
#   '4080720',
#   '3872813',
#   '3238666',
#   '4926654',
#   '505441'],
#  ['0193-0610', 'CSFREIGHT', '4926654'],
#  ['507357'],
#  ['0132-0491'],
#  ['0149-2828', '0149-2827', '0122-0922', '506924'],
#  ['A044F796', 'CSFREIGHT'],
#  ['0115-0573', '0507-0031'],
#  ['3403800',
#   '4982627',
#   '0149-2967',
#   'A048M259',
#   '3238666',
#   '506924',
#   'CSFREIGHT1'],
#  ['3403800',
#   '3816986',
#   '0122-0922',
#   '0140-4088',
#   '0149-2828',
#   '0149-2827',
#   '506924',
#   'CSFREIGHT1'],
#  ['4093731',
#   '0122-0922',
#   '506924',
#   '3403800',
#   '3816986',
#   'CSFREIGHT1',
#   '0140-4088'],
#  ['A031B113'],
#  ['3015527', '3103972', '3238452'],
#  ['4926654', 'CSFREIGHT1'],
#  ['3329289', '3889310', '3889311', '3238665', '3403800', '4926654'],
#  ['0149-2967', '4982627', 'A048M259', '506924', 'CSFREIGHT1', '3403800'],
#  ['0149-2827',
#   '0149-2828',
#   '0122-0922',
#   '0140-4088',
#   '3816986',
#   '506924',
#   '0140-4323-02',
#   'CSFREIGHT1',
#   '3403800'],
#  ['0122-0949', 'AX1002172'],
#  ['142429'],
#  ['3238204',
#   '3238493',
#   '3879488',
#   'CSFREIGHT1',
#   '3167226',
#   '3872813',
#   '4926654'],
#  ['0149-2952', '0122-0961', '506924', '0140-4088', '3816986'],
#  ['3238204',
#   '3238493',
#   '3879488',
#   '3872813',
#   '3167226',
#   'CSFREIGHT1',
#   '4926654'],
#  ['4344509',
#   '4345001',
#   '3401544',
#   '4058965',
#   '506655',
#   '4957708',
#   '4957709',
#   '4926654',
#   'CSFREIGHT1'],
#  ['0338-5255'],
#  ['0115-0573'],
#  ['0511-0248'],
#  ['RSK5001', 'E000-24403'],
#  ['AX1009277'],
#  ['504626'],
#  ['504626'],
#  ['AX1009277'],
#  ['0122-0962', '0149-2967', '506924'],
#  ['67185    H', '3936594', '0122-0922', '4093731', 'A048M259', 'AX1013358'],
#  ['4093731', '3816986', 'AX1014236', '0140-4088', '0122-0922', '507551'],
#  ['4093731', '3931063', '3937743', '0140-4088'],
#  ['4093731', '3931063', '3937743'],
#  ['4093731'],
#  ['4957708', '4957709', '206576'],
#  ['4093731', '0122-0922', '0140-4088'],
#  ['4080631', 'CSFREIGHT1'],
#  ['3803125'],
#  ['4347659', 'CS-P&F3', 'CS-F&D3'],
#  ['AX1013235', 'CSFREIGHT'],
#  ['4346918', 'CS-P&F3', 'CS-F&D3'],
#  ['4346917', 'CS-P&F3', 'CS-F&D3'],
#  ['4093731', '0122-0922', '0149-2828', '0149-2827', 'CSFREIGHT1', '3816986'],
#  ['3233003', 'CSFREIGHT1'],
#  ['3978040',
#   '4343955',
#   '5285612',
#   '4315238',
#   '4315239',
#   '505441',
#   '4926654',
#   '3403800',
#   '3872813',
#   'CSFREIGHT1'],
#  ['3238204',
#   '3238493',
#   '3879488',
#   '4926654',
#   '506655',
#   '3167226',
#   '3872813',
#   'CSFREIGHT1'],
#  ['5589060', '4946635', '4992119', '3937736', '3978040', '3329289'],
#  ['5285612',
#   '3931063',
#   '4093731',
#   '3816986',
#   '505441',
#   '3403800',
#   '4080720',
#   'CSFREIGHT1'],
#  ['4093731',
#   '0122-0922',
#   '3816986',
#   '3403800',
#   '506641',
#   'A048M259',
#   'CSFREIGHT1',
#   '0140-4088'],
#  ['A031B113'],
#  ['0140-4088', '0149-2828', '0149-2827', '0122-0922', '506924', 'CSFREIGHT1'],
#  ['504626', 'CSFREIGHT1'],
#  ['4104830', '4104829'],
#  ['3872640', 'CSFREIGHT'],
#  ['0122-0922',
#   '0149-2967',
#   'A048M259',
#   '3403800',
#   '506924',
#   '3816986',
#   'A034P656',
#   'A034P660'],
#  ['3872258', '3872294', 'CSFREIGHT1'],
#  ['4093731',
#   '3931063',
#   '3937743',
#   '3238666',
#   '4080720',
#   '4926654',
#   '505441',
#   '3403800',
#   '3872813',
#   'CSFREIGHT1'],
#  ['3238204', 'CSFREIGHT1'],
#  ['3872294', 'CSFREIGHT1'],
#  ['0503-3017', 'A044S174', '0132-0491'],
#  ['3238204', '3238493', '3879488', '505441', '506924', '506923'],
#  ['4926654', 'CSFREIGHT1'],
#  ['3238057', 'CS-P&F2', 'CS-F&D2'],
#  ['3403800',
#   '4093731',
#   '0122-0922',
#   '0140-4088',
#   '4926654',
#   '0140-4323-02',
#   '506924'],
#  ['0122-0922', '0149-2828', '0149-2827', '506923'],
#  ['AX1013235'],
#  ['4093731',
#   '3931063',
#   '3937743',
#   '5285612',
#   '4080720',
#   '3403800',
#   '3238666',
#   '4315238',
#   '4315239',
#   '0140-4323-02',
#   'CSFREIGHT1',
#   '4926654'],
#  ['5285612',
#   '5349496',
#   '5319245',
#   '3238666',
#   '4926654',
#   '3403800',
#   '0140-4323-02',
#   '4080720'],
#  ['0193-0430-01'],
#  ['3238204', '3238493', '3879488', '3167224', '3238665', '4071913', '4071909'],
#  ['AX1012845'],
#  ['3827423',
#   '3872284',
#   '3016142',
#   '3414611',
#   '43828    F',
#   '135144',
#   '3089766',
#   '4056441',
#   '2867240',
#   '2885030',
#   '2885031',
#   'AK16020   SS',
#   '2884902',
#   '2880040',
#   '3629140',
#   '3872813'],
#  ['0193-0529-01'],
#  ['4072352',
#   '3329289',
#   '3889310',
#   '3889311',
#   '3167218',
#   '3035580',
#   '4920076',
#   '4020551',
#   '4020552',
#   '3403800',
#   '3872813',
#   'CSFREIGHT1'],
#  ['3632024', '3632206', '3632027', '3628888', '3175318', '3632025'],
#  ['0149-2967', '0122-0922', '3403800', '3816986', '506924', 'CSFREIGHT1'],
#  ['CSFREIGHT', '0193-0610', 'A031B113'],
#  ['3401544',
#   '3973232',
#   '3973233',
#   'A041R273',
#   'A041R279',
#   '3403800',
#   'CSFREIGHT1',
#   '3872813'],
#  ['0155-4659'],
#  ['0155-4779', '0155-4778'],
#  ['3238666'],
#  ['0402-0972'],
#  ['3238204', '3238493', '3879488', '3167218', '3167226', 'CSFREIGHT1'],
#  ['3238204', '3879488', '3238493', 'CSFREIGHT1'],
#  ['4071913', '4071909'],
#  ['4071909',
#   'AK 5060   SS',
#   'AK10065   MS',
#   '4071913',
#   '3408326',
#   '3030778',
#   '154087',
#   '3878278',
#   '4055963',
#   '3229096',
#   '3827423'],
#  ['504975'],
#  ['3238204'],
#  ['4982627',
#   '0149-2967',
#   '506924',
#   '3816986',
#   '3238666',
#   'CSFREIGHT1',
#   'A048M259',
#   '3872813'],
#  ['3978040',
#   '4343955',
#   '4897898',
#   'A042M070',
#   '4926654',
#   '505441',
#   'A042M071',
#   '3403800',
#   '3872813',
#   'CSFREIGHT1'],
#  ['4093731',
#   '3931063',
#   '3937743',
#   '3403800',
#   '505441',
#   '4926654',
#   '4080720',
#   '3872813',
#   'CSFREIGHT1',
#   '3238666'],
#  ['3629140',
#   '4959090',
#   '3872278',
#   '3872252',
#   '3872284',
#   '3872258',
#   '3872268',
#   '3872304',
#   '3016787',
#   '3237954',
#   '3238493',
#   '3238204',
#   '3879488',
#   '4072352',
#   '3167217',
#   'CSFREIGHT1'],
#  ['3238543', '506924', '505441'],
#  ['5469225', 'CSFREIGHT1'],
#  ['0122-0922',
#   '4093731',
#   '3816986',
#   'A048M259',
#   '0140-4088',
#   '506924',
#   'CSFREIGHT1'],
#  ['3978040', '4343955', '5285612', '3403800', 'CSFREIGHT1'],
#  ['0149-2967',
#   '4982627',
#   '506924',
#   '4926654',
#   '3238666',
#   'A048M259',
#   'CSFREIGHT1',
#   '3872813'],
#  ['4982627'],
#  ['3815419', '3918562', '3928624', 'CSFREIGHT1'],
#  ['5319245', '5349496', '5285612', '4080720', '505441', '3816986', '3403800'],
#  ['0102-1543',
#   '3931904',
#   'A047D772',
#   'A047C312',
#   '0511-0246',
#   'A049W504',
#   '0122-0922',
#   '4093731',
#   '0140-4088',
#   '506924',
#   '3816986',
#   '0509-0507',
#   '0509-0514',
#   'CSFREIGHT1'],
#  ['0140-4088'],
#  ['4093731', '0122-0922', 'A034P656', 'A034P660', '506924'],
#  ['0122-0961',
#   '0149-2952',
#   '0140-4088',
#   'A048M259',
#   '506923',
#   '3403800',
#   '3872813',
#   'CSFREIGHT1'],
#  ['3238543', '506924', '505441', '3238668'],
#  ['5319527', 'CSFREIGHT1'],
#  ['5285612',
#   '4093731',
#   '3931063',
#   '4080720',
#   '505441',
#   '4315238',
#   '4315239',
#   'CSFREIGHT1',
#   '3403800',
#   '5469225'],
#  ['5285612',
#   '5349496',
#   '5319245',
#   '3238666',
#   '505441',
#   '3816986',
#   '3403800',
#   'CSFREIGHT1',
#   '4080720'],
#  ['3403800',
#   '0149-2967',
#   '4982627',
#   '506924',
#   '3238666',
#   'CSFREIGHT1',
#   'A048M259'],
#  ['3403800',
#   '4093731',
#   '5319245',
#   '5285612',
#   '506924',
#   '4080720',
#   '3872813',
#   '3238666',
#   'CSFREIGHT1',
#   '3816986'],
#  ['3973233',
#   '3973232',
#   'A041R273',
#   'A041R279',
#   '4058965',
#   '3401544',
#   '4926654',
#   'CSFREIGHT1',
#   '3167218'],
#  ['0149-2967',
#   '4982627',
#   '506924',
#   '3238666',
#   '3816986',
#   'A048M259',
#   'CSFREIGHT1',
#   '3403800'],
#  ['5285612',
#   '4343955',
#   '3978040',
#   '3403800',
#   '4926654',
#   '505441',
#   'CSFREIGHT1'],
#  ['3978040',
#   '4343955',
#   '4897898',
#   'A042M070',
#   'A042M071',
#   '3403800',
#   '3872813',
#   '505441',
#   '4926654'],
#  ['4926654', 'CSFREIGHT1'],
#  ['A048M259'],
#  ['3238543', '3289124'],
#  ['4982184',
#   '0338-5324',
#   'A044F796',
#   'A048R416',
#   '0193-0430-01',
#   '0503-3099-02',
#   '0503-3099-03',
#   '4995243',
#   'A054G527',
#   'CSFREIGHT1',
#   '4982627',
#   '0149-2967',
#   '3238666',
#   'A048M259'],
#  ['A044U999', 'A044S584', '0507-0036'],
#  ['5285612',
#   '3931063',
#   '4093731',
#   '3403800',
#   '505441',
#   '4080720',
#   '3816986',
#   'CSFREIGHT1'],
#  ['0149-2952',
#   '0122-0961',
#   '0140-4088',
#   'A048M259',
#   '506924',
#   '3816986',
#   'CSFREIGHT1'],
#  ['3238204', '3238493', '3879488', '4058965', '3403800', '3872813'],
#  ['3889310',
#   '3889311',
#   '3329289',
#   '4058965',
#   '4926654',
#   '3403800',
#   '3872813',
#   '506655'],
#  ['5319245', '5349496', '5285612', '3816986', '505441', '3238666'],
#  ['0503-2985'],
#  ['3973232',
#   '3973233',
#   '3401544',
#   '3403800',
#   '4926654',
#   '505441',
#   'CSFREIGHT1'],
#  ['3979344'],
#  ['0149-2967',
#   '0122-0962',
#   '506924',
#   '3238666',
#   '3816986',
#   'CSFREIGHT1',
#   '3403800',
#   'AX1015645'],
#  ['AX1014236', 'CSFREIGHT'],
#  ['504626'],
#  ['0149-2967',
#   '4982627',
#   '3403800',
#   '3872813',
#   'AX1015645',
#   'A048M259',
#   '3238666',
#   '506924',
#   '3816986',
#   'CSFREIGHT1'],
#  ['0149-2967',
#   '4982627',
#   '3403800',
#   '3816986',
#   '506924',
#   '3238666',
#   'A048M259',
#   'CSFREIGHT1'],
#  ['5285612',
#   '3931063',
#   '4093731',
#   '4080720',
#   'CSFREIGHT1',
#   '3403800',
#   '505441',
#   '4926654'],
#  ['504626'],
#  ['505441', '506923', 'CSFREIGHT1'],
#  ['0307-3197', 'CSFREIGHT1'],
#  ['0149-2967',
#   '4982627',
#   'A048M259',
#   '506924',
#   '3403800',
#   '3872813',
#   'CSFREIGHT1',
#   '3238666'],
#  ['3937743', '4093731', '3931063'],
#  ['167157',
#   '193736',
#   '3054999',
#   'KIT4987391',
#   '212601',
#   'S 16052',
#   '3803615',
#   '3034221',
#   '146483',
#   'KITBM68356',
#   '3867393',
#   '154087',
#   '129888',
#   'CSFREIGHT1',
#   '212161',
#   '4085720',
#   '3225109',
#   '3865398'],
#  ['3167217'],
#  ['4093731',
#   '0122-0922',
#   '0140-4088',
#   '3816986',
#   'A048M259',
#   '506924',
#   'CSFREIGHT1',
#   '3403800'],
#  ['4926654', '3816986', 'AX1013358', 'CSFREIGHT1'],
#  ['507357', 'CSFREIGHT1'],
#  ['3875875', 'CS-P&F2', 'CS-F&D2'],
#  ['4020551', '4020552', 'CS-P&F2', 'CS-F&D2'],
#  ['5285612',
#   '4093731',
#   '3931063',
#   '4080720',
#   '3403800',
#   '4926654',
#   '505441',
#   'CSFREIGHT1'],
#  ['0300-6085', 'CSFREIGHT'],
#  ['A052W630', 'CSFREIGHT1'],
#  ['0338-5255', 'A044F796', 'CSFREIGHT1'],
#  ['4330737', '4344499', 'CSFREIGHT1'],
#  ['4093731',
#   '3931063',
#   '5285612',
#   'AX1015645',
#   '3403800',
#   '3872813',
#   '4315238',
#   '4315239',
#   '4926654',
#   '505441',
#   'CSFREIGHT1',
#   '4080720',
#   '3903924'],
#  ['AX1014429', 'CSFREIGHT'],
#  ['4084054'],
#  ['AX1001368',
#   '0122-0949',
#   '0140-4088',
#   '0123-2437',
#   '0123-2438',
#   '506924',
#   '3816986',
#   'CSFREIGHT1'],
#  ['3238667'],
#  ['A035F401'],
#  ['3403800',
#   'AX1001368',
#   '0122-0949',
#   '3238666',
#   'AX1015645',
#   '506924',
#   '3816986',
#   'CSFREIGHT1',
#   '0193-0610'],
#  ['3017993', '154087', 'CSFREIGHT1'],
#  ['3329289', 'CSFREIGHT1'],
#  ['3329289', '3889310', '3889311', '4926654'],
#  ['0102-1543',
#   '0509-0493',
#   '0509-0494',
#   '0509-0514',
#   '0509-0507',
#   '3931904',
#   '506923',
#   'CSFREIGHT1'],
#  ['0193-0430-01', 'CSFREIGHT1'],
#  ['4093731',
#   '0122-0922',
#   '3816986',
#   'A048M259',
#   '506924',
#   'CSFREIGHT1',
#   '3403800'],
#  ['505441'],
#  ['0149-2967', '0122-0962', '506924', '3238666'],
#  ['A044F796', '0309-0714', 'A047C312', 'A047D772', 'A049W504'],
#  ['0149-2967', '0122-0962', '3816986', '3403800', '506924', 'CSFREIGHT1'],
#  ['5285612',
#   '4080720',
#   '3403800',
#   '4093731',
#   '3931063',
#   '505441',
#   '4315238',
#   '4315239'],
#  ['AX1014236'],
#  ['0140-4088'],
#  ['0149-2952', '0122-0961', 'A048M259', '506924', '3816986', 'CSFREIGHT1'],
#  ['0149-2886',
#   '3973232',
#   '3973233',
#   'A041R273',
#   'A041R279',
#   '4926654',
#   '505441',
#   '3403800',
#   '3872813',
#   'CSFREIGHT1'],
#  ['3401544'],
#  ['5285612',
#   '5349496',
#   '5319245',
#   '3238666',
#   '505441',
#   '0503-3193',
#   'CSFREIGHT1'],
#  ['4093731',
#   '5285612',
#   '3931063',
#   '3403800',
#   '4315238',
#   '505441',
#   '4080720',
#   'CSFREIGHT1',
#   '4315239'],
#  ['0302-2121', 'CSFREIGHT1'],
#  ['3046200'],
#  ['3403800',
#   '4093731',
#   '0122-0922',
#   '3816986',
#   'A048M259',
#   '506924',
#   'CSFREIGHT1',
#   'AX1015645'],
#  ['4072352'],
#  ['3401544',
#   '4058965',
#   '3973232',
#   '3973233',
#   '4926654',
#   'A041R273',
#   'A041R279',
#   '505441',
#   '506924',
#   '506923',
#   'CSFREIGHT1'],
#  ['A041R273', 'A041R279', '3973232', '3401544', '4058965'],
#  ['0149-2967', '0122-0962'],
#  ['0149-2827',
#   '0122-0922',
#   '0140-4088',
#   '0149-2828',
#   '3816986',
#   '506924',
#   'CSFREIGHT1',
#   '3403800',
#   '3872813'],
#  ['0193-0430-01', 'CSFREIGHT1'],
#  ['0503-2924',
#   '0503-2925',
#   '0503-2993',
#   '0503-2940',
#   '43828    B',
#   '43828    C',
#   'CSFREIGHT1'],
#  ['AX1015646'],
#  ['3978040',
#   '4343955',
#   '4897898',
#   '3403800',
#   'A042M070',
#   'A042M071',
#   '505441',
#   '3816986',
#   'CSFREIGHT1'],
#  ['3973233'],
#  ['A028X493', 'CSFREIGHT1'],
#  ['AX1013235'],
#  ['3401544',
#   '4345001',
#   '4344509',
#   '4957708',
#   '4957709',
#   '3872813',
#   '4072352',
#   '4926654',
#   'AX1013508',
#   'CSFREIGHT1'],
#  ['4093731',
#   '0122-0922',
#   '0140-4088',
#   '3816986',
#   '506924',
#   '3403800',
#   '0511-0246',
#   'CSFREIGHT1'],
#  ['0503-3178', '0503-3179', 'CSFREIGHT1'],
#  ['3978040', '4343955', '4897898', '505441', 'CSFREIGHT1'],
#  ['3238203', '3879488', '3238493', 'CSFREIGHT1'],
#  ['4926654', 'CSFREIGHT1'],
#  ['4093731', '3931063', '3937743'],
#  ['4096196',
#   '3329289',
#   '4072352',
#   '3238204',
#   '3238493',
#   '3879488',
#   '3238358',
#   '3238665'],
#  ['506924', 'CSFREIGHT1'],
#  ['A044F796'],
#  ['4093731',
#   '3937743',
#   '3931063',
#   '3815068',
#   '3815069',
#   '505441',
#   '4926654',
#   '3403800',
#   '3872813',
#   'AX1015645',
#   '4080720',
#   'CSFREIGHT1'],
#  ['3084539'],
#  ['AX1008846', '505441'],
#  ['0122-0922', '0149-2967', '0140-4088'],
#  ['5285612', '5293068', '5332229', '2868463', '3814133', '4080720'],
#  ['AX1008847', '4926654', '505441', 'A042M070', 'A042M071', 'CSFREIGHT1'],
#  ['3935430'],
#  ['E000-24403'],
#  ['3931063', '3937743', '4093731', '505441'],
#  ['506924'],
#  ['5285612', '5293068', '5332229', '4080720', '2868463', '3814133', '505441'],
#  ['0122-0922', '0149-2967', '506924', 'A034P656', 'A034P660', 'CSFREIGHT1'],
#  ['AX1008844', '506924', '3238666', '506923'],
#  ['AX1008844', '3238666', '506924', '506923'],
#  ['0122-0962', '0149-2967', '506924', 'CSFREIGHT1'],
#  ['A035F403'],
#  ['0122-0922', '4093731', '0140-4088', '4104802', '506923', '3936594'],
#  ['0122-0922', '4093731', '0140-4088', '506924'],
#  ['3401544',
#   '3973232',
#   '3973233',
#   '5285612',
#   '3931063',
#   '4093731',
#   '4315239',
#   '4315238',
#   '0122-0922',
#   '0140-4088',
#   '504626'],
#  ['3931063', '4093731', '3937743', '3238666'],
#  ['4104802'],
#  ['AX1008843', '506924', '3816986', 'CSFREIGHT'],
#  ['AX1008848',
#   'AX1008846',
#   '4926654',
#   'A041R279',
#   'A041R273',
#   '4315238',
#   '4315239'],
#  ['0122-0962', '0149-2967', '4104802', '506924', 'CSFREIGHT1'],
#  ['0122-0962',
#   '0149-2967',
#   '0140-4088',
#   '3816986',
#   '0193-0610',
#   'AX1008840',
#   '506924',
#   '506923',
#   'CSFREIGHT1'],
#  ['506924'],
#  ['3931063', '3937743', '4093731', '3816986', '505441', 'CSFREIGHT1'],
#  ['4315238', '4315239'],
#  ['3815424'],
#  ['3037535'],
#  ['0122-0922', '0149-2967', '4104802', 'CSFREIGHT1'],
#  ['AX1014236'],
#  ['3935338'],
#  ['0338-5015', '0307-3190', 'CSFREIGHT1'],
#  ['4093731', '0122-0922', '3816986', '506924'],
#  ['4084907',
#   '4104832',
#   '3071160',
#   '3028291',
#   'A035F403',
#   '3872284',
#   '3872294'],
#  ['0122-0922', '0149-2827', '0149-2828'],
#  ['5285612',
#   '3931063',
#   '4093731',
#   '506655',
#   '4315238',
#   '4315239',
#   'CSFREIGHT1'],
#  ['5469225'],
#  ['3931063',
#   '3937743',
#   '4093731',
#   '4080720',
#   '2868463',
#   '3814133',
#   '505441',
#   '5469225'],
#  ['0122-0922', '4093731', '4104802', '506924'],
#  ['201989', 'CSFREIGHT1'],
#  ['0140-4088'],
#  ['AX1013233'],
#  ['3931063', '3937743', '4093731', '505441'],
#  ['3816981', '504626'],
#  ['5285612', '5349496', '5319245', '4080720', '506924', 'CSFREIGHT1'],
#  ['AX1014236'],
#  ['AX1013235', '4104832', '4104829', '43828    D', '43828    A'],
#  ['3816981', '504626'],
#  ['3238543', '505441'],
#  ['0149-2967',
#   '0122-0922',
#   'A048M259',
#   '0140-4088',
#   '4104802',
#   '506924',
#   'CSFREIGHT1'],
#  ['AX1012843'],
#  ['4104802'],
#  ['0122-0922',
#   '0149-2828',
#   '0149-2827',
#   '0149-2967',
#   '0140-4088',
#   'A034P656',
#   'A034P660',
#   '3816986',
#   '506924',
#   '506923',
#   '0193-0610',
#   '4926975',
#   'AX1013233'],
#  ['506924'],
#  ['3329289', '3889310', '3889311', '4072352'],
#  ['506655', '3238543', '3238667', 'CSFREIGHT1'],
#  ['3930906', '5285612', '4093731', '3931063', '505441', 'CSFREIGHT1'],
#  ['5285612',
#   '3931063',
#   '4093731',
#   '4080720',
#   '4315238',
#   '4315239',
#   '3285410',
#   '0503-3164',
#   'AX1013507',
#   '4926654',
#   '3816986',
#   '5469225',
#   '0503-3094',
#   '4080631',
#   '505441',
#   'CSFREIGHT1'],
#  ['3906698', '0503-2993'],
#  ['3931063', '3937743', '4093731', '3238666'],
#  ['AX1008846', '4315238', '4315239', '4926654', '505441', 'CSFREIGHT1'],
#  ['4093731', '3937743', '3931063', '505441', '506924', '2868463', '3814133'],
#  ['0122-0922', '4093731', '506923'],
#  ['3238493', '3238204', '3879488', '67185    H'],
#  ['AX1008843', '4104802', '506924'],
#  ['3238543', 'CSFREIGHT1'],
#  ['3238667'],
#  ['4926975', '4080631', '3906697'],
#  ['A053N752'],
#  ['4982627',
#   '0149-2967',
#   '3238666',
#   '0193-0430-01',
#   'A048M259',
#   '4926654',
#   '3936594',
#   'AX1012843'],
#  ['AX1008841', '0140-4088'],
#  ['3238543', '3238667', '3167222', '505441', 'CSFREIGHT1'],
#  ['3931063', '3937743', '4093731', '4080720', '3238666', '3816986', '505441'],
#  ['5285612', '5293068', '5332229', '4080720'],
#  ['AX1008846', '4926654', '505441', 'CSFREIGHT1'],
#  ['5469225', '0193-0610'],
#  ['AX1001368',
#   '0122-0949',
#   '0149-2967',
#   '0122-0962',
#   '3931063',
#   '3937743',
#   '4093731',
#   '4080720',
#   '506655',
#   'CSFREIGHT1'],
#  ['3931063', '3937743', '4093731', '3816986', '505441'],
#  ['0122-0962',
#   '0149-2967',
#   '3238666',
#   '4926654',
#   '506924',
#   'AX1013358',
#   'CSFREIGHT1'],
#  ['AX1012843', 'CSFREIGHT1'],
#  ['AX1008848', '4926654', 'CSFREIGHT1'],
#  ['A044F796'],
#  ['0338-5256'],
#  ['0338-5256'],
#  ['0122-0961', '0149-2952', '0140-4088', '506923', '4104802'],
#  ['3880726', '178636'],
#  ['506923'],
#  ['4315238', '4315239', '505441', '5285612', '3931063', '4093731', '4080720'],
#  ['AX1008848', '505441', '4926654', 'CSFREIGHT1'],
#  ['5285612', '5293068', '5332229', '4080720'],
#  ['3937743'],
#  ['0503-3214'],
#  ['3329289', '3978040', '5285612'],
#  ['3329289', '3889310', '3889311', '4072352', '506655', 'CSFREIGHT1'],
#  ['4093731',
#   '3931063',
#   '3937743',
#   '0122-0922',
#   '505441',
#   '506924',
#   '3238666',
#   '4104802'],
#  ['4926975'],
#  ['506924', '0149-2967', '0122-0962'],
#  ['3329289', '3889310', '3889311', '4072352', '506655'],
#  ['AX1002172'],
#  ['0300-6315-02'],
#  ['505441',
#   '4093731',
#   '3931063',
#   '3937743',
#   '3403800',
#   '3238666',
#   '4926654',
#   'CSFREIGHT1'],
#  ['506655', '3238543', '4962810', 'CSFREIGHT1'],
#  ['4104821', '4962810', '3238667'],
#  ['AX1013235'],
#  ['A055G562'],
#  ['3931063', '4093731', '3937743', '505441'],
#  ['3238666', 'A048A496', 'AX1002172'],
#  ['5285612', '5293068', '5332229', '4080720'],
#  ['3972266', '3935430'],
#  ['3931063', '3937743', '4093731', '3816986', '505441', 'CSFREIGHT1'],
#  ['3238543',
#   '3931063',
#   '4093731',
#   '3937743',
#   '3238666',
#   '505441',
#   '506924',
#   '3238667',
#   'CSFREIGHT1',
#   'A028X493'],
#  ['506923'],
#  ['5469225'],
#  ['3329289',
#   '3889310',
#   '3889311',
#   '4072352',
#   '3238665',
#   '4920076',
#   'CSFREIGHT1',
#   '506655'],
#  ['AX1013235'],
#  ['AX1008840', '506923', 'A044X404', 'A049W504', '0140-4088'],
#  ['AX1008847',
#   '505441',
#   '506924',
#   'CSFREIGHT1',
#   '4104802',
#   '5285612',
#   '3931063',
#   '4093731'],
#  ['3289124'],
#  ['0193-0610'],
#  ['504626'],
#  ['AX1008845', '4926654', '505441', 'CSFREIGHT1'],
#  ['RSK5001', '051-01072'],
#  ['AX1008840', '4104802', '506923', 'CSFREIGHT1'],
#  ['4347124', 'CSFREIGHT1'],
#  ['5285612'],
#  ['3200287', '4080829'],
#  ['3937743', '3931063', '4093731', '505441'],
#  ['2897333'],
#  ['A046L404', '5469225'],
#  ['0193-0610'],
#  ['E000-24403', 'A044F794', 'A048M259', 'CSFREIGHT1'],
#  ['0122-0922', '4093731', '506924', '3816986', 'CSFREIGHT1', 'AX1012843'],
#  ['AX1008847', '505441', '506924'],
#  ['AX1008847', '505441', '506924', 'CSFREIGHT1'],
#  ['AX1013235', '0300-6085', '70624'],
#  ['3238543', '506655', 'CSFREIGHT1'],
#  ['3238543', '505441', '506923'],
#  ['AX1001368', '3238666', '4104802', '0130-7779', '0122-0949'],
#  ['AX1008848',
#   'A041R273',
#   'A041R279',
#   '4926654',
#   '505441',
#   '506924',
#   '506923',
#   'CSFREIGHT1'],
#  ['5285612',
#   '4093731',
#   '3931063',
#   '4315238',
#   '4315239',
#   'CSFREIGHT1',
#   '505441'],
#  ['178554', '4104828', '4104829', '43828    D', '145536'],
#  ['5285612', '5293068', '5332229', '2868463', '3814133', '4080720'],
#  ['505441', '3238667', '3238543'],
#  ['AX1008842', '0140-4088', '4926654', '506924'],
#  ['506924',
#   '506923',
#   '3931063',
#   '3937743',
#   '4093731',
#   '5469225',
#   '2868463',
#   '3814133'],
#  ['4926975'],
#  ['506923',
#   '506924',
#   '3931063',
#   '3937743',
#   '4093731',
#   '2868463',
#   '3814133',
#   '5469225'],
#  ['3238204',
#   '3879488',
#   '3238493',
#   '3238665',
#   '3238543',
#   '3238668',
#   '0300-6014',
#   '3167224',
#   '504626',
#   'CSFREIGHT1'],
#  ['3238543'],
#  ['3238204', '3879488', '3238493', '505441', '506924'],
#  ['5285612', '4093731', '3931063', '505441', '4926654', '4315238', '4315239'],
#  ['4093731', '3931063', '5285612', '4315239', '4315238'],
#  ['AX1008848',
#   'A041R273',
#   'A041R279',
#   'AX1014429',
#   '5269379',
#   'AX1008845',
#   '4315238',
#   '4315239',
#   '3936594',
#   '505441',
#   '506924',
#   'CSFREIGHT1'],
#  ['505441', '5293068', '5285612', '5332229', '2868463', '3814133'],
#  ['3238493'],
#  ['2868463', '3814133'],
#  ...]

# %%
len(transactions)
# Out:
# 6000

# %%
temp = grouped['ITEM_NAME'].str.len()

# %%
temp.head()
# Out:
# 0     1
# 1     3
# 2     6
# 3    26
# 4     1
# Name: ITEM_NAME, dtype: int64

# %%
temp.describe()

# %%
# Count a transaction which contains 5285612, 5319245, and 5349496
type(transactions)

# %%
transactions.count(['5285612', '5319245', '5349496'])

# %%
# Count the number of rules

# Import library to count the number of permutations
from itertools import permutations

# Extract unique items.
unique_items = [item for transaction in transactions for item in transaction]

# Convert the unique item list from a string to a list
unique_item_list = list(set(unique_items))

# Compute and print rules.
rules = list(permutations(unique_item_list, 2))

# %%
len(unique_item_list)
# Out:
# 1627

# %%
len(unique_items)
# Out:
# 24733

# %%
print(len(rules))
# Out:
# 2645502

# %%
#print(rules)

# %% [markdown]
# ##  Basic Metrics

# %%
# Import the library for encoding
from mlxtend.preprocessing import TransactionEncoder

# Instantiate transaction encoder
encoder = TransactionEncoder().fit(transactions)

# %%
# One-hot encode itemsets by applying fit and transform
onehot = encoder.transform(transactions)

# Convert one-hot encoded data to DataFrame
onehot = pd.DataFrame(onehot, columns = encoder.columns_)
print(onehot)
# Out:
#       .CSJ1  0098-7902-01  0098-8104-03  0102-1537  0102-1543  0103-0876  \
# 0     False         False         False      False      False      False
# 1     False         False         False      False      False      False
# 2     False         False         False      False      False      False
# 3     False         False         False      False      False      False
# 4     False         False         False      False      False      False
# ...     ...           ...           ...        ...        ...        ...
# 5995  False         False         False      False      False      False
# 5996  False         False         False      False      False      False
# 5997  False         False         False      False      False      False
# 5998  False         False         False      False      False      False
# 5999  False         False         False      False      False      False
#
#       0104-2116  0104-2117  0105-0791  0110-4013  ...  S   610  S   622  \
# 0         False      False      False      False  ...    False    False
# 1         False      False      False      False  ...    False    False
# 2         False      False      False      False  ...    False    False
# 3         False      False      False      False  ...    False    False
# 4         False      False      False      False  ...    False    False
# ...         ...        ...        ...        ...  ...      ...      ...
# 5995      False      False      False      False  ...    False    False
# 5996      False      False      False      False  ...    False    False
# 5997      False      False      False      False  ...    False    False
# 5998      False      False      False      False  ...    False    False
# 5999      False      False      False      False  ...    False    False
#
#       S   670  S   946  S   985    C  S  1040    A  S  1650  S 16052  \
# 0       False    False         False         False    False    False
# 1       False    False         False         False    False    False
# 2       False    False         False         False    False    False
# 3       False    False         False         False    False    False
# 4       False    False         False         False    False    False
# ...       ...      ...           ...           ...      ...      ...
# 5995    False    False         False         False    False    False
# 5996    False    False         False         False    False    False
# 5997    False    False         False         False    False    False
# 5998    False    False         False         False    False    False
# 5999    False    False         False         False    False    False
#
#       SR-SC-PV-Maint-Gen    nan
# 0                   True  False
# 1                  False  False
# 2                  False  False
# 3                  False  False
# 4                  False  False
# ...                  ...    ...
# 5995               False  False
# 5996               False  False
# 5997               False  False
# 5998               False  False
# 5999               False  False
#
# [6000 rows x 1627 columns]

# %%
onehot.columns=onehot.columns.str.replace('[-, ,_]','')
# Out:
# C:\Users\sjj920315\AppData\Local\Temp\ipykernel_2728\1046257701.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   onehot.columns=onehot.columns.str.replace('[-, ,_]','')

# %%
onehot
# Out:
#       .CSJ1  0098790201  0098810403  01021537  01021543  01030876  01042116  \
# 0     False       False       False     False     False     False     False
# 1     False       False       False     False     False     False     False
# 2     False       False       False     False     False     False     False
# 3     False       False       False     False     False     False     False
# 4     False       False       False     False     False     False     False
# ...     ...         ...         ...       ...       ...       ...       ...
# 5995  False       False       False     False     False     False     False
# 5996  False       False       False     False     False     False     False
# 5997  False       False       False     False     False     False     False
# 5998  False       False       False     False     False     False     False
# 5999  False       False       False     False     False     False     False
#
#       01042117  01050791  01104013  ...   S610   S622   S670   S946  S985C  \
# 0        False     False     False  ...  False  False  False  False  False
# 1        False     False     False  ...  False  False  False  False  False
# 2        False     False     False  ...  False  False  False  False  False
# 3        False     False     False  ...  False  False  False  False  False
# 4        False     False     False  ...  False  False  False  False  False
# ...        ...       ...       ...  ...    ...    ...    ...    ...    ...
# 5995     False     False     False  ...  False  False  False  False  False
# 5996     False     False     False  ...  False  False  False  False  False
# 5997     False     False     False  ...  False  False  False  False  False
# 5998     False     False     False  ...  False  False  False  False  False
# 5999     False     False     False  ...  False  False  False  False  False
#
#       S1040A  S1650  S16052  SRSCPVMaintGen    nan
# 0      False  False   False            True  False
# 1      False  False   False           False  False
# 2      False  False   False           False  False
# 3      False  False   False           False  False
# 4      False  False   False           False  False
# ...      ...    ...     ...             ...    ...
# 5995   False  False   False           False  False
# 5996   False  False   False           False  False
# 5997   False  False   False           False  False
# 5998   False  False   False           False  False
# 5999   False  False   False           False  False
#
# [6000 rows x 1627 columns]

# %% [markdown]
# ## Creating dictionary and List to get part number and description

# %%
parts_cummins = pd.read_excel("CSS Partinfo.xlsb")

# %%
colm = parts_cummins.columns
colm = colm[2:]

# %%
parts =parts_cummins.drop(colm,axis=1)

# %%
parts = parts[:-1]

# %%
parts.tail()
# Out:
#             ITEM                                     ITEMNAME
# 70988  AX1003618  RECONDITIONED ALTERNATOR FOR 160 KVA DG SET
# 70989  AX1005081                             SEALING,PUSH ROD
# 70990  AX1004752                                   CRANKSHAFT
# 70991  AX1004865                          CYLINDER HEAD MINOR
# 70992  AX1004930             PLATE IDLER GEAR RETAINING LOWER

# %%
parts['ITEM'] = parts['ITEM'].replace(r'[^\w\s+]|_', '', regex=True)

# %%
parts['ITEM'] = parts['ITEM'].replace(" ",'', regex=True)

# %%
parts_list = parts['ITEM'].to_list()

# %%
parts_list = [str(r) for r in parts_list]

# %%
parts_list
# Out:
# ['4958439',
#  '3393077',
#  '3814720',
#  '4894306',
#  'A046W832',
#  'C6141211530',
#  '0800661963',
#  'AK10149SS',
#  'AR60740',
#  '554013',
#  '3046942',
#  'AX1012769',
#  '4926782',
#  '503929A',
#  '05070048',
#  '3229938',
#  '3538350',
#  'AX1014391',
#  '69751',
#  '4089730NX',
#  '4042265',
#  '5269423',
#  'A040F057',
#  '4919360',
#  '5269717',
#  '3016344',
#  '5278762',
#  '80010477',
#  '217008',
#  '3642922',
#  '3249599',
#  '4939853',
#  'A034S891',
#  'A034N735',
#  '3249587',
#  '3249733',
#  '3086060',
#  'RX3232595',
#  '556711',
#  '05170477',
#  'AX1005736',
#  '03324404',
#  '3636373',
#  'AX1007495',
#  '4922210',
#  '01856503',
#  '4007663NX',
#  '5413017',
#  'S510',
#  'A046G653',
#  '0333063402',
#  '3877208',
#  '4101372',
#  '01856574',
#  '3249442',
#  'C6204211610',
#  '4105926',
#  '3015545',
#  '4054729',
#  '3235613',
#  '9278',
#  '211722',
#  'A052E125',
#  'A066E748',
#  'A052W678',
#  '3001722',
#  '4007582',
#  '4928594',
#  '115034',
#  '3970546',
#  '3054219',
#  '3878275',
#  'S123B',
#  '3052587',
#  'AK10075SS',
#  '3873807',
#  '3814032',
#  'RX3085964',
#  '3877027',
#  'A041S481',
#  '500412',
#  '4372338',
#  '3016787',
#  '3002956',
#  '3863522',
#  'RXC6008631410',
#  'AX1014203',
#  '3081076',
#  '3414584',
#  '3815914',
#  '213485',
#  '3963983',
#  '3052820',
#  '3920603',
#  'S995',
#  '4957919',
#  '108307',
#  '3046419',
#  '3054889',
#  'AK4030SS',
#  '4084887',
#  '0338387001',
#  'AX1015308',
#  '4386219',
#  '3411290',
#  'A047R074',
#  '3201919',
#  '3167816',
#  '5276769',
#  '01305709',
#  '3392672',
#  '2880044',
#  'A040L186',
#  '4007165',
#  '3166619',
#  '4957714',
#  '4089368',
#  'RX3533197',
#  '3916302',
#  '3279720',
#  '3249459',
#  '3635035',
#  'ST1264',
#  'ST1318',
#  'ST1327',
#  '3817029',
#  '3945268',
#  '3944167',
#  '3943740',
#  '3957592',
#  '3945918',
#  '3964093',
#  '4021058',
#  '4021362',
#  '4021371',
#  '3255321',
#  '3255764',
#  '3253714',
#  '3635124',
#  '3635129',
#  '3277099',
#  '3638603',
#  '144490',
#  'RX4956667',
#  '4027881',
#  'A052P683',
#  '01866685',
#  'T83302910',
#  '01308485',
#  '4085324',
#  '500851',
#  '4992163',
#  '4089201',
#  'A044K217',
#  '3002425',
#  '5405345',
#  '0155496904',
#  '4945007',
#  '3955069',
#  '01308324',
#  '3018767',
#  'AX1005298',
#  'AX1006173',
#  '3001352',
#  'J0402000505',
#  '138993',
#  '2882673',
#  '05090590',
#  '143085',
#  '3245111',
#  '4936026',
#  '3925964',
#  '3092716',
#  '3685960',
#  '4950612',
#  'AX1006073',
#  '3901764',
#  'RX3873947',
#  '3968806',
#  'A040K585',
#  '2881910',
#  '3920802',
#  '3931914',
#  '3249324',
#  '0149233102',
#  '4946299',
#  '4095922',
#  '5333474',
#  '3249337',
#  '3630242',
#  '123146',
#  '3904648',
#  '05202703',
#  '3103372',
#  '3393581',
#  'A065K044',
#  '4345071',
#  '4911618',
#  'AX1005396',
#  '02490797',
#  '3920758',
#  '3918667',
#  '3624451',
#  '3636085',
#  '3005590',
#  '01307792',
#  '3933841',
#  '3666075',
#  '3666119',
#  '01492954',
#  'AX1009058',
#  '3049145',
#  '3095130',
#  '5529797',
#  '3375470',
#  '4085307',
#  'AR9633',
#  '3937660',
#  '4945774',
#  '4954880',
#  '0320229101',
#  '3906790',
#  '3523592',
#  '3874949',
#  'AX1005907',
#  '505409',
#  '0130798602',
#  '4963703',
#  '4020488',
#  '3877466',
#  '3232953',
#  '3280796',
#  '3392318',
#  '5260025',
#  '3250939',
#  'NI910036134',
#  '3231517',
#  '3085857',
#  'AX1002142',
#  '3930668',
#  '216864',
#  '3176910',
#  '3911570',
#  '03065442',
#  '5525521',
#  '3167054',
#  '3287423',
#  '0200331203',
#  'AX1013566',
#  'A046E840',
#  '05021659',
#  '3034958',
#  '3681898',
#  'C0143520612',
#  '4027924',
#  '4020538',
#  'A056T663',
#  'A054G986',
#  '23010269',
#  '3903384',
#  '05033234',
#  'AX1005631',
#  'AX1005568',
#  '3872373',
#  '216693',
#  '4950114',
#  '4054901',
#  'AX1015141',
#  'HCI54C400B1',
#  '4323079',
#  '3088308',
#  '4309353NX',
#  'AX1005380',
#  '3928229',
#  '05032196',
#  '03005315',
#  '3225171',
#  '3684414',
#  '4998570',
#  '44676',
#  '3238077',
#  'A049M997',
#  '196112',
#  '4911991',
#  '3874472',
#  '03385342',
#  'AX1006416',
#  '3094045',
#  'AX1013192',
#  'AX1015294',
#  'A063D324',
#  '4015881',
#  '4009247',
#  '3283686',
#  '4955665',
#  '4033542',
#  '3044849',
#  'AX1004914',
#  '3234881',
#  '3167927',
#  '3911586',
#  '2865104',
#  '198962',
#  '3644292',
#  'AX1002250',
#  'A061B617',
#  '3233112',
#  '0309064105',
#  'AK160306MS',
#  '4918725',
#  '3094028',
#  'A064G364',
#  '4020483',
#  'AX1014274',
#  '01855777',
#  '3637752',
#  '3817032',
#  '3379182',
#  '3898182',
#  '4964229',
#  '4963544',
#  '3245082',
#  '3240697',
#  '3594172',
#  '3092904',
#  '3376495',
#  'J01308849',
#  '3932529',
#  'AX1005536',
#  '3638475',
#  '01306623',
#  'AX1012937',
#  '3645962',
#  'AX1006267',
#  '4955525',
#  'A046W412',
#  'AX1002662',
#  '3804891',
#  '5339449',
#  'A054Y263',
#  '5310311',
#  'A041F023',
#  '3863993',
#  '4068583',
#  'A042L827',
#  '3417958',
#  '4096470',
#  '4100433',
#  'AK4018MS',
#  '2885348',
#  '4095525',
#  '05410809',
#  '3965953',
#  '3408345',
#  '3026236',
#  '3028180',
#  '2872792',
#  '4948168',
#  '3004259',
#  '3089796',
#  '3414420',
#  'AR5109',
#  '3236888',
#  '3865155',
#  '4955955',
#  'RO4382239',
#  '01305554',
#  '3166878',
#  '3942748',
#  '3376754',
#  '207535',
#  'AX1014893',
#  '3052170',
#  'S115A',
#  '3230434',
#  '5340055',
#  '3240325',
#  '3201060',
#  '3288845',
#  '3910755',
#  '3929028',
#  '3897538',
#  '4980390',
#  '3607276',
#  '4036307',
#  'A034W239',
#  '4105981',
#  '4069778',
#  '101834',
#  '3230211',
#  '5300876',
#  '505324',
#  'A061W593',
#  '3330658',
#  '3069689',
#  'AX1012966',
#  '3875323',
#  '3966450',
#  'A055S175',
#  'RX4020861',
#  '3781591',
#  'A050T563',
#  '0200313602',
#  '4970363',
#  '4096049',
#  '01320475',
#  '3897972',
#  '178572',
#  '3228265',
#  '3229212',
#  'AK4088SS',
#  '4104880',
#  '4918212',
#  '206511',
#  'AX1014471',
#  'A051N572',
#  '5305340',
#  '4334668',
#  'AX1003734',
#  '3412920',
#  '3098353',
#  '3082573',
#  '102397',
#  'AX1004735',
#  '3177198',
#  '3636262',
#  '2879299',
#  'AX1003670',
#  '3974642',
#  '4086588',
#  '3420742',
#  '5394247',
#  'RO3076703',
#  '3392749',
#  '3970139',
#  'NI910042937',
#  '4330744',
#  '4956000',
#  '5302028',
#  '2873258',
#  '3909394',
#  'A061M513',
#  'RX3913269',
#  '3879460KE214',
#  '4348577',
#  '3092610',
#  'AX1006125',
#  '4928637',
#  '3008591',
#  '4950139',
#  'AX1007553',
#  '3089298',
#  'A024J110',
#  '05032522',
#  '4913173',
#  '3599718',
#  '3163400',
#  'A065N206',
#  'RO3920867',
#  'AX1005082',
#  '3092246',
#  'AX1015953',
#  'AX1006696',
#  '3814490',
#  '64490',
#  '3824541',
#  'RX3070889',
#  'AX1015955',
#  '4981575',
#  '5262624',
#  'KIT4105238',
#  '3200943',
#  '4939857',
#  '2865451',
#  'AX1006448',
#  '4990979',
#  'A066P898',
#  '3249566',
#  '4083954',
#  '4912678',
#  '5279084',
#  '4919767',
#  '3529035',
#  '3680140',
#  '3008876',
#  '3685860',
#  '3288678',
#  '4053630',
#  'KIT3880634',
#  '3074354',
#  '03384739',
#  '3804666',
#  'A054L670',
#  '5563305',
#  '3698067',
#  '137990',
#  '01855502',
#  '4926762',
#  '4055717',
#  '3523556',
#  '2868200',
#  'A049J724',
#  '4105839KF95',
#  '500946',
#  '218499',
#  '4068549',
#  '3886350',
#  '4926959',
#  '4086158',
#  '5583127',
#  '4912604',
#  'A062T785',
#  '0304083103',
#  '5324151',
#  '01819124',
#  '3863822',
#  '3923883',
#  '208118',
#  '3877688',
#  '4105956',
#  '500343',
#  '3685700',
#  'A044X404',
#  '3246528',
#  '3957380',
#  '3236300',
#  'AX1006280',
#  '200584',
#  '3877719',
#  'RXAR40039',
#  '5286815',
#  '4953321',
#  '4104509',
#  '5363429',
#  'A051H103',
#  '207312',
#  '0860212721',
#  '3225305',
#  '3053159',
#  '3533163',
#  'AX1007254',
#  '4055380',
#  '2879966',
#  '01403890',
#  'AX1006858',
#  '3800529',
#  'RX4089981',
#  '145551',
#  'KIT4968318',
#  '3231923',
#  '01857076',
#  '3641139',
#  '205466',
#  '4941369',
#  '3029626',
#  '4975709',
#  '4000713',
#  'AX1013240',
#  '3974600',
#  '3017993',
#  '3594034',
#  '4926703',
#  '3332148',
#  '5295568',
#  '4080535',
#  'C6204114810',
#  '141634',
#  'BM40951',
#  '3524421',
#  '4962840',
#  '3335044',
#  'AR5115',
#  'AR5125',
#  '4980030',
#  '4930897',
#  '3970976',
#  '3249559',
#  '3413810',
#  '05052550',
#  '3042591',
#  '4387613',
#  '03385329',
#  '3935326',
#  '5405482',
#  '4901349',
#  '3873050',
#  '4065739',
#  '3234949',
#  'RO2879737KE374',
#  'AX1016296',
#  '3226062',
#  '102296',
#  '3898495',
#  '3069114',
#  'BM54901',
#  '4939801',
#  'J01308318',
#  '03383730',
#  '3249496',
#  '154277',
#  '4968393',
#  '4950383',
#  '5405129',
#  '199568',
#  'AX1006503',
#  'A060K940',
#  '3593410',
#  '01856567',
#  '0403640204',
#  '3411370',
#  'KIT3238606',
#  '3008847',
#  '4017194',
#  '3249281',
#  '3914013',
#  '3790201',
#  '4037497',
#  '62182',
#  'A059P172',
#  'A060C750',
#  '5543936',
#  'A060J486',
#  'A060K936',
#  'A042T459',
#  'A051Y594',
#  'A055C964',
#  'A063G245',
#  'A063N867',
#  'A063V407',
#  'RO3641571',
#  'A064C369',
#  '5572828',
#  '5611344',
#  '3238975',
#  '3521817',
#  '502903',
#  '5289626',
#  '4003264',
#  '3027677',
#  '5274349',
#  '5525353',
#  '05021245',
#  '05411234',
#  '0800301719',
#  '4058095',
#  '3229321',
#  '4059455',
#  '3228716',
#  '3228741',
#  '4058968',
#  '3229639',
#  '3229610',
#  '4058964',
#  '3228250',
#  '148076',
#  '3022209',
#  '100671',
#  '3024989',
#  '3022463',
#  '4105621',
#  '4896897',
#  '4042623',
#  '3239268',
#  '4105674',
#  '4964133',
#  '5303406',
#  'A054H720',
#  'A054P343',
#  'A056P729',
#  'A056S555',
#  'SO63159',
#  '3349001',
#  'A052J608',
#  '4105658',
#  '4105319',
#  '4105323',
#  '4105604',
#  '3876071',
#  '3876155',
#  '212603',
#  '3392073',
#  '3376323',
#  '3375459',
#  '3909355',
#  '3902023',
#  '4940117',
#  'AX1006274',
#  '3804938',
#  'AX1001686',
#  'AX1001689',
#  '3810298',
#  '3876097',
#  '3813732',
#  'AR9022',
#  '3937449',
#  '4081093',
#  '3233715',
#  '3233574',
#  '3375935',
#  '3232074',
#  '3233597',
#  '3233604',
#  '3166480',
#  '3232503',
#  '4913129',
#  '4913004',
#  '4913019',
#  'AK6040ST',
#  'AR45224',
#  'AR12780',
#  '4954431',
#  '3338243',
#  'AR13010',
#  '4964687',
#  '4964704',
#  'AX1004657',
#  'AX1004617',
#  'AX1004553',
#  'AX1004572',
#  'AX1004542',
#  'AX1004642',
#  '3287422',
#  '3285102',
#  '3286499',
#  '3336141',
#  '3375278',
#  '3025460',
#  '4968091',
#  '4968133',
#  '4968137',
#  '4964680',
#  'A028Y124',
#  'A065A513',
#  '4978619',
#  '4906023',
#  'A058L339',
#  'A064W138',
#  '5694301',
#  'A062P051',
#  'RX5327831',
#  'A065A409',
#  'A048C856',
#  'A066M747',
#  '3686790',
#  '3058868',
#  'A055Z211',
#  'A066K570',
#  'AX1015539',
#  '5581026',
#  '5264248',
#  '3047575',
#  '4934279',
#  '3949781',
#  'AX1012855',
#  '4089854',
#  '01857050',
#  '5402579',
#  '3863996',
#  '5626215',
#  '5561753',
#  'AX1015938',
#  '30256609017',
#  '4937910',
#  'AX1007390',
#  '5450754',
#  '3969343',
#  '3936838',
#  'A062J296',
#  'A062Y122',
#  '3970799',
#  'RX4044418',
#  'RX3584121',
#  '03385234',
#  '2865101',
#  '4096410',
#  '03006506',
#  '03006503',
#  '03006510',
#  '03006569',
#  '3415318',
#  '3415658',
#  'A062T986',
#  'A062T987',
#  '5411406',
#  '4054091',
#  '0334230002',
#  'A043V941',
#  '0800662037',
#  '0319738902',
#  '01554694',
#  'A046E940',
#  '0870224805',
#  'A045L600',
#  'A041Z162',
#  '0332392702',
#  'A041X346',
#  '0155501002',
#  '0319606202',
#  '3168221',
#  '4350611',
#  '0130727802',
#  '4350628',
#  '4334445',
#  '4328170',
#  'A043N002',
#  '01855908',
#  '01855893',
#  '01856000',
#  '01856985',
#  '01855866',
#  '4001152',
#  '0800661934',
#  '0800661952',
#  '0800661947',
#  '0800661946',
#  '0800661932',
#  '0800661970',
#  '0800661942',
#  '0800661944',
#  '0800661972',
#  '4323082',
#  '3959841',
#  '5405754',
#  '0320247904',
#  '0320247905',
#  '0320247909',
#  '03073199',
#  'A047A499',
#  'A043F989',
#  'A043S906',
#  '4989115',
#  '2885136',
#  '4939831',
#  '4940611',
#  '4089877',
#  '4948642',
#  '3047992',
#  'AX1013268',
#  'AX1013257',
#  '3090256',
#  '4037629',
#  '3631242',
#  '4932908',
#  '3893850',
#  '3824820',
#  '3683607',
#  '3821470',
#  '119364',
#  '03196949',
#  '03330790',
#  '5264214',
#  '0402077905',
#  '3824424',
#  'J01308608',
#  'AX1012822',
#  '4054071',
#  '4054093',
#  'A048K611',
#  'A048K615',
#  'A048G165',
#  'AX1013754',
#  'A048P490',
#  '05411146',
#  '3287300',
#  '4955521',
#  'A048N787',
#  '3025997',
#  '4345156',
#  '4345166',
#  '4334001',
#  '5303139',
#  '5293884',
#  'A048N508',
#  'A048H279',
#  'A048K954',
#  'AX1001382',
#  'AX1001412',
#  'AX1001415',
#  'AX1001376',
#  'AX1001318',
#  'AX1001320',
#  'RC4913146',
#  'RO3523070',
#  '3882774',
#  '3897387',
#  '3898020',
#  '3898627',
#  '3074422',
#  '211968',
#  'AX1007447',
#  'AX1001426',
#  'AX1001430',
#  'AX1001482',
#  '3230216',
#  '4072921',
#  '4072094',
#  '3627662',
#  'KIT3238327',
#  '4302609',
#  '4030864',
#  '3800765',
#  '5552790',
#  '4963832',
#  '5621847',
#  'A064S132',
#  'A056H970',
#  '3165643',
#  '0323167802',
#  '3000934',
#  '4078400',
#  '3230406',
#  'NI910022198',
#  'NI181027197',
#  '0332402504',
#  'A043K974',
#  'A043K944',
#  'A043L434',
#  'A043L448',
#  'A042Z616',
#  '0320222405',
#  '0319605402',
#  '0403628901',
#  '4944182',
#  '4944183',
#  '4955573',
#  'NI910021655',
#  'NI0E00031',
#  '4982558',
#  '5335052',
#  '500346',
#  'AR96066',
#  'AR96295',
#  '142248',
#  '140205',
#  '120918',
#  '109557',
#  '0503220406',
#  '4938940',
#  '4096694',
#  'A040G506',
#  '5277340',
#  '3640332',
#  '4945814',
#  '3521918',
#  '500943',
#  '501085',
#  '500327',
#  '5419151',
#  '5409684',
#  '5419859',
#  '5554134',
#  '5563435',
#  '5587214',
#  '3627781',
#  '3179672',
#  '3640314',
#  '5373059',
#  'A065P204',
#  '3648157',
#  '5466253',
#  '5419463',
#  '5419450',
#  '5505282',
#  '4312970',
#  '5466563',
#  'A051F130',
#  'A051G202',
#  '00988446',
#  '0800652723',
#  '4333011',
#  '4333020',
#  '5316752',
#  '5289711',
#  'A051K941',
#  'A050A994',
#  'A051L117',
#  'A051L121',
#  '2897654',
#  '3649443',
#  'AX1008843',
#  '4331003',
#  'A051K203',
#  'A051E688',
#  'RX3803360',
#  'RX3810432',
#  'RX3879479',
#  'RX4000590',
#  'RX3878571',
#  'RX3878723',
#  'RX3879164',
#  '03231384',
#  '102483',
#  '05051490',
#  '05090196',
#  '105293',
#  '128129',
#  '124547',
#  '3802627',
#  '3802628',
#  'RO4056378',
#  ...]

# %%
parts = parts.set_index('ITEM')
parts.index = parts.index.astype('str')

# %%
part_dict = parts.agg(list,axis=1).to_dict()

# %%
part_dict
# Out:
# {'4958439': ['ASSEMBLY,ROCKER LEVER'],
#  '3393077': ['CONNECTION,WATER TRANSFER'],
#  '3814720': ['SHIELD,HEAT'],
#  '4894306': ['COMPRESSOR,REFRIGERANT'],
#  'A046W832': ['PLATE'],
#  'C6141211530': ['DOWEL,PIN'],
#  '0800661963': ['SCREW,HEX FLANGE HEAD'],
#  'AK10149SS': ['HOSE,FLEXIBLE'],
#  'AR60740': ['PISTON'],
#  '554013': ['CLAMP,TUBE'],
#  '3046942': ['PLUG,THREADED'],
#  'AX1012769': ['PICKUP,ACTIVE'],
#  '4926782': ['MIXER,AIR FUEL'],
#  '503929A': ['SHIM'],
#  '05070048': ['GEAR-RING'],
#  '3229938': ['PULLEY,ACCESSORY DRIVE'],
#  '3538350': ['TURBOCHARGER'],
#  'AX1014391': ['PRESSURE GAUGE(0-200 MBAR,3/8"BSPM)'],
#  '69751': ['GASKET,LUB OIL FIL COVER'],
#  '4089730NX': ['TURBOCHARGER,HX83 WTRCOOL'],
#  '4042265': ['TURBOCHARGER'],
#  '5269423': ['KIT,INT MAG SWITCH'],
#  'A040F057': ['PIPE WATER'],
#  '4919360': ['FIXTURE,CYL HEAD LIFTING'],
#  '5269717': ['TUBE,OIL GAUGE'],
#  '3016344': ['PULLEY,IDLER'],
#  '5278762': ['FILLER CAP'],
#  '80010477': ['FR8 DE BRG CAP (6232) M/C'],
#  '217008': ['SPACER,BEARING'],
#  '3642922': ['CLAMP,U BOLT'],
#  '3249599': ['PARTS,CATALOG'],
#  '4939853': ['HARNESS,WIRING'],
#  'A034S891': ['GENERATOR'],
#  'A034N735': ['HARNESS,INTERFACE'],
#  '3249587': ['PARTS,CATALOG'],
#  '3249733': ['PARTS,CATALOG'],
#  '3086060': ['TUBE,FUEL SUPPLY'],
#  'RX3232595': ['RECONDITIONED RADIATOR'],
#  '556711': ['LOCKPLATE'],
#  '05170477': ['PULG-DRAIN'],
#  'AX1005736': ['HEAD,CYLINDER ASSLY'],
#  '03324404': ['TERMINAL BLOCK (ZDK 2,5)'],
#  '3636373': ['GASKET,CONNECTION'],
#  'AX1007495': ['THERMOSTAT'],
#  '4922210': ['CONNECTION,WATER OUTLET'],
#  '01856503': ['OIL SHIELD-BREATHER'],
#  '4007663NX': ['HEAD,CYLINDER'],
#  '5413017': ['BELT,V RIBBED'],
#  'S510': ['PIN,COTTER'],
#  'A046G653': ['VALVE,CHECK'],
#  '0333063402': ['HEATER,COOLANT'],
#  '3877208': ['TUBE,AFTERCOOLER'],
#  '4101372': ['ALTERNATOR'],
#  '01856574': ['LEAVER ASSY'],
#  '3249442': ['PARTS,CATALOG'],
#  'C6204211610': ['SCREW,HEX FLANGE HEAD CAP'],
#  '4105926': ['HARNESS,WIRING'],
#  '3015545': ['GASKET,WTR TRF CONNECTION'],
#  '4054729': ['HARNESS,WIRING'],
#  '3235613': ['SPRING,COMPRESSION'],
#  '9278': ['GASKET GEN DR BRG CAGE'],
#  '211722': ['TUBE,CPR WATER OUTLET'],
#  'A052E125': ['CABINET'],
#  'A066E748': ['BRACKET,ENGINE MOUNTING'],
#  'A052W678': ['COUPLING KIT,F0,SAE7.5,1B'],
#  '3001722': ['SUPPORT,OIL COOLER'],
#  '4007582': ['CLAMP,U BOLT'],
#  '4928594': ['SENSOR,PRESSURE'],
#  '115034': ['LEVER,ANEROID CONTROL'],
#  '3970546': ['HARNESS,WIRING'],
#  '3054219': ['INJECTOR'],
#  '3878275': ['TUBE,WATER OUTLET'],
#  'S123B': ['SCREW,HEXAGON HEAD CAP'],
#  '3052587': ['SEAL,O RING'],
#  'AK10075SS': ['HOSE,FLEXIBLE'],
#  '3873807': ['ADAPTER,REDUCING'],
#  '3814032': ['MUFFLER'],
#  'RX3085964': ['RECONDITIONED, CROSSHEAD VALVE QSK19'],
#  '3877027': ['ISOLATOR,VIBRATION'],
#  'A041S481': ['PIPE,AIR INLET'],
#  '500412': ['GAUGE,TEMPERATURE'],
#  '4372338': ['PUMP,WATER'],
#  '3016787': ['SEAL,OIL'],
#  '3002956': ['TUBE,WATER TRANSFER'],
#  '3863522': ['CLAMP,HOSE'],
#  'RXC6008631410': ['RECONDITIONED MOTOR STARTING 4B3.3'],
#  'AX1014203': ['RADIATOR'],
#  '3081076': ['GASKET,EXHAUST MANIFOLD'],
#  '3414584': ['HOSE,FLEXIBLE'],
#  '3815914': ['HARNESS,WIRING'],
#  '213485': ['TUBE,WATER BYPASS'],
#  '3963983': ['WASHER,SEALING'],
#  '3052820': ['VALVE,INTAKE'],
#  '3920603': ['HOSE,FLEXIBLE'],
#  'S995': ['PLUG,PIPE'],
#  '4957919': ['HOSE,PLAIN'],
#  '108307': ['DRAINCOCK'],
#  '3046419': ['ROD,PUSH'],
#  '3054889': ['SCREW,HEX FLANGE HEAD CAP'],
#  'AK4030SS': ['HOSE,FLEXIBLE'],
#  '4084887': ['HARNESS,WIRING'],
#  '0338387001': ['HARNESS,EXTENSION'],
#  'AX1015308': ['SCHNEIDER AUXILLIARY CONTACT 1C/O, TYPE 29450 FOR CVS/NSX MCCB'],
#  '4386219': ['NUT,HEXAGON FLANGE'],
#  '3411290': ['CAMSHAFT'],
#  'A047R074': ['HARNESS,ENGINE'],
#  '3201919': ['GEAR & SHAFT'],
#  '3167816': ['CONNECTION,EXHAUST OUTLET'],
#  '5276769': ['SWITCH,OVERSPEED'],
#  '01305709': ['CORE-RADIATOR (JW)'],
#  '3392672': ['HOSE,FLEXIBLE'],
#  '2880044': ['GASKET,EXH OUT CONNECTION'],
#  'A040L186': ['HOSE,FUEL'],
#  '4007165': ['GASKET,GEAR HOUSING'],
#  '3166619': ['COVER,TOR CNV OIL COOLER'],
#  '4957714': ['CLAMP,T BOLT'],
#  '4089368': ['SET,UPPER ENGINE GASKET'],
#  'RX3533197': ['RECONDITIONED TURBOCHARGER'],
#  '3916302': ['SWITCH,MAGNETIC'],
#  '3279720': ['CUP,INJECTOR'],
#  '3249459': ['PARTS,CATALOG'],
#  '3635035': ['LEVER,IDLER'],
#  'ST1264': ['SPACER'],
#  'ST1318': ['TOO,CHAMFER'],
#  'ST1327': ['GAUGE,RING'],
#  '3817029': ['TUBE,WATER INLET'],
#  '3945268': ['HOSE,MOLDED'],
#  '3944167': ['BEARING,CRANKSHAFT THRUST'],
#  '3943740': ['SHAFT,SHUTOFF VALVE'],
#  '3957592': ['MOTOR,STARTING'],
#  '3945918': ['SET,MAIN BEARING (010)'],
#  '3964093': ['HOUSING,BREATHER'],
#  '4021058': ['SHIELD,HEAT'],
#  '4021362': ['QSV91G PARTS CATALOG'],
#  '4021371': ['QST30 GEN DRIVE WIRE DIAG'],
#  '3255321': ['UNION,MALE'],
#  '3255764': ['BOX,ELECTRICAL'],
#  '3253714': ['CLAMP,WIRE TIE'],
#  '3635124': ['ALTERNATOR'],
#  '3635129': ['HOSE,FLEXIBLE'],
#  '3277099': ['SEAL,RECTANGULAR STRIP'],
#  '3638603': ['HOSE,FLEXIBLE'],
#  '144490': ['SPRING,COMPRESSION'],
#  'RX4956667': ['RECONDITIONED  PUMP FUEL'],
#  '4027881': ['TURBOCHARGER REPAIR KIT'],
#  'A052P683': ['HARNESS,GENSET'],
#  '01866685': ['ELEMENT-AIR CLNR'],
#  'T83302910': ['ROTATING RECTIFIER DD 89 N 14 K 1400 V'],
#  '01308485': ['SHROUD-RADIATOR'],
#  '4085324': ['RADIATOR'],
#  '500851': ['PIPE,WATER INLET'],
#  '4992163': ['DATA,PERFORMANCE CONTROL'],
#  '4089201': ['SET,QUADRANT AFTCLR GSKT'],
#  'A044K217': ['HOSE,FUEL'],
#  '3002425': ['TUBE,LUB OIL SUCTION'],
#  '5405345': ['TUBE,FUEL SUPPLY'],
#  '0155496904': ['GASKET-EXHAUST'],
#  '4945007': ['CONNECTION,WATER INLET'],
#  '3955069': ['RING,SPEED INDICATOR'],
#  '01308324': ['FAN-RADIATOR'],
#  '3018767': ['SPRING,COMPRESSION'],
#  'AX1005298': ['HOSE,MAKE-UP LINE'],
#  'AX1006173': ['TANK,BOTTOM'],
#  '3001352': ['PIECE'],
#  'J0402000505': ['ISOLATOR AVA P5/14MF'],
#  '138993': ['SPRING,COMPRESSION'],
#  '2882673': ['"FILTER,LUBRICATING OIL"'],
#  '05090590': ['SEAL-O RING'],
#  '143085': ['SPACER FAN'],
#  '3245111': ['COVER,HAND HOLE'],
#  '4936026': ['THERMOSTAT'],
#  '3925964': ['HOSE,PLAIN'],
#  '3092716': ['SHIELD,HEAT'],
#  '3685960': ['PLATE,POSITION SENSOR'],
#  '4950612': ['PLUG,THREADED'],
#  'AX1006073': ['HYDRAULIC FILTER'],
#  '3901764': ['RING,RETAINING'],
#  'RX3873947': ['RECONDITIONED RADIATOR'],
#  '3968806': ['CORE,COOLER'],
#  'A040K585': ['BREAKER,CIRCUIT'],
#  '2881910': ['KIT,TURBOCHARGER'],
#  '3920802': ['PLUG,THREADED'],
#  '3931914': ['HOSE,ELBOW'],
#  '3249324': ['PARTS,CATALOG'],
#  '0149233102': ['PUMP-ELEC FUEL'],
#  '4946299': ['COMPRESSOR,AIR'],
#  '4095922': ['CLAMP,HOSE'],
#  '5333474': ['TUBE,INJECTOR FUEL SUPPLY'],
#  '3249337': ['PARTS CATALOGE KTA-2300-G'],
#  '3630242': ['MANIFOLD,EXHAUST'],
#  '123146': ['GASKET,CONNECTION'],
#  '3904648': ['GASKET,COVER'],
#  '05202703': ['STUD'],
#  '3103372': ['TUBE,WATER OUTLET'],
#  '3393581': ['WASHER,PLAIN'],
#  'A065K044': ['RETURN LINE'],
#  '4345071': ['BRACKET,WATER TUBE'],
#  '4911618': ['NIPPLE,COUPLING'],
#  'AX1005396': ['ASSEMBLY,THROTTLE STOP'],
#  '02490797': ['DIODE/VARISTOR KIT (TEXT)'],
#  '3920758': ['HOUSING,GEAR'],
#  '3918667': ['SUPPORT,FRONT ENGINE'],
#  '3624451': ['C SERIES INDUSTRIAL POSTR'],
#  '3636085': ['HOUSING,GEAR'],
#  '3005590': ['SPACER,FAN PILOT'],
#  '01307792': ['GUARD-RADIATOR FAN'],
#  '3933841': ['VALVE,FUEL FLOW'],
#  '3666075': ['M11 SERIES ENG SHOP MANUA'],
#  '3666119': ['B5,9G WIRING DIAGRAM'],
#  '01492954': ['BRACKET-FUEL FILTER'],
#  'AX1009058': ['PIPE,FIP CYL 3'],
#  '3049145': ['ADAPTER,PROBE'],
#  '3095130': ['PULLEY,ACCESSORY DRIVE'],
#  '5529797': ['PUMP,FUEL TRANSFER'],
#  '3375470': ['FILLER,HIGH PRESSURE LINE'],
#  '4085307': ['TUBE,WATER INLET'],
#  'AR9633': ['SHAFT & PLUG, ROCKER LEVE'],
#  '3937660': ['BELT,V RIBBED'],
#  '4945774': ['COVER,LUB OIL PUMP'],
#  '4954880': ['PUMP,GEAR FUEL'],
#  '0320229101': ['BREAKER-CIRCUIT (50 A,3 POLE MCCB)'],
#  '3906790': ['TUBE,FUEL SUPPLY'],
#  '3523592': ['IMPELLER,TUR COMPRESSOR'],
#  '3874949': ['CLAMP,TUBE'],
#  'AX1005907': ['ELEMENT AIR CLEANER, OUTER'],
#  '505409': ['BEARING,ROLLER'],
#  '0130798602': ['HEAT EXCHANGER'],
#  '4963703': ['BRACKET,EXPANSION TANK'],
#  '4020488': ['BRACKET,FILTER'],
#  '3877466': ['TUBE,WATER TRANSFER'],
#  '3232953': ['BRACKET,CARBURETOR'],
#  '3280796': ['PUMP,FUEL INJECTION'],
#  '3392318': ['CLEANER,AIR'],
#  '5260025': ['INJECTOR'],
#  '3250939': ['BRACKET,OIL TUBE'],
#  'NI910036134': ['ADDITIONAL COMPONENT - UDC 2 N+'],
#  '3231517': ['CONTROL,SAFETY'],
#  '3085857': ['SLEEVE,WEAR'],
#  'AX1002142': ['PIPE MAKE UP'],
#  '3930668': ['TUBE,FUEL SUPPLY'],
#  '216864': ['SPRING,COMPRESSION'],
#  '3176910': ['SCREW,HEXAGON HEAD CAP'],
#  '3911570': ['BELT,V RIBBED'],
#  '03065442': ['ACTUATOR'],
#  '5525521': ['CONNECTION,AIR TRANSFER'],
#  '3167054': ['CONNECTOR,MALE'],
#  '3287423': ['HOSE,FLEXIBLE'],
#  '0200331203': ['GENERATOR ASSY'],
#  'AX1013566': ['LONG BLOCK.6BTAA-5.9-C.125 HP@2200 RPM_BS-III'],
#  'A046E840': ['INSULATION,PANEL'],
#  '05021659': ['BOLT-BANJO'],
#  '3034958': ['RELAY'],
#  '3681898': ['SCREW,SOCKET HEAD CAP'],
#  'C0143520612': ['SCREW,HEX FLANGE HEAD CAP'],
#  '4027924': ['CORE ASSEMBLY HT3B'],
#  '4020538': ['CONNECTION,AIR INTAKE'],
#  'A056T663': ['KIT,ACCESSORIES'],
#  'A054G986': ['SKID,BASE'],
#  '23010269': ['UCD22 SAE11,5 CPLNG DISC 1.2MM'],
#  '3903384': ['RING,OIL PISTON'],
#  '05033234': ['CLAMP-HOSE'],
#  'AX1005631': ['FUSE,3 PHASE'],
#  'AX1005568': ['RADIATOR, MAIN-KTA19G4'],
#  '3872373': ['HOSE,FLEXIBLE'],
#  '216693': ['LINK,ADJUSTING'],
#  '4950114': ['SUPPORT,FRONT ENGINE'],
#  '4054901': ['TUBE,WATER TRANSFER'],
#  'AX1015141': ['OEN SOCKET FOR 31-4R-3C/O RELAY - P/N: 31-9700-310'],
#  'HCI54C400B1': ['400 KVA, ALTERNATOR, 3PH,50HZ,HCI54C, NO AVR, WITH CT'],
#  '4323079': ['PISTON,ENGINE'],
#  '3088308': ['LEVER ROCKER'],
#  '4309353NX': ['KIT,WATER PUMP'],
#  'AX1005380': ['COVER MODULAR HE, LTA FRONT'],
#  '3928229': ['NOZZLE,INJECTOR'],
#  '05032196': ['HOSE,COOLANT'],
#  '03005315': ['CONTROL ASSEMBLY'],
#  '3225171': ['SCREW,HEXAGON HEAD CAP'],
#  '3684414': ['TUBE,OIL FILLER'],
#  '4998570': ['CHANNEL PLATE'],
#  '44676': ['SLEEVE,WEAR'],
#  '3238077': ['SERVICE KIT IND 6BT'],
#  'A049M997': ['PIPE,WATER'],
#  '196112': ['BREAKER,CIRCUIT'],
#  '4911991': ['LEVER,THROTTLE'],
#  '3874472': ['TUBE,FUEL DRAIN'],
#  '03385342': ['HARNESS,ENGINE'],
#  'AX1006416': ['MONITOR GENSET EFFICIENCY'],
#  '3094045': ['SEAL,O RING'],
#  'AX1013192': ['WOUND EXCITER STATOR,25MM_BC16(A,B,C,D)'],
#  'AX1015294': ['CAPACITIVE FUEL LEVEL SENSOR WITH 0-5VDC O/P-175MM WITH'],
#  'A063D324': ['HARNESS,ENGINE'],
#  '4015881': ['HARNESS,WIRING'],
#  '4009247': ['PIN,CAM FOLLOWER ROLLER'],
#  '3283686': ['STUD'],
#  '4955665': ['KIT,OIL SEAL'],
#  '4033542': ['TURBOCHARGER,AFTERMARKET'],
#  '3044849': ['TUBE,PRESSURE SENSING'],
#  'AX1004914': ['PIPE LUB OIL PUMP DELIVERY'],
#  '3234881': ['COVER,HYD PUMP FLANGE'],
#  '3167927': ['DATAPLATE'],
#  '3911586': ['BELT,V RIBBED'],
#  '2865104': ['WASHER,SEALING'],
#  '198962': ['TUBE,WATER INLET'],
#  '3644292': ['MOTOR,STARTING'],
#  'AX1002250': ['BOARD PC -DISPLAY- AMF'],
#  'A061B617': ['TUBE,AIR'],
#  '3233112': ['TUBE,AIR INLET'],
#  '0309064105': ['SWITCH-PRESSURE'],
#  'AK160306MS': ['HOSE,FLEXIBLE'],
#  '4918725': ['KIT,WIRING HARNESS REPAIR'],
#  '3094028': ['PLUG,EXPANSION'],
#  'A064G364': ['BRACKET,HEAT SHIELD'],
#  '4020483': ['TUBE,WATER MAKEUP'],
#  'AX1014274': ['AIR FILTER,SAFETY'],
#  '01855777': ['BEARING-BALL'],
#  '3637752': ['HOSE,FLEXIBLE'],
#  '3817032': ['TUBE,AIR TRANSFER'],
#  '3379182': ['PT(TYPE G)FP CALIB VALUES'],
#  '3898182': ['AUDIO CASS QSK19 FS'],
#  '4964229': ['MANIFOLD,FUEL'],
#  '4963544': ['CONNECTOR,BANJO'],
#  '3245082': ['COVER,HAND HOLE'],
#  '3240697': ['HUB,FAN'],
#  '3594172': ['TURBOCHARGER'],
#  '3092904': ['TUBE,WATER TRANSFER'],
#  '3376495': ['SET,DRILL/REAM BUSHING'],
#  'J01308849': ['TOP TANK, AC TT-98-0300'],
#  '3932529': ['SOLENOID,FUEL PUMP'],
#  'AX1005536': ['ELEMENT, AIR CLEANER OUTER'],
#  '3638475': ['BRACKET,SHOCK ABSORBER'],
#  '01306623': ['TUBE-RADIATOR VENT'],
#  'AX1012937': ['FILTER,HYDRAULIC SPIN-ON'],
#  '3645962': ['HOSE,FLEXIBLE'],
#  'AX1006267': ['FILTER,LUB OIL'],
#  '4955525': ['KIT,INJECTOR'],
#  'A046W412': ['PANEL,CONTROL BOX'],
#  'AX1002662': ['ACOUSTIC ENCLOSURE  2X500 kVA, 1X250 kVA & 1X125 kVA'],
#  '3804891': ['VALVE INTAKE'],
#  '5339449': ['CLIP'],
#  'A054Y263': ['SWITCH,PUSH BUTTON'],
#  '5310311': ['"CLEANER,AIR"'],
#  'A041F023': ['PANEL,ENCLOSURE'],
#  '3863993': ['SCREW,HEX FLANGE HEAD CAP'],
#  '4068583': ['HEAD,FUEL FILTER'],
#  'A042L827': ['BRACKET,HEAT SHIELD'],
#  '3417958': ['COMPRESSOR,AIR'],
#  '4096470': ['TUBE,FUEL TRANSFER'],
#  '4100433': ['FILTER,BODY'],
#  'AK4018MS': ['HOSE,FLEXIBLE'],
#  '2885348': ['KIT,GOV BARREL & PLUNGER'],
#  '4095525': ['PLATE,COVER'],
#  '05410809': ['CONTROLKIT (DOM NCM)'],
#  '3965953': ['MODULE,ELECTRONIC CONTROL'],
#  '3408345': ['SENSOR,TEMPERATURE'],
#  '3026236': ['CONNECTION,EXHAUST OUTLET'],
#  '3028180': ['TUBE,WATER BYPASS'],
#  '2872792': ['SENSOR,TEMPERATURE'],
#  '4948168': ['TUBE,OIL GAUGE'],
#  '3004259': ['PLUG,EXPANSION'],
#  '3089796': ['ASSY,CRANKSHAFT'],
#  '3414420': ['PLUG,O RING'],
#  'AR5109': ['PULLEY,FAN'],
#  '3236888': ['CONNECTION,WATER TRANSFER'],
#  '3865155': ['BODY,LUBRICATING OIL PUMP'],
#  '4955955': ['KIT,LUBE PUMP'],
#  'RO4382239': ['RECONDITIONED CYLINDER HEAD QSK60 G'],
#  '01305554': ['FAN'],
#  '3166878': ['CONNECTION,OIL SUCTION'],
#  '3942748': ['LEVER,ROCKER'],
#  '3376754': ['REAMER,OS VALVE GUIDE'],
#  '207535': ['GASKET,WTR TRF CONNECTION'],
#  'AX1014893': ['AIR FILTER SAFETY'],
#  '3052170': ['HOUSING, ROCKER'],
#  'S115A': ['SCREW,HEXAGON HEAD CAP'],
#  '3230434': ['GEAR,HYDRAULIC PUMP'],
#  '5340055': ['ALTERNATOR'],
#  '3240325': ['HEAD,CYLINDER'],
#  '3201060': ['COVER,HAND HOLE'],
#  '3288845': ['BELT,V RIBBED'],
#  '3910755': ['INSERT'],
#  '3929028': ['GEAR,CAMSHAFT'],
#  '3897538': ['CONNECTION,AIR CROSSOVER'],
#  '4980390': ['BRACE,ALTERNATOR'],
#  '3607276': ['VALVE,PRESSURE REGULATOR'],
#  '4036307': ['SLINGER,OIL'],
#  'A034W239': ['PUMP,FUEL'],
#  '4105981': ['WASHER,PLAIN'],
#  '4069778': ['TUBE,INJECTOR FUEL SUPPLY'],
#  '101834': ['CAP,BYPASS VALVE'],
#  '3230211': ['COVER,PROTECTIVE'],
#  '5300876': ['CONNECTION,ADAPTER'],
#  '505324': ['GUARD,FAN'],
#  'A061W593': ['ADAPTER,PIPE'],
#  '3330658': ['BODY,CONTROL VALVE'],
#  '3069689': ['CROSSHEAD,VALVE'],
#  'AX1012966': ['KIT,INTAKE SYSTEM UPFIT QSK23C'],
#  '3875323': ['PULLEY,ALTERNATOR'],
#  '3966450': ['HEAD,CYLINDER'],
#  'A055S175': ['LEAD,CABLE'],
#  'RX4020861': ['RECONDITIONED RADIATOR'],
#  '3781591': ['TURBOCHARGER'],
#  'A050T563': ['PANEL,DUCT'],
#  '0200313602': ['GENERATOR ASSY (ALT HC4)   HC4'],
#  '4970363': ['DATAPLATE'],
#  '4096049': ['PAD,WEAR'],
#  '01320475': ['PUMP-WATER (REMOTE)'],
#  '3897972': ['SHIELD,HEAT'],
#  '178572': ['BELT,V'],
#  '3228265': ['CONNECTION,AIR CROSSOVER'],
#  '3229212': ['SHAFT,ACCESSORY DRIVE'],
#  'AK4088SS': ['HOSE,FLEXIBLE'],
#  '4104880': ['HARNESS,WIRING'],
#  '4918212': ['COMPRESSOR,PISTON RING'],
#  '206511': ['SCREW,TWELVE POINT CAP'],
#  'AX1014471': ['LONG BLOCK ISB-5.9-G'],
#  'A051N572': ['PANEL,CONTROL'],
#  '5305340': ['GASKET,CYLINDER HEAD'],
#  '4334668': ['DATA,INSTALLATION TRIM'],
#  'AX1003734': ['RECONDITIONED ELECT.CONTROL PANEL FOR 40 KVA DG SET'],
#  '3412920': ['SHAFT,SHUTOFF VALVE'],
#  '3098353': ['PUMP,FUEL'],
#  '3082573': ['SEAL,O RING'],
#  '102397': ['STUD'],
#  'AX1004735': ['CONNECTION WATER OUTLET TAP'],
#  '3177198': ['ELBOW,MALE UNION'],
#  '3636262': ['TUBE,WATER TRANSFER'],
#  '2879299': ['KIT,NC TO HE K-50G3'],
#  'AX1003670': ['RECONDITIONED BASE RAIL FOR 50 KVA DG SET'],
#  '3974642': ['SWITCH,TEMPERATURE'],
#  '4086588': ['CLAMP,T BOLT'],
#  '3420742': ['"ELEMENT,LUB OIL FILTER"'],
#  '5394247': ['ADAPTER,INSTALLER'],
#  'RO3076703': ['INJECTOR RECON'],
#  '3392749': ['CONNECTOR,MALE'],
#  '3970139': ['TUBE,AIR'],
#  'NI910042937': ['EXCITER ROTOR DSG74'],
#  '4330744': ['TUBE,TUR OIL DRAIN'],
#  '4956000': ['SET,LOWER OIL PAN GASKET'],
#  '5302028': ['PAN,OIL'],
#  '2873258': ['EXTENSION,SPARK PLUG'],
#  '3909394': ['DRAINCOCK'],
#  'A061M513': ['BRACKET,SENSOR'],
#  'RX3913269': ['RECONDITIONED PUMP FUEL'],
#  '3879460KE214': ['PUMP,FUEL W CAL CODE'],
#  '4348577': ['PIPE,WATER OUTLET'],
#  '3092610': ['GEAR,LUB OIL PUMPING'],
#  'AX1006125': ['KIT,KNOCK DETECTION'],
#  '4928637': ['SWITCH,PRESSURE'],
#  '3008591': ['GASKET,INTAKE MANIFOLD'],
#  '4950139': ['BRACKET,CRN RESISTOR'],
#  'AX1007553': ['HOSE,FUEL SUCTION'],
#  '3089298': ['HEAD,CORROSION RESISTOR'],
#  'A024J110': ['GTEC-0320-2479-28'],
#  '05032522': ['HOSE-COOLANT (R76265)'],
#  '4913173': ['TUBE,WATER OUTLET'],
#  '3599718': ['TURBOCHARGER'],
#  '3163400': ['TOOL,BUSHING R&I'],
#  'A065N206': ['LINE DIESEL EXHAUST FLUID'],
#  'RO3920867': ['INTAKE VALVE RECON'],
#  'AX1005082': ['WASHER'],
#  '3092246': ['SCREW,ROUND HEAD CAP'],
#  'AX1015953': ['GASKET FIP GEAR INSPECTION COVER'],
#  'AX1006696': ['HEATER,SPACE (240V) BC16 & BC18'],
#  '3814490': ['VALVE,AIR CONTROL'],
#  '64490': ['KEY,SQUARE'],
#  '3824541': ['DISC,ABRASIVE'],
#  'RX3070889': ['RECONDITIONED COVER AFTERCOOLER'],
#  'AX1015955': ['NUT M6X1.00-6 HEX'],
#  '4981575': ['DATA,ENGINE CONFIGURATIO'],
#  '5262624': ['PUMP,FUEL INJECTION'],
#  'KIT4105238': ['KIT PISTON AND RING SET'],
#  '3200943': ['SHAFT,HYD PUMP DRIVE'],
#  '4939857': ['HARNESS,WIRING'],
#  '2865451': ['BRACKET,FUL CONTROL VALVE'],
#  'AX1006448': ['PIN,SAFETY'],
#  '4990979': ['HARNESS,WIRING'],
#  'A066P898': ['TUBE,COOLANT'],
#  '3249566': ['PARTS,CATALOG'],
#  '4083954': ['CAMSHAFT'],
#  '4912678': ['HOSE,FLEXIBLE'],
#  '5279084': ['ADAPTER,O RING'],
#  '4919767': ['TERMINAL,ELC CNR REPAIR'],
#  '3529035': ['TURBOCHARGER'],
#  '3680140': ['ALTERNATOR'],
#  '3008876': ['SUPPORT, A.C. TUBE'],
#  '3685860': ['WASHER,PLAIN'],
#  '3288678': ['BELT,V RIBBED'],
#  '4053630': ['CONNECTION,WATER OUTLET'],
#  'KIT3880634': ['KIT CYL LINER PISTON & RING SET'],
#  '3074354': ['SCREW,TWELVE POINT CAP'],
#  '03384739': ['HARNESS-AC (POWERCOM PT/CT)'],
#  '3804666': ['ENGINE GASKET SET LOWER'],
#  'A054L670': ['CABLE'],
#  '5563305': ['KIT,PISTON RING'],
#  '3698067': ['PUMP,WATER'],
#  '137990': ['SCREW,HEXAGON HEAD CAP'],
#  '01855502': ['PLUG'],
#  '4926762': ['TUBE,CPR WATER INLET'],
#  '4055717': ['PULLEY,CRANKSHAFT'],
#  '3523556': ['HOUSING,COMPRESSOR'],
#  '2868200': ['RADIATOR'],
#  'A049J724': ['PANEL,GUARD'],
#  '4105839KF95': ['PUMP,FUEL W CAL CODE'],
#  '500946': ['BRACKET FUEL FILTER'],
#  '218499': ['PULLEY,WATER PUMP SHEAVE'],
#  '4068549': ['PLATE,COVER'],
#  '3886350': ['PRO KIT,INPOWER 0.2 G-DRI'],
#  '4926959': ['TUBE,COMPRESSOR AIR INLET'],
#  '4086158': ['ADAPTER,REDUCING'],
#  '5583127': ['HEAD,LUB OIL FILTER'],
#  '4912604': ['KIT RADIATOR(KTA38-G5)'],
#  'A062T785': ['MANUAL,OPERATOR'],
#  '0304083103': ['BRACKET ASSY-RES'],
#  '5324151': ['TURBOCHARGER'],
#  '01819124': ['GASKET-CRANKCASE'],
#  '3863822': ['SCREW,HEXAGON HEAD CAP'],
#  '3923883': ['RING,CLAMPING'],
#  '208118': ['PULLEY,IDLER'],
#  '3877688': ['PULLEY,FAN'],
#  '4105956': ['CIRCUIT,INTEGRATED'],
#  '500343': ['BEARING,ROLLER'],
#  '3685700': ['SPACER,THREADED'],
#  'A044X404': ['MOUNT,ANTIVIBRATION'],
#  '3246528': ['SUPPORT,RADIATOR'],
#  '3957380': ['PIPE,AIR TRANSFER'],
#  '3236300': ['SCREW,HEXAGON HEAD CAP'],
#  'AX1006280': ['THERMOCOUPLE'],
#  '200584': ['BEARING,MAIN'],
#  '3877719': ['SPACER,BEARING'],
#  'RXAR40039': ['RECONDITIONED INJECTOR'],
#  '5286815': ['MOTOR,STARTING'],
#  '4953321': ['GEAR,CAMSHAFT'],
#  '4104509': ['SWITCH,TEMPERATURE'],
#  '5363429': ['MOTOR,STARTING'],
#  'A051H103': ['HARNESS,GENSET'],
#  '207312': ['COVER,HAND HOLE'],
#  '0860212721': ['NUT-HEX'],
#  '3225305': ['SUPPORT,FLYWHEEL HOUSING'],
#  '3053159': ['SPRING,COMPRESSION'],
#  '3533163': ['RING,RETAINING'],
#  'AX1007254': ['T-SHIRT CUMMINS GENUINE PARTS'],
#  '4055380': ['CONNECTION,WATER BYPASS'],
#  '2879966': ['TUBE,WATER TRANSFER'],
#  '01403890': ['GASKET-AIR CLEANER'],
#  'AX1006858': ['UC27H MN RTR REWINDING KIT'],
#  '3800529': ['LB REBUILD KIT'],
#  'RX4089981': ['KIT,ACTUATOR'],
#  '145551': ['SEAL,O RING'],
#  'KIT4968318': ['KIT INJECTOR AND LINK'],
#  '3231923': ['GAUGE,SIGHT'],
#  '01857076': ['RING ASSY'],
#  '3641139': ['TUBE,FUEL DRAIN'],
#  '205466': ['PLUNGER,INJECTOR'],
#  '4941369': ['DATA,SYSTEM CONTROL'],
#  '3029626': ['SEAL,O RING'],
#  '4975709': ['HOSE,FLEXIBLE'],
#  '4000713': ['GASKET,AFTERCOOLER COVER'],
#  'AX1013240': ['ASSLY,CONTAINERISED ACOUSTIC ENCLOSURE_125KVA DG SET'],
#  '3974600': ['PUMP,FUEL INJECTION DELPH'],
#  '3017993': ['VALVE,SHUTOFF'],
#  '3594034': ['TURBOCHARGER'],
#  '4926703': ['ROD,CONTROL'],
#  '3332148': ['PLUG,O RING'],
#  '5295568': ['SOLENOID,FUEL PUMP'],
#  '4080535': ['HOSE,FLEXIBLE'],
#  'C6204114810': ['PLATE,COVER'],
#  '141634': ['PLUNGER,IDLE SPRING'],
#  'BM40951': ['PLUNGER,GOVERNOR'],
#  '3524421': ['DIFFUSER,TURBOCHARGER'],
#  '4962840': ['SWITCH,TEMPERATURE'],
#  '3335044': ['SCREW,HEXAGON HEAD CAP'],
#  'AR5115': ['PULLEY,FAN'],
#  'AR5125': ['PULLEY,FAN'],
#  '4980030': ['CONNECTION,WATER OUTLET'],
#  '4930897': ['TENSIONER,BELT'],
#  '3970976': ['FLYWHEEL'],
#  '3249559': ['PARTS CATALOG'],
#  '3413810': ['TUBE,WATER MAKEUP'],
#  '05052550': ['FLANGE-PIPE'],
#  '3042591': ['GASKET,OIL PAN'],
#  '4387613': ['TANK,DIESEL EXHAUST FLUID'],
#  '03385329': ['HARNESS-AC'],
#  '3935326': ['ALTERNATOR'],
#  '5405482': ['TUBE,FUEL DRAIN'],
#  '4901349': ['SCREW,HEX FLANGE HEAD CAP'],
#  '3873050': ['RADIATOR'],
#  '4065739': ['LEVER,ROCKER'],
#  '3234949': ['TUBE,LUB OIL TRANSFER'],
#  'RO2879737KE374': ['RECON PUMP,FUEL'],
#  'AX1016296': ['HYDRAULIC FILTER'],
#  '3226062': ['BRACKET,OVERSPEED CONTROL'],
#  '102296': ['GASKET,GOV DRIVE COVER'],
#  '3898495': ['FUL SYS TROU/REPR PAL VID'],
#  '3069114': ['TUBE,FUEL SUPPLY'],
#  'BM54901': ['PUMP,FUEL MTG'],
#  '4939801': ['HARNESS,WIRING'],
#  'J01308318': ['SUPPORT-MOUNT HE-00-0420-1'],
#  '03383730': ['HARNESS-EXTENSION'],
#  '3249496': ['PARTS CATALOG'],
#  '154277': ['SCREEN FUEL FILTER'],
#  '4968393': ['KIT,INJECTOR AND LINK'],
#  '4950383': ['SUPPORT,THM HOUSING'],
#  '5405129': ['MANIFOLD,EXHAUST'],
#  '199568': ['GASKET,INTAKE MANIFOLD'],
#  'AX1006503': ['VOLTAGE,TRANSDUCER'],
#  'A060K940': ['LIST,RECOMMENDED SPARES'],
#  '3593410': ['CORE ASSEMBLY HX30W'],
#  '01856567': ['WEIGHT ASSY-GOV'],
#  '0403640204': ['BASE-DRIP PAN'],
#  '3411370': ['HOUSING,THERMOSTAT'],
#  'KIT3238606': ['O RINGS KIT (6)'],
#  '3008847': ['CLAMP,V BAND'],
#  '4017194': ['HOSE,MOLDED'],
#  '3249281': ['PARTS,CATALOGUE'],
#  '3914013': ['PAN,OIL'],
#  '3790201': ['TURBOCHARGER'],
#  '4037497': ['TURBOCHARGER'],
#  '62182': ['COVER,STARTER FLANGE'],
#  'A059P172': ['HEATER,CONTROL'],
#  'A060C750': ['PANEL,CONTROL BOX'],
#  '5543936': ['HOSE,FLEXIBLE'],
#  'A060J486': ['TRAY,BATTERY'],
#  'A060K936': ['LIST,RECOMMENDED SPARES'],
#  'A042T459': ['PANEL,ENCLOSURE'],
#  'A051Y594': ['ENCLOSURE'],
#  'A055C964': ['BRACE,RADIATOR'],
#  'A063G245': ['TUBE,AIR'],
#  'A063N867': ['HOSE,FUEL'],
#  'A063V407': ['EXHAUST,TUBE'],
#  'RO3641571': ['RECONDITIONED HEAD, CYLINDER'],
#  'A064C369': ['COOLER,OIL'],
#  '5572828': ['SOCKET,SPARK PLUG'],
#  '5611344': ['COVER,HAND HOLE'],
#  '3238975': ['KIT, OVERHAUL NT855 BC -DRILL'],
#  '3521817': ['TURBOCHARGER'],
#  '502903': ['FLYWHEEL'],
#  '5289626': ['COVER,VALVE'],
#  '4003264': ['COVER,HAND HOLE'],
#  '3027677': ['FLANGE'],
#  '5274349': ['THERMOSTAT'],
#  '5525353': ['BRACE,TUBE'],
#  '05021245': ['ADAPTER,PIPE'],
#  '05411234': ['CONTROL KIT'],
#  '0800301719': ['SCREW,HEX HEAD CAP'],
#  '4058095': ['HOSE,FLEXIBLE'],
#  '3229321': ['TUBE,WATER OUTLET'],
#  '4059455': ['COVER,GEAR'],
#  '3228716': ['BUSHING'],
#  '3228741': ['CONNECTION,ADAPTER'],
#  '4058968': ['RING,COMPRESSION PISTON'],
#  '3229639': ['CONTROL,SPEED DROOP'],
#  '3229610': ['TUBE,FUEL BYPASS'],
#  '4058964': ['"RESISTOR,CORROSION"'],
#  '3228250': ['LEVER,IDLER'],
#  '148076': ['SHROUD RADIATOR FAN'],
#  '3022209': ['"CARTRIDGE,ASSEMBLY"'],
#  '100671': ['BUSHING'],
#  '3024989': ['CARRIER,GOVERNOR WEIGHT'],
#  '3022463': ['HOUSING,GOVERNOR'],
#  '4105621': ['TUBE,WATER OUTLET'],
#  '4896897': ['GASKET,ACC DRIVE COVER'],
#  '4042623': ['TURBOCHARGER'],
#  '3239268': ['TUBE,WATER DRAIN'],
#  '4105674': ['KIT,CONTROL ANNUNCIATOR'],
#  '4964133': ['ADAPTER,REDUCING'],
#  '5303406': ['SPRING,VALVE'],
#  'A054H720': ['INSULATION,PANEL'],
#  'A054P343': ['INSULATION,PANEL'],
#  'A056P729': ['ISOLATOR,VIBRATION'],
#  'A056S555': ['TOOL,REMOVAL'],
#  'SO63159': ['ENGINE.QSB-5.9-G2.206 BHP @ 1500 RPM AS PER ISO3046.GENSET'],
#  '3349001': ['PUMP,SEA WATER'],
#  'A052J608': ['BAFFLE,EXHAUST'],
#  '4105658': ['HARNESS,WIRING'],
#  '4105319': ['SUBBASE'],
#  '4105323': ['TUBE,FUEL SUPPLY'],
#  '4105604': ['CLEANER,AIR'],
#  '3876071': ['FILTER,HYDRAULIC OIL'],
#  '3876155': ['COUPLING,FLEXIBLE'],
#  '212603': ['SEAL,OIL'],
#  '3392073': ['HOUSING,GEAR'],
#  '3376323': ['KIT,STIRRER GEAR'],
#  '3375459': ['FLANGE,INJ COUPLING ADA'],
#  '3909355': ['ADAPTER,FILTER HEAD'],
#  '3902023': ['SCREW,HEX FLANGE HEAD CAP'],
#  '4940117': ['SCREW,HEX FLANGE HEAD CAP'],
#  'AX1006274': ['ACTUATOR,GAS DF KIT 1MW'],
#  '3804938': ['SET,LOWER ENGINE GASKET'],
#  'AX1001686': ['CUT-AWAY MODEL (ENGINE) - 6BT 5.9 CUT SECTION'],
#  'AX1001689': ['CUT-AWAY COMPONENT - OIL COOLER - N495'],
#  '3810298': ['BULLETIN'],
#  '3876097': ['BULB,LIGHT'],
#  '3813732': ['CONNECTION,WATER OUTLET'],
#  'AR9022': ['PUMP,LUB OIL'],
#  '3937449': ['TUBE,FUEL SUPPLY'],
#  '4081093': ['PUMP,WATER'],
#  '3233715': ['BRACE,RADIATOR'],
#  '3233574': ['SHIM'],
#  '3375935': ['KIT,MARINE TEST'],
#  '3232074': ['PULLEY,CRANKSHAFT'],
#  '3233597': ['CONNECTION,WATER INLET'],
#  '3233604': ['FILTER'],
#  '3166480': ['HOSE,FLEXIBLE'],
#  '3232503': ['CARBURETOR'],
#  '4913129': ['BRACKET,ADJUSTING LINK'],
#  '4913004': ['CIRCUIT,INTEGRATED'],
#  '4913019': ['PANEL,INSTRUMENT'],
#  'AK6040ST': ['HOSE,FLEXIBLE'],
#  'AR45224': ['MANIFOLD, FUEL'],
#  'AR12780': ['SUPPORT,HYDRAULIC PUMP'],
#  '4954431': ['MODULE,ELECTRONIC CONTR'],
#  '3338243': ['SEAL,OIL'],
#  'AR13010': ['PISTON & CONNECTION ROD'],
#  '4964687': ['HOSE,FLEXIBLE'],
#  '4964704': ['CLIP'],
#  'AX1004657': ['PLUG SUMP DRAIN'],
#  'AX1004617': ['STUD'],
#  'AX1004553': ['KIT, ACOUSTIC ENCLOSURE FOR RAILWAY POWERCAR'],
#  'AX1004572': ['NUT'],
#  'AX1004542': ['ACOUSTIC ENCLOSURE FOR POWER HOUSE'],
#  'AX1004642': ['JOINT LUB OIL SUMP FRONT'],
#  '3287422': ['VALVE,CHECK'],
#  '3285102': ['HOUSING,THERMOSTAT'],
#  '3286499': ['HOSE,PLAIN'],
#  '3336141': ['SEAL,O RING'],
#  '3375278': ['GAUGE,0.75 IN HG PRESS'],
#  '3025460': ['PLUG,PIPE'],
#  '4968091': ['HARNESS,WIRING'],
#  '4968133': ['BRACKET,FILTER'],
#  '4968137': ['SUPPORT,HYDRAULIC PUMP'],
#  '4964680': ['HOSE,FLEXIBLE'],
#  'A028Y124': ['HOSE,OIL'],
#  'A065A513': ['PLATE,SUPPORT'],
#  '4978619': ['SPACER,MOUNTING'],
#  '4906023': ['ELBOW,MALE UNION'],
#  'A058L339': ['HOSE,RADIATOR'],
#  'A064W138': ['CLAMP,VEE BAND'],
#  '5694301': ['TUBE,AIR INLET'],
#  'A062P051': ['TUBE,VENT'],
#  'RX5327831': ['RECONDITIONED TURBOCHARGER KTA38C'],
#  'A065A409': ['PIPE,AIR INLET'],
#  'A048C856': ['HOSE,RADIATOR'],
#  'A066M747': ['TUBE,EXHAUST'],
#  '3686790': ['SUPPORT,EXH RCN VALVE'],
#  '3058868': ['COVER,PROTECTIVE'],
#  'A055Z211': ['SHAFT,FAN'],
#  'A066K570': ['PANEL,ENCLOSURE'],
#  'AX1015539': ['PRESSURE LINE BALL VALVE 1"'],
#  '5581026': ['PIPE,WATER INLET'],
#  '5264248': ['PUMP,FUEL'],
#  '3047575': ['WASHER,PLAIN'],
#  '4934279': ['WASHER,SEALING'],
#  '3949781': ['SEAL,O RING'],
#  'AX1012855': ['SEPARATOR,WATER'],
#  '4089854': ['KIT,TURBOCHARGER'],
#  '01857050': ['PIPE ASSY'],
#  '5402579': ['BUSHING'],
#  '3863996': ['SCREW,HEX FLANGE HEAD CAP'],
#  '5626215': ['SEAL,O RING'],
#  '5561753': ['SCREW,FRACTURE RESISTANT'],
#  'AX1015938': ['PIN 13X34 PLAIN DOWEL'],
#  '30256609017': ['PUMP,FUEL'],
#  '4937910': ['HOSE,FLEXIBLE'],
#  'AX1007390': ['COIL OF POWER CONTACTOR  25 AMP 240 V AC'],
#  '5450754': ['HARNESS,WIRING'],
#  '3969343': ['BRACE,TUBE'],
#  '3936838': ['TUBE,CPR WATER OUTLET'],
#  'A062J296': ['ADAPTER,PIPE'],
#  'A062Y122': ['BRACKET,AIR FILTER'],
#  '3970799': ['VALVE,CHECK'],
#  'RX4044418': ['RECONDITIONED TURBOCHARGER'],
#  'RX3584121': ['RECONDITIONED TURBOCHARGER'],
#  '03385234': ['HARNESS-ENGINE'],
#  '2865101': ['NIPPLE,REDUCING HEXAGON'],
#  '4096410': ['TURBOCHARGER'],
#  '03006506': ['PANEL-CONTROL'],
#  '03006503': ['PANEL-CONTROL'],
#  '03006510': ['PANEL-CONTROL'],
#  '03006569': ['PANEL-CONTROL'],
#  '3415318': ['HOSE,FLEXIBLE'],
#  '3415658': ['GASKET,CONNECTION'],
#  'A062T986': ['MANUAL,OPERATOR'],
#  'A062T987': ['MANUAL,OPERATOR'],
#  '5411406': ['MANUAL,SERVICE'],
#  '4054091': ['TUBE,LUB OIL TRANSFER'],
#  '0334230002': ['WIRE-STRANDED (BS6231 RED)'],
#  'A043V941': ['CLIP,CABLE'],
#  '0800662037': ['SCREW,HEX HEAD'],
#  '0319738902': ['PANEL,TERMINAL'],
#  '01554694': ['PIPE-EXHAUST (FLEX)'],
#  'A046E940': ['SILENCER,EXHAUST'],
#  '0870224805': ['M8 LOCKNUT (NYLON INSERT)'],
#  'A045L600': ['BRACKET,ENCLOSURE'],
#  'A041Z162': ['DOOR,ENCLOSURE'],
#  '0332392702': ['TERMINAL BLOCK (END PLATE)'],
#  'A041X346': ['KIT,RETAINER BRACE'],
#  '0155501002': ['MUFFLER,EXHAUST RESIDENTIAL'],
#  '0319606202': ['BOX-TERMINAL (ASSY)'],
#  '3168221': ['HOSE,FLEXIBLE'],
#  '4350611': ['MANIFOLD,AIR INTAKE'],
#  '0130727802': ['BRACKET-RADIATOR (LH SUPPORT)'],
#  '4350628': ['HOUSING,FLYWHEEL'],
#  '4334445': ['SEAL,OIL'],
#  '4328170': ['TEE,MALE RUN'],
#  'A043N002': ['HARNESS,GOVERNOR'],
#  '01855908': ['BUSHING-IDLE GEAR'],
#  '01855893': ['GASKET-BRG CASE COVER'],
#  '01856000': ['PIPE-WATER RETURN'],
#  '01856985': ['GASKET-PUMP COVER'],
#  '01855866': ['GASKET-CYL HEAD'],
#  '4001152': ['TUBE,FUEL DRAIN'],
#  '0800661934': ['SCREW,HEX FLANGE HEAD'],
#  '0800661952': ['SCREW,HEX FLANGE HEAD'],
#  '0800661947': ['SCREW,HEX FLANGE HEAD'],
#  '0800661946': ['SCREW,HEX FLANGE HEAD'],
#  '0800661932': ['SCREW,HEX FLANGE HEAD'],
#  '0800661970': ['SCREW,HEX FLANGE HEAD'],
#  '0800661942': ['SCREW,HEX FLANGE HEAD'],
#  '0800661944': ['SCREW,HEX FLANGE HEAD'],
#  '0800661972': ['SCREW,HEX FLANGE HEAD'],
#  '4323082': ['VALVE,WASTEGATE'],
#  '3959841': ['BELT,V RIBBED'],
#  '5405754': ['KIT,INTAKE VALVE'],
#  '0320247904': ['GTEC TRANSFER SWITCH'],
#  '0320247905': ['GTEC TRANSFER SWITCH'],
#  '0320247909': ['GTEC TRANSFER SWITCH'],
#  '03073199': ['BRACKET-RELAY'],
#  'A047A499': ['BRACKET,ALTERNATOR'],
#  'A043F989': ['PIPE,EXHAUST'],
#  'A043S906': ['PIPE,EXHAUST'],
#  '4989115': ['HEAD,FUEL FILTER'],
#  '2885136': ['SHROUD'],
#  '4939831': ['PANEL,CONTROL'],
#  '4940611': ['HARNESS,WIRING'],
#  '4089877': ['KIT,INJECTOR'],
#  '4948642': ['DATA,PERFORMANCE CONTROL'],
#  '3047992': ['INJECTOR'],
#  'AX1013268': ['ELEMENT,AIR CLEANER INNER'],
#  'AX1013257': ['FILTER,AIR'],
#  '3090256': ['BUSHING'],
#  '4037629': ['TURBOCHARGER'],
#  '3631242': ['KIT,PISTON ENGINE'],
#  '4932908': ['FLANGE,CRANKSHAFT'],
#  '3893850': ['BRACE,FUEL PUMP'],
#  '3824820': ['CONNECTOR,ELECTRICAL'],
#  '3683607': ['SEAL,WATER'],
#  '3821470': ['TUBE,BREATHER'],
#  '119364': ['GEAR,FUEL PUMPING'],
#  '03196949': ['PANEL-CONTROL BOX'],
#  '03330790': ['BRACKET-HEATER'],
#  '5264214': ['CONTROL,JOYSTICK MOTION'],
#  '0402077905': ['ISOLATOR - VIBRATION'],
#  '3824424': ['INSTALLER,CRANKSHAFT SEAL'],
#  'J01308608': ['BELT-RAD POLY V 2285 MM'],
#  'AX1012822': ['PLC - 24 V DC'],
#  '4054071': ['TUBE,LUB OIL TRANSFER'],
#  '4054093': ['TUBE,LUB OIL TRANSFER'],
#  'A048K611': ['DOOR,ENCLOSURE'],
#  'A048K615': ['DOOR,ENCLOSURE'],
#  'A048G165': ['GENERATOR'],
#  'AX1013754': ['INDICATOR,RESTRICTION'],
#  'A048P490': ['CLAMP,HOSE'],
#  '05411146': ['PUMP KIT (RE70962)'],
#  '3287300': ['BRACKET,IDLER PULLEY'],
#  '4955521': ['SET,MAIN BEARING'],
#  'A048N787': ['CORE,RADIATOR'],
#  '3025997': ['HOUSING,FLYWHEEL'],
#  '4345156': ['DATA,ENGINE CONTROL'],
#  '4345166': ['DATA,INSTALLATION TRIM'],
#  '4334001': ['TUBE,LUB OIL SUCTION'],
#  '5303139': ['CLIP'],
#  '5293884': ['HOUSING,GEAR'],
#  'A048N508': ['HARNESS,CONTROL'],
#  'A048H279': ['INSULATION,ENCLOSURE'],
#  'A048K954': ['FOAM,PANEL'],
#  'AX1001382': ['PULLEY FAN'],
#  'AX1001412': ['45 KVA 3 PH UCI224D1 WITH AVR, WITH CT SAE 3/11.5'],
#  'AX1001415': ['ALTERNATOR 60 KVA -CG NEWAGE UC2244E'],
#  'AX1001376': ['V BELT COGGED'],
#  'AX1001318': ['ALTERNATOR 30 KVA -CG NEWAGE UC2244C1'],
#  'AX1001320': ['TOOL KIT MOTORPAL'],
#  'RC4913146': ['CORE INJECTOR'],
#  'RO3523070': ['TURBOCHARGER NT RECON'],
#  '3882774': ['SEAL,O RING'],
#  '3897387': ['PUMP,SEA WATER'],
#  '3898020': ['B5.9G (NAT GAS) ENG. FAM'],
#  '3898627': ['VIRTUAL COLLEGE NATURAL G'],
#  '3074422': ['COVER,PROTECTIVE'],
#  '211968': ['GOVERNOR,MECHANICAL'],
#  'AX1007447': ['ACTUATOR SWITCH ON-OFF'],
#  'AX1001426': ['ALTERNATOR,180 KVA 3 PH UCI274G1 SINGLE BEARING, WITHOUT AVR, WITH CT SAE 2/11.5'],
#  'AX1001430': ['250 KVA 3 PH HCI444C1 WITHOUT AVR, WITH CT SAE 2/11.5'],
#  'AX1001482': ['ECCENTRIC SHAFT'],
#  '3230216': ['HOUSING BEARING'],
#  '4072921': ['PIPE,AIR INLET'],
#  '4072094': ['TUBE,AIR INLET'],
#  '3627662': ['TUBE,LUB OIL TRANSFER'],
#  'KIT3238327': ['COMPLETE OVERHAUL KIT_SET OF 10_855 COMPRESSOR'],
#  '4302609': ['HARNESS,WIRING'],
#  '4030864': ['KIT,TURBOCHARGER ACTUATOR'],
#  '3800765': ['KIT,ENGINE BRAKE'],
#  '5552790': ['TURBOCHARGER'],
#  '4963832': ['HOSE,FLEXIBLE'],
#  '5621847': ['TENSIONER,BELT'],
#  'A064S132': ['BRACKET,GUARD'],
#  'A056H970': ['GASKET,CIRCULAR'],
#  '3165643': ['BRACKET,CHECK VALVE'],
#  '0323167802': ['CONNECTOR-PLUG'],
#  '3000934': ['SPRING,COMPRESSION'],
#  '4078400': ['INJECTOR'],
#  '3230406': ['GASKET,FLANGE'],
#  'NI910022198': ['REGULATOR STAND FOR  CPF'],
#  'NI181027197': ['BALL BEARING 6226 C3'],
#  '0332402504': ['TERMINAL-RECEPTACLE'],
#  'A043K974': ['GUARD,FAN'],
#  'A043K944': ['TANK,RADIATOR'],
#  'A043L434': ['BRACKET,RADIATOR'],
#  'A043L448': ['HOSE,RADIATOR'],
#  'A042Z616': ['SCREW,BUTTON HEAD'],
#  '0320222405': ['CIRCUIT BREAKER 4P 32A MCB'],
#  '0319605402': ['BRACKET CONTROL BOX'],
#  '0403628901': ['PLATE - TANK'],
#  '4944182': ['ROD,PUSH'],
#  '4944183': ['LEVER,ROCKER'],
#  '4955573': ['KIT,ENGINE PISTON'],
#  'NI910021655': ['PROTECTIVE SWITCH 3120'],
#  'NI0E00031': ['PRINTED CIRCUIT BOARD TO112.1'],
#  '4982558': ['HEAD,CYLINDER'],
#  '5335052': ['HOSE,PLAIN'],
#  '500346': ['KEY,RECTANGULAR'],
#  'AR96066': ['FILTER,LUB OIL'],
#  'AR96295': ['SHELL, ASSEMBLY'],
#  '142248': ['CONNECTION,AIR CROSSOVER'],
#  '140205': ['HOUSING,THERMOSTAT'],
#  '120918': ['TUBE,VENT'],
#  '109557': ['WASHER,PLAIN'],
#  '0503220406': ['HOSE-STEAM'],
#  '4938940': ['BEARING,MAIN'],
#  '4096694': ['TUBE,TUR OIL SUPPLY'],
#  'A040G506': ['WRAPPER,GUARD'],
#  '5277340': ['TUBE,WATER TRANSFER'],
#  '3640332': ['SUPPORT,CONNECTION'],
#  '4945814': ['CONNECTION,EXHAUST OUTLET'],
#  '3521918': ['IMPELLER,TUR COMPRESSOR'],
#  '500943': ['SEAL,RECTANGULAR RING'],
#  '501085': ['HOUSING,THERMOSTAT'],
#  '500327': ['SPACER,HYDRAULIC PUMP'],
#  '5419151': ['SHIELD,HEAT'],
#  '5409684': ['BRACE,TUBE'],
#  '5419859': ['BRACKET,WIRING RETAINER'],
#  '5554134': ['TURBOCHARGER'],
#  '5563435': ['BRACE,TUBE'],
#  '5587214': ['BREATHER,CRANKCASE'],
#  '3627781': ['BRACKET,IDLER PULLEY'],
#  '3179672': ['BELT,V RIBBED'],
#  '3640314': ['HARNESS,WIRING'],
#  '5373059': ['BRACKET,FUEL PLUMBING'],
#  'A065P204': ['HOSE,FUEL'],
#  '3648157': ['PAN,OIL'],
#  '5466253': ['SHIELD,HEAT'],
#  '5419463': ['SHIELD,HEAT'],
#  '5419450': ['SHIELD,HEAT'],
#  '5505282': ['SHIELD,HEAT'],
#  '4312970': ['SHIELD,HEAT'],
#  '5466563': ['SHIELD,HEAT'],
#  'A051F130': ['FRAME,CARRYING'],
#  'A051G202': ['HARNESS,POWER'],
#  '00988446': ['LABEL-INFORMATION'],
#  '0800652723': ['SCREW-HEX HD'],
#  '4333011': ['DATA,APL CONFIGURATIO'],
#  '4333020': ['DATA,INSTALLATION TRIM'],
#  '5316752': ['HOUSING,FLYWHEEL'],
#  '5289711': ['GAUGE,PRESSURE'],
#  'A051K941': ['PAN,OIL'],
#  'A050A994': ['CROSSMEMBER,SKID'],
#  'A051L117': ['BOLT,BANJO'],
#  'A051L121': ['FILTER,FUEL'],
#  '2897654': ['SENSOR,KNOCK'],
#  '3649443': ['COVER,CAMSHAFT'],
#  'AX1008843': ['B CHECK KIT FOR CPCB-II ENGINE MODEL B3.3'],
#  '4331003': ['"FILTER,LUBRICATING OIL"'],
#  'A051K203': ['BREAKER,CIRCUIT'],
#  'A051E688': ['PANEL,ENCLOSURE'],
#  'RX3803360': ['RECONDITIONED KIT INTAKE VALVE'],
#  'RX3810432': ['COPY-TROUBLE SHOOTING AND REPAIR MANUAL - K38/50'],
#  'RX3879479': ['RECONDITIONED VALVE,PISTON COOLING'],
#  'RX4000590': ['RECONDITIONED ALTERNATOR'],
#  'RX3878571': ['RECONDITIONED RADIATOR'],
#  'RX3878723': ['RECONDITIONED RADIATOR'],
#  'RX3879164': ['RECONDITIONED RADIATOR'],
#  '03231384': ['RECEPTACLE CIRCULAR'],
#  '102483': ['END,CONTROL ROD'],
#  '05051490': ['CONNECTOR,MALE'],
#  '05090196': ['O RING'],
#  '105293': ['GUIDE,VALVE STEM'],
#  '128129': ['FLANGE,WELD'],
#  '124547': ['GASKET GEAR CASE COVER'],
#  '3802627': ['KIT,ENGINE PISTON'],
#  '3802628': ['KIT,ENGINE PISTON'],
#  'RO4056378': ['RADIATOR RECON'],
#  ...}

# %%
columns_encoded = onehot.columns

# %%
columns_encoded
# Out:
# Index(['.CSJ1', '0098790201', '0098810403', '01021537', '01021543', '01030876',
#        '01042116', '01042117', '01050791', '01104013',
#        ...
#        'S610', 'S622', 'S670', 'S946', 'S985C', 'S1040A', 'S1650', 'S16052',
#        'SRSCPVMaintGen', 'nan'],
#       dtype='object', length=1627)

# %%
result = [i for i in parts_list if i in columns_encoded]

# %%
len(result)
# Out:
# 988

# %%
index_no = []
try:
    for x in result:
        index_no.append(onehot.columns.get_loc(x))
except:
    pass

# %%
index_no
# Out:
# [936,
#  352,
#  411,
#  878,
#  537,
#  464,
#  111,
#  1160,
#  241,
#  355,
#  543,
#  1086,
#  1307,
#  913,
#  995,
#  776,
#  1195,
#  547,
#  535,
#  458,
#  174,
#  159,
#  321,
#  1076,
#  427,
#  1239,
#  1090,
#  1143,
#  1139,
#  315,
#  276,
#  472,
#  947,
#  260,
#  874,
#  1589,
#  655,
#  501,
#  203,
#  1593,
#  353,
#  374,
#  932,
#  109,
#  627,
#  539,
#  1123,
#  962,
#  721,
#  389,
#  712,
#  23,
#  100,
#  598,
#  744,
#  527,
#  1136,
#  1174,
#  345,
#  201,
#  1348,
#  699,
#  1587,
#  1585,
#  1367,
#  692,
#  805,
#  663,
#  715,
#  718,
#  1018,
#  860,
#  1113,
#  1065,
#  813,
#  310,
#  1154,
#  1368,
#  1095,
#  21,
#  877,
#  512,
#  477,
#  20,
#  1203,
#  1094,
#  413,
#  1072,
#  939,
#  732,
#  33,
#  22,
#  237,
#  1172,
#  415,
#  391,
#  577,
#  516,
#  1366,
#  558,
#  950,
#  1097,
#  266,
#  1284,
#  668,
#  336,
#  1103,
#  568,
#  224,
#  343,
#  338,
#  967,
#  1012,
#  5,
#  179,
#  26,
#  1220,
#  1131,
#  807,
#  1306,
#  79,
#  1611,
#  1615,
#  1055,
#  540,
#  642,
#  667,
#  1079,
#  640,
#  318,
#  279,
#  282,
#  873,
#  1241,
#  842,
#  309,
#  1354,
#  167,
#  908,
#  1351,
#  330,
#  435,
#  54,
#  1305,
#  738,
#  764,
#  290,
#  322,
#  210,
#  1274,
#  1177,
#  952,
#  954,
#  399,
#  499,
#  192,
#  757,
#  199,
#  1011,
#  259,
#  523,
#  1169,
#  446,
#  450,
#  846,
#  986,
#  153,
#  1345,
#  292,
#  1118,
#  857,
#  468,
#  370,
#  41,
#  914,
#  379,
#  369,
#  725,
#  1129,
#  252,
#  465,
#  350,
#  973,
#  95,
#  424,
#  285,
#  948,
#  1365,
#  1315,
#  736,
#  700,
#  826,
#  623,
#  812,
#  689,
#  554,
#  595,
#  592,
#  1107,
#  1145,
#  669,
#  1108,
#  517,
#  1196,
#  57,
#  2,
#  845,
#  335,
#  249,
#  1357,
#  752,
#  750,
#  714,
#  972,
#  989,
#  137,
#  463,
#  1116,
#  658,
#  423,
#  480,
#  524,
#  747,
#  428,
#  620,
#  377,
#  847,
#  1105,
#  177,
#  907,
#  278,
#  497,
#  919,
#  123,
#  1578,
#  158,
#  746,
#  957,
#  761,
#  628,
#  211,
#  47,
#  52,
#  741,
#  688,
#  25,
#  1024,
#  717,
#  825,
#  622,
#  213,
#  613,
#  1126,
#  459,
#  75,
#  1071,
#  1006,
#  522,
#  1242,
#  881,
#  365,
#  339,
#  867,
#  1022,
#  528,
#  1204,
#  1186,
#  85,
#  297,
#  1610,
#  151,
#  550,
#  1199,
#  694,
#  745,
#  982,
#  129,
#  486,
#  705,
#  1387,
#  838,
#  112,
#  1047,
#  1373,
#  473,
#  1179,
#  197,
#  696,
#  1017,
#  1316,
#  327,
#  375,
#  1584,
#  1121,
#  1588,
#  1100,
#  1161,
#  243,
#  362,
#  68,
#  880,
#  269,
#  1153,
#  71,
#  1363,
#  980,
#  119,
#  674,
#  138,
#  1171,
#  773,
#  1,
#  843,
#  974,
#  534,
#  1007,
#  1091,
#  766,
#  988,
#  1137,
#  1075,
#  968,
#  731,
#  961,
#  308,
#  791,
#  1093,
#  1364,
#  1303,
#  1599,
#  498,
#  1341,
#  645,
#  653,
#  883,
#  226,
#  602,
#  822,
#  344,
#  804,
#  1166,
#  244,
#  184,
#  320,
#  445,
#  448,
#  666,
#  261,
#  1167,
#  19,
#  1243,
#  560,
#  888,
#  742,
#  1380,
#  1101,
#  637,
#  1211,
#  36,
#  207,
#  863,
#  242,
#  161,
#  1048,
#  60,
#  1163,
#  895,
#  891,
#  347,
#  1358,
#  1362,
#  418,
#  106,
#  147,
#  239,
#  245,
#  969,
#  50,
#  1061,
#  934,
#  1182,
#  854,
#  581,
#  865,
#  1016,
#  1138,
#  1083,
#  1591,
#  1567,
#  1614,
#  835,
#  1037,
#  246,
#  144,
#  780,
#  1192,
#  1135,
#  610,
#  380,
#  1205,
#  765,
#  617,
#  398,
#  876,
#  373,
#  875,
#  1069,
#  135,
#  781,
#  695,
#  916,
#  788,
#  53,
#  489,
#  357,
#  953,
#  571,
#  574,
#  852,
#  1286,
#  856,
#  959,
#  615,
#  504,
#  273,
#  265,
#  1227,
#  1225,
#  410,
#  182,
#  154,
#  958,
#  580,
#  703,
#  487,
#  1224,
#  687,
#  70,
#  1346,
#  612,
#  654,
#  549,
#  734,
#  605,
#  1245,
#  298,
#  885,
#  630,
#  178,
#  851,
#  753,
#  841,
#  971,
#  1233,
#  884,
#  1214,
#  401,
#  795,
#  78,
#  1570,
#  128,
#  1110,
#  120,
#  148,
#  607,
#  274,
#  646,
#  648,
#  1202,
#  977,
#  494,
#  299,
#  1050,
#  811,
#  737,
#  457,
#  225,
#  317,
#  575,
#  1173,
#  735,
#  544,
#  762,
#  248,
#  455,
#  1150,
#  1371,
#  519,
#  590,
#  678,
#  289,
#  618,
#  1184,
#  110,
#  1051,
#  1162,
#  1277,
#  215,
#  710,
#  181,
#  1382,
#  827,
#  1104,
#  796,
#  434,
#  437,
#  1232,
#  341,
#  332,
#  1374,
#  247,
#  720,
#  930,
#  1058,
#  1181,
#  639,
#  682,
#  125,
#  43,
#  733,
#  774,
#  787,
#  905,
#  55,
#  975,
#  1014,
#  616,
#  76,
#  89,
#  348,
#  1159,
#  506,
#  562,
#  69,
#  253,
#  134,
#  624,
#  606,
#  1102,
#  987,
#  150,
#  672,
#  892,
#  514,
#  893,
#  894,
#  1054,
#  680,
#  1146,
#  407,
#  1119,
#  994,
#  202,
#  1152,
#  684,
#  1190,
#  1066,
#  139,
#  931,
#  127,
#  724,
#  698,
#  759,
#  1068,
#  754,
#  421,
#  420,
#  49,
#  626,
#  142,
#  46,
#  1194,
#  564,
#  1183,
#  431,
#  798,
#  48,
#  222,
#  793,
#  924,
#  412,
#  251,
#  840,
#  1009,
#  683,
#  264,
#  414,
#  810,
#  829,
#  170,
#  323,
#  1244,
#  690,
#  164,
#  870,
#  400,
#  1586,
#  625,
#  368,
#  118,
#  970,
#  779,
#  1209,
#  1376,
#  722,
#  828,
#  833,
#  1604,
#  548,
#  1059,
#  593,
#  713,
#  836,
#  387,
#  395,
#  933,
#  28,
#  188,
#  316,
#  596,
#  108,
#  216,
#  194,
#  200,
#  183,
#  1176,
#  770,
#  491,
#  1013,
#  641,
#  697,
#  790,
#  943,
#  409,
#  430,
#  94,
#  103,
#  815,
#  1568,
#  525,
#  1356,
#  466,
#  176,
#  1223,
#  460,
#  481,
#  890,
#  1575,
#  1057,
#  1185,
#  1308,
#  1311,
#  1379,
#  855,
#  1003,
#  180,
#  702,
#  228,
#  859,
#  585,
#  406,
#  633,
#  66,
#  67,
#  304,
#  187,
#  1613,
#  998,
#  88,
#  386,
#  1246,
#  1236,
#  903,
#  24,
#  660,
#  272,
#  287,
#  985,
#  1247,
#  1304,
#  981,
#  1168,
#  871,
#  483,
#  518,
#  808,
#  1073,
#  268,
#  1279,
#  311,
#  960,
#  186,
#  990,
#  691,
#  166,
#  956,
#  376,
#  306,
#  175,
#  1564,
#  1563,
#  1134,
#  91,
#  8,
#  77,
#  542,
#  1197,
#  1200,
#  1206,
#  208,
#  1201,
#  866,
#  1600,
#  1067,
#  187,
#  1170,
#  1562,
#  868,
#  453,
#  122,
#  1210,
#  198,
#  911,
#  900,
#  6,
#  937,
#  305,
#  1313,
#  1092,
#  342,
#  371,
#  778,
#  797,
#  758,
#  351,
#  784,
#  105,
#  1045,
#  521,
#  1240,
#  1273,
#  1074,
#  704,
#  185,
#  915,
#  1372,
#  771,
#  1601,
#  730,
#  230,
#  756,
#  155,
#  651,
#  1155,
#  1148,
#  1062,
#  37,
#  839,
#  587,
#  1621,
#  136,
#  288,
#  561,
#  1607,
#  1019,
#  378,
#  484,
#  996,
#  1605,
#  830,
#  1248,
#  74,
#  32,
#  452,
#  361,
#  1378,
#  591,
#  229,
#  760,
#  65,
#  650,
#  209,
#  1572,
#  634,
#  1099,
#  726,
#  1049,
#  349,
#  906,
#  533,
#  1189,
#  706,
#  557,
#  14,
#  1052,
#  723,
#  1579,
#  1580,
#  382,
#  493,
#  1088,
#  1590,
#  831,
#  250,
#  1620,
#  1142,
#  635,
#  141,
#  454,
#  685,
#  1283,
#  358,
#  238,
#  130,
#  63,
#  140,
#  333,
#  1219,
#  1221,
#  576,
#  1355,
#  80,
#  719,
#  31,
#  1077,
#  307,
#  743,
#  751,
#  1250,
#  510,
#  794,
#  113,
#  206,
#  1120,
#  801,
#  821,
#  490,
#  946,
#  84,
#  97,
#  219,
#  1235,
#  40,
#  1180,
#  789,
#  328,
#  1149,
#  636,
#  1576,
#  83,
#  416,
#  1222,
#  1230,
#  471,
#  992,
#  90,
#  390,
#  837,
#  449,
#  1114,
#  799,
#  442,
#  186,
#  38,
#  965,
#  922,
#  949,
#  294,
#  169,
#  609,
#  232,
#  440,
#  30,
#  559,
#  1231,
#  1053,
#  594,
#  1122,
#  545,
#  162,
#  649,
#  814,
#  515,
#  586,
#  114,
#  917,
#  1001,
#  93,
#  7,
#  1312,
#  405,
#  727,
#  509,
#  286,
#  1278,
#  1353,
#  802,
#  1270,
#  231,
#  340,
#  966,
#  475,
#  1565,
#  566,
#  1084,
#  918,
#  291,
#  96,
#  39,
#  72,
#  777,
#  505,
#  984,
#  233,
#  729,
#  115,
#  444,
#  769,
#  902,
#  1217,
#  785,
#  263,
#  17,
#  1064,
#  1622,
#  572,
#  621,
#  964,
#  117,
#  485,
#  686,
#  1046,
#  938,
#  1360,
#  563,
#  1141,
#  326,
#  212,
#  64,
#  800,
#  872,
#  1595,
#  1187,
#  270,
#  531,
#  1238,
#  1237,
#  1089,
#  1106,
#  1178,
#  422,
#  392,
#  467,
#  235,
#  1624,
#  366,
#  1193,
#  887,
#  334,
#  1623,
#  1342,
#  133,
#  10,
#  18,
#  520,
#  27,
#  393,
#  508,
#  156,
#  35,
#  570,
#  1015,
#  578,
#  955,
#  638,
#  204,
#  1078,
#  402,
#  15,
#  171,
#  1112,
#  45,
#  217,
#  168,
#  1132,
#  1133,
#  1369,
#  739]

# %%
onehot = onehot.iloc[:,index_no]

# %%
onehot.shape
# Out:
# (6000, 988)

# %% [markdown]
# ## Apriori

# %%
# Import Apriori algorithm
from mlxtend.frequent_patterns import apriori

# %%
# Compute frequent itemsets
#frequent_itemsets1 = apriori(onehot, min_support = 0.0005,max_len = 4, use_colnames = True)
frequent_itemsets = apriori(onehot, min_support = 0.005,max_len = 5, use_colnames = True)

# Print number of itemsets
print(len(frequent_itemsets))
# Out:
# 465

# %%
import sys

# %%
sys.getsizeof(frequent_itemsets)

# %%
print(frequent_itemsets.head())
# Out:
#     support     itemsets
# 0  0.012500  (AX1008843)
# 1  0.006667    (3167224)
# 2  0.008167  (AX1014236)
# 3  0.014333  (AX1014429)
# 4  0.042167   (01220962)

# %%
# Import Apriori algorithm
from mlxtend.frequent_patterns import apriori, association_rules

# Compute association rules
Rules = association_rules(frequent_itemsets,
                          metric = "support",
                          min_threshold = 0.005)

# %%
# Print association rules
Rules
# Out:
#       antecedents                           consequents  antecedent support  \
# 0       (3238666)                           (AX1008843)            0.082500
# 1     (AX1008843)                             (3238666)            0.012500
# 2      (01220962)                            (01404088)            0.042167
# 3      (01404088)                            (01220962)            0.054833
# 4      (01220962)                           (AX1014598)            0.042167
# ...           ...                                   ...                 ...
# 3345    (4093731)  (4080720, 3403800, 3937743, 3238666)            0.126333
# 3346    (3937743)  (4080720, 3403800, 4093731, 3238666)            0.060167
# 3347    (4080720)  (3403800, 4093731, 3238666, 3937743)            0.042333
# 3348    (3403800)  (4080720, 4093731, 3238666, 3937743)            0.096833
# 3349    (3238666)  (4080720, 3403800, 4093731, 3937743)            0.082500
#
#       consequent support   support  confidence       lift  leverage  \
# 0               0.012500  0.006500    0.078788   6.303030  0.005469
# 1               0.082500  0.006500    0.520000   6.303030  0.005469
# 2               0.054833  0.006000    0.142292   2.595000  0.003688
# 3               0.042167  0.006000    0.109422   2.595000  0.003688
# 4               0.034833  0.007667    0.181818   5.219661  0.006198
# ...                  ...       ...         ...        ...       ...
# 3345            0.005167  0.005167    0.040897   7.915567  0.004514
# 3346            0.005333  0.005167    0.085873  16.101108  0.004846
# 3347            0.007000  0.005167    0.122047  17.435321  0.004870
# 3348            0.012500  0.005167    0.053356   4.268503  0.003956
# 3349            0.007333  0.005167    0.062626   8.539945  0.004562
#
#       conviction
# 0       1.071957
# 1       1.911458
# 2       1.101969
# 3       1.075519
# 4       1.179648
# ...          ...
# 3345    1.037254
# 3346    1.088105
# 3347    1.131040
# 3348    1.043159
# 3349    1.058987
#
# [3350 rows x 9 columns]

# %%
filtered_rules = Rules[(Rules['antecedent support'] > 0.01) & 
                       (Rules['support'] > 0.009) & 
                       (Rules['confidence'] > 0.5) & 
                       (Rules['lift'] > 1.00)]

# %%
filtered_rules
# Out:
#              antecedents                  consequents  antecedent support  \
# 12            (01492967)                   (01220962)            0.069000
# 13            (01220962)                   (01492967)            0.042167
# 19            (01404088)                   (01220922)            0.054833
# 28           (AX1004458)                    (3931063)            0.027000
# 30           (AX1004458)                    (4093731)            0.027000
# ...                  ...                          ...                 ...
# 2858  (3931063, 3238666)  (4080720, 4093731, 3937743)            0.021500
# 2861  (4093731, 3238666)  (4080720, 3931063, 3937743)            0.022333
# 2862  (4080720, 3937743)  (4093731, 3931063, 3238666)            0.020833
# 2863  (3937743, 3238666)  (4080720, 4093731, 3931063)            0.018667
# 2864  (4080720, 3238666)  (4093731, 3931063, 3937743)            0.014500
#
#       consequent support   support  confidence       lift  leverage  \
# 12              0.042167  0.035333    0.512077  12.144126  0.032424
# 13              0.069000  0.035333    0.837945  12.144126  0.032424
# 19              0.060333  0.030167    0.550152   9.118541  0.026858
# 28              0.091333  0.015667    0.580247   6.353068  0.013201
# 30              0.126333  0.016667    0.617284   4.886153  0.013256
# ...                  ...       ...         ...        ...       ...
# 2858            0.020833  0.012500    0.581395  27.906977  0.012052
# 2861            0.020833  0.012500    0.559701  26.865672  0.012035
# 2862            0.021500  0.012500    0.600000  27.906977  0.012052
# 2863            0.033500  0.012500    0.669643  19.989339  0.011875
# 2864            0.058000  0.012500    0.862069  14.863258  0.011659
#
#       conviction
# 12      1.963084
# 13      5.744951
# 19      2.088854
# 28      2.164765
# 30      2.282806
# ...          ...
# 2858    2.339120
# 2861    2.223870
# 2862    2.446250
# 2863    2.925622
# 2864    6.829500
#
# [356 rows x 9 columns]

# %%
type(filtered_rules)
# Out:
# pandas.core.frame.DataFrame

# %%
final_rules = filtered_rules.sort_values('confidence',ascending=False)

# %%
final_rules
# Out:
#                         antecedents         consequents  antecedent support  \
# 1575    (4080720, 3931063, 3238666)           (4093731)            0.013167
# 1127  (AX1004458, 3931063, 3937743)           (4093731)            0.015333
# 1129  (AX1004458, 4093731, 3937743)           (3931063)            0.015333
# 2176    (3238493, 3167226, 3879488)           (3238204)            0.010833
# 710              (3937743, 3238666)           (4093731)            0.018667
# ...                             ...                 ...                 ...
# 624              (3931063, 5285612)           (4315238)            0.031500
# 1664             (3931063, 4926654)  (4093731, 3937743)            0.023000
# 121                       (3167222)           (3879488)            0.022500
# 845                       (3167222)  (3879488, 3238204)            0.022500
# 249                       (3167222)           (3238204)            0.022500
#
#       consequent support   support  confidence       lift  leverage  \
# 1575            0.126333  0.013167    1.000000   7.915567  0.011503
# 1127            0.126333  0.015333    1.000000   7.915567  0.013396
# 1129            0.091333  0.015333    1.000000  10.948905  0.013933
# 2176            0.040667  0.010833    1.000000  24.590164  0.010393
# 710             0.126333  0.018667    1.000000   7.915567  0.016308
# ...                  ...       ...         ...        ...       ...
# 624             0.034167  0.016000    0.507937  14.866434  0.014924
# 1664            0.058333  0.011667    0.507246   8.695652  0.010325
# 121             0.039500  0.011333    0.503704  12.751992  0.010445
# 845             0.037333  0.011333    0.503704  13.492063  0.010493
# 249             0.040667  0.011333    0.503704  12.386157  0.010418
#
#       conviction
# 1575         inf
# 1127         inf
# 1129         inf
# 2176         inf
# 710          inf
# ...          ...
# 624     1.962823
# 1664    1.911029
# 121     1.935336
# 845     1.939701
# 249     1.932985
#
# [356 rows x 9 columns]

# %%
final_rules = final_rules.drop(columns = ['antecedent support','consequent support','leverage','conviction'])

# %%
final_rules

# %% [markdown]
# ## Mapping parts number with description

# %%
type(final_rules.iloc[0]['antecedents'])

# %%
x = final_rules.iloc[0]['antecedents']

# %%
x

# %%
temp_list=[]
#temp_list2 = []
for j in range(len(final_rules)):
    x = final_rules.iloc[j]['antecedents']
    temp_list2 = []
    for i in x:
        part_name = part_dict[i][0]
        temp = str(i)+" "+str(part_name)
        temp_list2.append(temp)
    temp_list.append(temp_list2)

# %%
temp_list3=[]
#temp_list2 = []
for j in range(len(final_rules)):
    x = final_rules.iloc[j]['consequents']
    temp_list2 = []
    for i in x:
        part_name = part_dict[i][0]
        temp = str(i)+" "+str(part_name)
        temp_list2.append(temp)
    temp_list3.append(temp_list2)

# %%
supp=[]
#temp_list2 = []
for j in range(len(final_rules)):
    x = final_rules.iloc[j]['support']
    supp2 = []
    supp2.append(x)
    supp.append(supp2)

# %%
conf=[]
#temp_list2 = []
for j in range(len(final_rules)):
    x = final_rules.iloc[j]['confidence']
    conf2 = []
    conf2.append(x)
    conf.append(conf2)

# %%
lift=[]
#temp_list2 = []
for j in range(len(final_rules)):
    x = final_rules.iloc[j]['lift']
    lift2 = []
    lift2.append(x)
    lift.append(lift2)

# %%
xy = pd.Series(temp_list)

# %%
yz = pd.Series(temp_list3)

# %%
supp = pd.Series(supp)
conf = pd.Series(conf)
lift = pd.Series(lift)

# %%
frame = { 'antecedents': xy, 'consequents': yz, 'support':supp, 'confidence': conf, 'lift':lift }

# %%
final_part_output = pd.DataFrame(frame)

# %%
final_part_output
# Out:
#                                            antecedents  \
# 0    [4080720 STRAINER,FUEL, 3931063 FILTER,FUEL, 3...
# 1    [AX1004458 PREMIUM BLUE CI4 PLUS 15W40 5 LTR, ...
# 2    [AX1004458 PREMIUM BLUE CI4 PLUS 15W40 5 LTR, ...
# 3    [3238493 KIT,FUEL FILTER AND RING, 3167226 KIT...
# 4    [3937743 "CARTRIDGE,LUB OIL FILTER", 3238666 K...
# ..                                                 ...
# 351  [3931063 FILTER,FUEL, 5285612 CARTRIDGE,LUB OI...
# 352  [3931063 FILTER,FUEL, 4926654 INHIBITOR,CORROS...
# 353            [3167222 INHIBITOR,CORROSION 10 LITERS]
# 354            [3167222 INHIBITOR,CORROSION 10 LITERS]
# 355            [3167222 INHIBITOR,CORROSION 10 LITERS]
#
#                                            consequents  \
# 0                       [4093731 SEPARATOR,FUEL WATER]
# 1                       [4093731 SEPARATOR,FUEL WATER]
# 2                                [3931063 FILTER,FUEL]
# 3                     [3238204 ELEMENT,LUB OIL FILTER]
# 4                       [4093731 SEPARATOR,FUEL WATER]
# ..                                                 ...
# 351                      [4315238 "AIR FILTER,SAFETY"]
# 352  [4093731 SEPARATOR,FUEL WATER, 3937743 "CARTRI...
# 353                [3879488 KIT,SUPER BYP.FILTER ELEM]
# 354  [3879488 KIT,SUPER BYP.FILTER ELEM, 3238204 EL...
# 355                   [3238204 ELEMENT,LUB OIL FILTER]
#
#                     support            confidence                  lift
# 0    [0.013166666666666667]                 [1.0]     [7.9155672823219]
# 1    [0.015333333333333332]                 [1.0]     [7.9155672823219]
# 2    [0.015333333333333332]                 [1.0]   [10.94890510948905]
# 3    [0.010833333333333334]                 [1.0]  [24.590163934426233]
# 4    [0.018666666666666668]                 [1.0]     [7.9155672823219]
# ..                      ...                   ...                   ...
# 351                 [0.016]  [0.5079365079365079]  [14.866434378629501]
# 352  [0.011666666666666667]  [0.5072463768115942]   [8.695652173913043]
# 353  [0.011333333333333334]  [0.5037037037037038]  [12.751992498827944]
# 354  [0.011333333333333334]  [0.5037037037037038]  [13.492063492063492]
# 355  [0.011333333333333334]  [0.5037037037037038]  [12.386156648451733]
#
# [356 rows x 5 columns]

# %%
final_part_output.to_csv('OTC_JC6000.csv')

# %% [markdown]
# ## ***************************************

# %%
boolarr = final_rules['antecedents'] == final_rules['consequents']

# %%
boolarr.sum()

# %%
column_names = final_rules.columns

# %%
result_df = pd.DataFrame(columns=column_names)

# %%
len_of_df = len(final_rules)

# %%
len_of_df

# %%
result_df = pd.DataFrame(0, index=np.arange(len_of_df), columns=column_names)

# %%
result_df

# %%
result_df

# %%
def csv_output(final_dataframe,part_dict,df_result):
    
    
    for index_number in range(len(final_dataframe)):
        x = final_dataframe.iloc[index_number]['antecedents']
        y = final_dataframe.iloc[index_number]['consequents']
        for i in x:
             part_name = part_dict[i][0]
             temp_a = str(i)+" "+str(part_name)
             df_result.iloc[index_number]['antecedents'] = temp_a
        for i in y:
             part_name = part_dict[i][0]
             temp_c = str(i)+" "+str(part_name)
             df_result.iloc[index_number]['consequents'] = temp_c
    df_result['support'] = final_dataframe['support']
    df_result['confidence'] = final_dataframe['confidence']
    df_result['lift'] = final_dataframe['lift']
    return df_result

# %%
tmpo_out = csv_output(final_rules,part_dict,result_df)

# %%
tmpo_out
